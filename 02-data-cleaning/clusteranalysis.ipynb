# %%
# Import data manipulation libraries
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import calendar
from datetime import datetime
pd.set_option('display.max_columns', None)

from plotly.subplots import make_subplots
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
# load the cleaned clustered data

df = pd.read_csv("cleaned_fulldf_withclusters.csv")

# %%
df.head()
# Out:
#                 ID    Set District      Block CropTillageDate  \
# 0  ID_GTFAC7PEVWQ9  train  Nalanda  Noorsarai      2022-07-20
# 1  ID_TK40ARLSPOKS  train  Nalanda     Rajgir      2022-07-18
# 2  ID_1FJY2CRIMLZZ  train     Gaya      Gurua      2022-06-30
# 3  ID_I3IPXS4DB7NE  train     Gaya      Gurua      2022-06-16
# 4  ID_4T8YQWXWHB4A  train  Nalanda  Noorsarai      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# 1                 5  Manual_PuddledRandom    2022-06-20
# 2                 6  Manual_PuddledRandom    2022-06-20
# 3                 6  Manual_PuddledRandom    2022-06-17
# 4                 4  Manual_PuddledRandom    2022-06-21
#
#   SeedingSowingTransplanting  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0                 2022-07-21              2.0                           5.0
# 1                 2022-07-20              2.0                           5.0
# 2                 2022-08-13              2.0                           4.0
# 3                 2022-07-17              2.0                           NaN
# 4                 2022-07-20              2.0                           9.0
#
#   TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# 0                        Boring                           Electric
# 1                        Boring                           Electric
# 2                        Boring                           Electric
# 3                           NaN                                NaN
# 4                        Boring                           Electric
#
#    TransIrriCost  TransIrriCost_per_Acre  StandingWater  Ganaura  \
# 0          200.0                   640.0            2.0      0.0
# 1          125.0                   400.0            3.0      0.0
# 2           80.0                   540.0            2.0      1.0
# 3            NaN                     NaN            NaN      1.0
# 4          300.0                   640.0            2.0      0.0
#
#    Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 0               NaN         0.0                  NaN
# 1               NaN         0.0                  NaN
# 2              6.75         1.0                 6.75
# 3              4.50         0.0                  NaN
# 4               NaN         0.0                  NaN
#
#   PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  BasalDAP_per_Acre  \
# 0                        NaN                  2       0.0                NaN
# 1                        NaN                  2      15.0               48.0
# 2                SoilApplied                  2       4.0               27.0
# 3                SoilApplied                  2       6.0               27.0
# 4                        NaN                  2      15.0               32.0
#
#    BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  1tdUrea  \
# 0       20.0                64.0         Broadcasting     15.0
# 1       10.0                32.0         Broadcasting     20.0
# 2        0.0                 NaN          SoilApplied      5.0
# 3        3.0                13.5         Broadcasting      5.0
# 4       30.0                64.0         Broadcasting     30.0
#
#    1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  2appDaysUrea  \
# 0             48.00          18.0      0.0               NaN           NaN
# 1             64.00          39.0      0.0               NaN           NaN
# 2             33.75          65.0      0.0               NaN           NaN
# 3             22.50           5.0      0.0               NaN           NaN
# 4             64.00          26.0      0.0               NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting     machine  2022-11-16             0.0
# 1           Broadcasting        hand  2022-11-25             3.0
# 2        RootApplication        hand  2022-12-12           480.0
# 3           Broadcasting        hand  2022-12-02           240.0
# 4           Broadcasting     machine  2022-11-30             0.0
#
#    Harv_hand_rent_per_Acre Threshing_date Threshing_method  Residue_length  \
# 0                      NaN     2022-11-16          machine              30
# 1                      9.6     2022-12-24          machine              24
# 2                   3240.0     2023-01-11          machine              30
# 3                   1080.0     2022-12-29             hand              26
# 4                      NaN     2022-12-02          machine              24
#
#    Residue_perc     Stubble_use      Acre  Yield  Yield_per_Acre  \
# 0            40  plowed_in_soil  0.312500  600.0     1920.000000
# 1            10  plowed_in_soil  0.312500  600.0     1920.000000
# 2            10  plowed_in_soil  0.148148  225.0     1518.750000
# 3            10  plowed_in_soil  0.222222  468.0     2106.000000
# 4            40  plowed_in_soil  0.468750  550.0     1173.333333
#
#    LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 0                          True                                   True
# 1                          True                                   True
# 2                          True                                   True
# 3                          True                                   True
# 4                          True                                  False
#
#    LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 0                              False                         False
# 1                               True                         False
# 2                              False                         False
# 3                              False                         False
# 4                               True                         False
#
#    LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 0                 False                        True
# 1                 False                        True
# 2                 False                       False
# 3                 False                        True
# 4                 False                        True
#
#    NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 0                            False                                  True
# 1                             True                                  True
# 2                             True                                  True
# 3                             True                                  True
# 4                            False                                  True
#
#    NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 0                             False                            True
# 1                              True                            True
# 2                              True                           False
# 3                              True                            True
# 4                             False                            True
#
#    TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 0                              False                         True
# 1                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
#
#    TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                        True                                   True
# 4                        True                                   True
#
#    TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 0                        True                 True               False
# 1                        True                 True                True
# 2                        True                False                True
# 3                        True                 True                True
# 4                        True                 True                True
#
#    CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
#
#    FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 0                   False                  False                    False
# 1                   False                  False                    False
# 2                   False                  False                    False
# 3                   False                  False                    False
# 4                   False                  False                    False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN k2label  \
# 0                     False                         False          7       A
# 1                     False                         False          5       A
# 2                     False                         False          3       A
# 3                     False                         False          9       A
# 4                     False                         False          6       A
#
#   k3label k4label k5label
# 0       A       A       B
# 1       A       A       B
# 2       A       A       A
# 3       A       A       A
# 4       A       A       B

# %%
# view 10 complete rows of the data of which we view all columns
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#                 ID    Set  District      Block CropTillageDate  \
# 0  ID_GTFAC7PEVWQ9  train   Nalanda  Noorsarai      2022-07-20
# 1  ID_TK40ARLSPOKS  train   Nalanda     Rajgir      2022-07-18
# 2  ID_1FJY2CRIMLZZ  train      Gaya      Gurua      2022-06-30
# 3  ID_I3IPXS4DB7NE  train      Gaya      Gurua      2022-06-16
# 4  ID_4T8YQWXWHB4A  train   Nalanda  Noorsarai      2022-07-19
# 5  ID_W5MM9H353RL9  train  Vaishali     Garoul      2022-07-02
# 6  ID_6O44Z25H1JAV  train     Jamui     Khaira      2022-07-23
# 7  ID_VRI9LEL2W3DR  train   Nalanda     Rajgir      2022-06-27
# 8  ID_6YA9Y09O55LE  train     Jamui     Khaira      2022-07-24
# 9  ID_EDA8RK1CP60K  train   Nalanda  Noorsarai      2022-07-14
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# 1                 5  Manual_PuddledRandom    2022-06-20
# 2                 6  Manual_PuddledRandom    2022-06-20
# 3                 6  Manual_PuddledRandom    2022-06-17
# 4                 4  Manual_PuddledRandom    2022-06-21
# 5                 6    Manual_PuddledLine    2022-06-15
# 6                 3  Manual_PuddledRandom    2022-07-05
# 7                 4          Broadcasting           NaN
# 8                 4  Manual_PuddledRandom    2022-07-09
# 9                 5  Manual_PuddledRandom    2022-06-27
#
#   SeedingSowingTransplanting  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0                 2022-07-21              2.0                           5.0
# 1                 2022-07-20              2.0                           5.0
# 2                 2022-08-13              2.0                           4.0
# 3                 2022-07-17              2.0                           NaN
# 4                 2022-07-20              2.0                           9.0
# 5                 2022-07-06              1.0                           1.0
# 6                 2022-07-30              4.0                           1.0
# 7                 2022-07-22              NaN                           5.0
# 8                 2022-08-02              4.0                           2.0
# 9                 2022-07-16              3.0                           2.0
#
#   TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# 0                        Boring                           Electric
# 1                        Boring                           Electric
# 2                        Boring                           Electric
# 3                           NaN                                NaN
# 4                        Boring                           Electric
# 5                        Boring                           Electric
# 6                         Canal                                NaN
# 7                        Boring                           Electric
# 8                         Canal                                NaN
# 9                        Boring                           Electric
#
#    TransIrriCost  TransIrriCost_per_Acre  StandingWater  Ganaura  \
# 0          200.0                   640.0            2.0      0.0
# 1          125.0                   400.0            3.0      0.0
# 2           80.0                   540.0            2.0      1.0
# 3            NaN                     NaN            NaN      1.0
# 4          300.0                   640.0            2.0      0.0
# 5            NaN                     NaN            3.0      0.0
# 6            NaN                     NaN            6.0      1.0
# 7            NaN                     NaN            3.0      0.0
# 8            NaN                     NaN            5.0      0.0
# 9          100.0                   640.0            1.0      0.0
#
#    Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 0               NaN         0.0                  NaN
# 1               NaN         0.0                  NaN
# 2          6.750000         1.0             6.750000
# 3          4.500000         0.0                  NaN
# 4               NaN         0.0                  NaN
# 5               NaN         5.0            36.666667
# 6          7.333333         0.0                  NaN
# 7               NaN         0.0                  NaN
# 8               NaN         2.0             8.800000
# 9               NaN         0.0                  NaN
#
#   PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  BasalDAP_per_Acre  \
# 0                        NaN                  2       0.0                NaN
# 1                        NaN                  2      15.0               48.0
# 2                SoilApplied                  2       4.0               27.0
# 3                SoilApplied                  2       6.0               27.0
# 4                        NaN                  2      15.0               32.0
# 5                SoilApplied                  2       6.0               44.0
# 6                SoilApplied                  3       3.0               22.0
# 7                        NaN                  2      15.0               60.0
# 8                SoilApplied                  3       5.0               22.0
# 9                        NaN                  2       0.0                NaN
#
#    BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  1tdUrea  \
# 0       20.0                64.0         Broadcasting     15.0
# 1       10.0                32.0         Broadcasting     20.0
# 2        0.0                 NaN          SoilApplied      5.0
# 3        3.0                13.5         Broadcasting      5.0
# 4       30.0                64.0         Broadcasting     30.0
# 5        0.0                 NaN          SoilApplied      6.0
# 6        0.0                 NaN         Broadcasting      4.0
# 7        8.0                32.0         Broadcasting     15.0
# 8        0.0                 NaN         Broadcasting      5.0
# 9       10.0                64.0         Broadcasting      5.0
#
#    1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  2appDaysUrea  \
# 0         48.000000          18.0      0.0               NaN           NaN
# 1         64.000000          39.0      0.0               NaN           NaN
# 2         33.750000          65.0      0.0               NaN           NaN
# 3         22.500000           5.0      0.0               NaN           NaN
# 4         64.000000          26.0      0.0               NaN           NaN
# 5         44.000000          30.0      0.0               NaN           NaN
# 6         29.333333          28.0      6.0              44.0          67.0
# 7         60.000000          35.0      0.0               NaN           NaN
# 8         22.000000          20.0      7.0              30.8          58.0
# 9         32.000000          20.0      0.0               NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting     machine  2022-11-16             0.0
# 1           Broadcasting        hand  2022-11-25             3.0
# 2        RootApplication        hand  2022-12-12           480.0
# 3           Broadcasting        hand  2022-12-02           240.0
# 4           Broadcasting     machine  2022-11-30             0.0
# 5           Broadcasting        hand  2022-10-24           600.0
# 6           Broadcasting        hand  2022-11-04           130.0
# 7           Broadcasting     machine  2022-12-05             0.0
# 8           Broadcasting        hand  2022-11-07           130.0
# 9           Broadcasting        hand  2022-10-29            80.0
#
#    Harv_hand_rent_per_Acre Threshing_date Threshing_method  Residue_length  \
# 0                      NaN     2022-11-16          machine              30
# 1                 9.600000     2022-12-24          machine              24
# 2              3240.000000     2023-01-11          machine              30
# 3              1080.000000     2022-12-29             hand              26
# 4                      NaN     2022-12-02          machine              24
# 5              4400.000000     2022-11-04             hand              30
# 6               953.333333     2022-12-08          machine              25
# 7                      NaN     2022-12-06             hand              25
# 8               572.000000     2022-12-15          machine              26
# 9               512.000000     2022-11-14             hand              22
#
#    Residue_perc     Stubble_use      Acre  Yield  Yield_per_Acre  \
# 0            40  plowed_in_soil  0.312500  600.0     1920.000000
# 1            10  plowed_in_soil  0.312500  600.0     1920.000000
# 2            10  plowed_in_soil  0.148148  225.0     1518.750000
# 3            10  plowed_in_soil  0.222222  468.0     2106.000000
# 4            40  plowed_in_soil  0.468750  550.0     1173.333333
# 5            10  plowed_in_soil  0.136364  205.0     1503.333333
# 6            10  plowed_in_soil  0.136364  270.0     1980.000000
# 7            40  plowed_in_soil  0.250000  490.0     1960.000000
# 8            10  plowed_in_soil  0.227273  425.0     1870.000000
# 9            10  plowed_in_soil  0.156250  300.0     1920.000000
#
#    LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 0                          True                                   True
# 1                          True                                   True
# 2                          True                                   True
# 3                          True                                   True
# 4                          True                                  False
# 5                          True                                  False
# 6                          True                                  False
# 7                         False                                   True
# 8                          True                                  False
# 9                         False                                  False
#
#    LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 0                              False                         False
# 1                               True                         False
# 2                              False                         False
# 3                              False                         False
# 4                               True                         False
# 5                              False                         False
# 6                              False                         False
# 7                              False                         False
# 8                              False                         False
# 9                               True                         False
#
#    LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 0                 False                        True
# 1                 False                        True
# 2                 False                       False
# 3                 False                        True
# 4                 False                        True
# 5                 False                        True
# 6                 False                        True
# 7                 False                       False
# 8                 False                        True
# 9                 False                        True
#
#    NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 0                            False                                  True
# 1                             True                                  True
# 2                             True                                  True
# 3                             True                                  True
# 4                            False                                  True
# 5                            False                                 False
# 6                            False                                 False
# 7                            False                                 False
# 8                            False                                 False
# 9                            False                                  True
#
#    NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 0                             False                            True
# 1                              True                            True
# 2                              True                           False
# 3                              True                            True
# 4                             False                            True
# 5                             False                            True
# 6                             False                            True
# 7                             False                           False
# 8                             False                            True
# 9                             False                            True
#
#    TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 0                              False                         True
# 1                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
# 5                              False                         True
# 6                              False                         True
# 7                              False                        False
# 8                              False                         True
# 9                              False                         True
#
#    TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                        True                                   True
# 4                        True                                   True
# 5                        True                                   True
# 6                        True                                   True
# 7                       False                                  False
# 8                        True                                   True
# 9                        True                                   True
#
#    TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 0                        True                 True               False
# 1                        True                 True                True
# 2                        True                False                True
# 3                        True                 True                True
# 4                        True                 True                True
# 5                        True                False                True
# 6                        True                False                True
# 7                       False                 True                True
# 8                        True                False                True
# 9                        True                 True               False
#
#    CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
# 5                  True               False               False
# 6                 False               False               False
# 7                 False               False               False
# 8                 False               False               False
# 9                 False               False               False
#
#    CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
# 5                False               False                False
# 6                False               False                False
# 7                False               False                False
# 8                False               False                False
# 9                False               False                False
#
#    FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
# 5                    True                  False                  False
# 6                    True                  False                  False
# 7                    True                  False                  False
# 8                    True                  False                  False
# 9                    True                  False                  False
#
#    FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 0                   False                  False                    False
# 1                   False                  False                    False
# 2                   False                  False                    False
# 3                   False                  False                    False
# 4                   False                  False                    False
# 5                   False                  False                    False
# 6                   False                  False                    False
# 7                   False                  False                    False
# 8                   False                  False                    False
# 9                   False                  False                    False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
# 5                   False                True                        False
# 6                    True               False                        False
# 7                   False               False                        False
# 8                   False                True                        False
# 9                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
# 5                     False                          False
# 6                     False                          False
# 7                     False                          False
# 8                     False                          False
# 9                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN k2label  \
# 0                     False                         False          7       A
# 1                     False                         False          5       A
# 2                     False                         False          3       A
# 3                     False                         False          9       A
# 4                     False                         False          6       A
# 5                     False                         False          6       A
# 6                     False                         False          5       A
# 7                     False                         False         12       A
# 8                     False                         False          5       A
# 9                     False                         False          6       A
#
#   k3label k4label k5label
# 0       A       A       B
# 1       A       A       B
# 2       A       A       A
# 3       A       A       A
# 4       A       A       B
# 5       A       A       A
# 6       A       A       A
# 7       A       A       B
# 8       A       A       A
# 9       A       A       B

# %%
df.loc[df['k3label'] == "A"].head(10)
# Out:
#                 ID    Set  District      Block CropTillageDate  \
# 0  ID_GTFAC7PEVWQ9  train   Nalanda  Noorsarai      2022-07-20
# 1  ID_TK40ARLSPOKS  train   Nalanda     Rajgir      2022-07-18
# 2  ID_1FJY2CRIMLZZ  train      Gaya      Gurua      2022-06-30
# 3  ID_I3IPXS4DB7NE  train      Gaya      Gurua      2022-06-16
# 4  ID_4T8YQWXWHB4A  train   Nalanda  Noorsarai      2022-07-19
# 5  ID_W5MM9H353RL9  train  Vaishali     Garoul      2022-07-02
# 6  ID_6O44Z25H1JAV  train     Jamui     Khaira      2022-07-23
# 7  ID_VRI9LEL2W3DR  train   Nalanda     Rajgir      2022-06-27
# 8  ID_6YA9Y09O55LE  train     Jamui     Khaira      2022-07-24
# 9  ID_EDA8RK1CP60K  train   Nalanda  Noorsarai      2022-07-14
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# 1                 5  Manual_PuddledRandom    2022-06-20
# 2                 6  Manual_PuddledRandom    2022-06-20
# 3                 6  Manual_PuddledRandom    2022-06-17
# 4                 4  Manual_PuddledRandom    2022-06-21
# 5                 6    Manual_PuddledLine    2022-06-15
# 6                 3  Manual_PuddledRandom    2022-07-05
# 7                 4          Broadcasting           NaN
# 8                 4  Manual_PuddledRandom    2022-07-09
# 9                 5  Manual_PuddledRandom    2022-06-27
#
#   SeedingSowingTransplanting  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0                 2022-07-21              2.0                           5.0
# 1                 2022-07-20              2.0                           5.0
# 2                 2022-08-13              2.0                           4.0
# 3                 2022-07-17              2.0                           NaN
# 4                 2022-07-20              2.0                           9.0
# 5                 2022-07-06              1.0                           1.0
# 6                 2022-07-30              4.0                           1.0
# 7                 2022-07-22              NaN                           5.0
# 8                 2022-08-02              4.0                           2.0
# 9                 2022-07-16              3.0                           2.0
#
#   TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# 0                        Boring                           Electric
# 1                        Boring                           Electric
# 2                        Boring                           Electric
# 3                           NaN                                NaN
# 4                        Boring                           Electric
# 5                        Boring                           Electric
# 6                         Canal                                NaN
# 7                        Boring                           Electric
# 8                         Canal                                NaN
# 9                        Boring                           Electric
#
#    TransIrriCost  TransIrriCost_per_Acre  StandingWater  Ganaura  \
# 0          200.0                   640.0            2.0      0.0
# 1          125.0                   400.0            3.0      0.0
# 2           80.0                   540.0            2.0      1.0
# 3            NaN                     NaN            NaN      1.0
# 4          300.0                   640.0            2.0      0.0
# 5            NaN                     NaN            3.0      0.0
# 6            NaN                     NaN            6.0      1.0
# 7            NaN                     NaN            3.0      0.0
# 8            NaN                     NaN            5.0      0.0
# 9          100.0                   640.0            1.0      0.0
#
#    Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 0               NaN         0.0                  NaN
# 1               NaN         0.0                  NaN
# 2          6.750000         1.0             6.750000
# 3          4.500000         0.0                  NaN
# 4               NaN         0.0                  NaN
# 5               NaN         5.0            36.666667
# 6          7.333333         0.0                  NaN
# 7               NaN         0.0                  NaN
# 8               NaN         2.0             8.800000
# 9               NaN         0.0                  NaN
#
#   PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  BasalDAP_per_Acre  \
# 0                        NaN                  2       0.0                NaN
# 1                        NaN                  2      15.0               48.0
# 2                SoilApplied                  2       4.0               27.0
# 3                SoilApplied                  2       6.0               27.0
# 4                        NaN                  2      15.0               32.0
# 5                SoilApplied                  2       6.0               44.0
# 6                SoilApplied                  3       3.0               22.0
# 7                        NaN                  2      15.0               60.0
# 8                SoilApplied                  3       5.0               22.0
# 9                        NaN                  2       0.0                NaN
#
#    BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  1tdUrea  \
# 0       20.0                64.0         Broadcasting     15.0
# 1       10.0                32.0         Broadcasting     20.0
# 2        0.0                 NaN          SoilApplied      5.0
# 3        3.0                13.5         Broadcasting      5.0
# 4       30.0                64.0         Broadcasting     30.0
# 5        0.0                 NaN          SoilApplied      6.0
# 6        0.0                 NaN         Broadcasting      4.0
# 7        8.0                32.0         Broadcasting     15.0
# 8        0.0                 NaN         Broadcasting      5.0
# 9       10.0                64.0         Broadcasting      5.0
#
#    1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  2appDaysUrea  \
# 0         48.000000          18.0      0.0               NaN           NaN
# 1         64.000000          39.0      0.0               NaN           NaN
# 2         33.750000          65.0      0.0               NaN           NaN
# 3         22.500000           5.0      0.0               NaN           NaN
# 4         64.000000          26.0      0.0               NaN           NaN
# 5         44.000000          30.0      0.0               NaN           NaN
# 6         29.333333          28.0      6.0              44.0          67.0
# 7         60.000000          35.0      0.0               NaN           NaN
# 8         22.000000          20.0      7.0              30.8          58.0
# 9         32.000000          20.0      0.0               NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting     machine  2022-11-16             0.0
# 1           Broadcasting        hand  2022-11-25             3.0
# 2        RootApplication        hand  2022-12-12           480.0
# 3           Broadcasting        hand  2022-12-02           240.0
# 4           Broadcasting     machine  2022-11-30             0.0
# 5           Broadcasting        hand  2022-10-24           600.0
# 6           Broadcasting        hand  2022-11-04           130.0
# 7           Broadcasting     machine  2022-12-05             0.0
# 8           Broadcasting        hand  2022-11-07           130.0
# 9           Broadcasting        hand  2022-10-29            80.0
#
#    Harv_hand_rent_per_Acre Threshing_date Threshing_method  Residue_length  \
# 0                      NaN     2022-11-16          machine              30
# 1                 9.600000     2022-12-24          machine              24
# 2              3240.000000     2023-01-11          machine              30
# 3              1080.000000     2022-12-29             hand              26
# 4                      NaN     2022-12-02          machine              24
# 5              4400.000000     2022-11-04             hand              30
# 6               953.333333     2022-12-08          machine              25
# 7                      NaN     2022-12-06             hand              25
# 8               572.000000     2022-12-15          machine              26
# 9               512.000000     2022-11-14             hand              22
#
#    Residue_perc     Stubble_use      Acre  Yield  Yield_per_Acre  \
# 0            40  plowed_in_soil  0.312500  600.0     1920.000000
# 1            10  plowed_in_soil  0.312500  600.0     1920.000000
# 2            10  plowed_in_soil  0.148148  225.0     1518.750000
# 3            10  plowed_in_soil  0.222222  468.0     2106.000000
# 4            40  plowed_in_soil  0.468750  550.0     1173.333333
# 5            10  plowed_in_soil  0.136364  205.0     1503.333333
# 6            10  plowed_in_soil  0.136364  270.0     1980.000000
# 7            40  plowed_in_soil  0.250000  490.0     1960.000000
# 8            10  plowed_in_soil  0.227273  425.0     1870.000000
# 9            10  plowed_in_soil  0.156250  300.0     1920.000000
#
#    LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 0                          True                                   True
# 1                          True                                   True
# 2                          True                                   True
# 3                          True                                   True
# 4                          True                                  False
# 5                          True                                  False
# 6                          True                                  False
# 7                         False                                   True
# 8                          True                                  False
# 9                         False                                  False
#
#    LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 0                              False                         False
# 1                               True                         False
# 2                              False                         False
# 3                              False                         False
# 4                               True                         False
# 5                              False                         False
# 6                              False                         False
# 7                              False                         False
# 8                              False                         False
# 9                               True                         False
#
#    LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 0                 False                        True
# 1                 False                        True
# 2                 False                       False
# 3                 False                        True
# 4                 False                        True
# 5                 False                        True
# 6                 False                        True
# 7                 False                       False
# 8                 False                        True
# 9                 False                        True
#
#    NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 0                            False                                  True
# 1                             True                                  True
# 2                             True                                  True
# 3                             True                                  True
# 4                            False                                  True
# 5                            False                                 False
# 6                            False                                 False
# 7                            False                                 False
# 8                            False                                 False
# 9                            False                                  True
#
#    NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 0                             False                            True
# 1                              True                            True
# 2                              True                           False
# 3                              True                            True
# 4                             False                            True
# 5                             False                            True
# 6                             False                            True
# 7                             False                           False
# 8                             False                            True
# 9                             False                            True
#
#    TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 0                              False                         True
# 1                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
# 5                              False                         True
# 6                              False                         True
# 7                              False                        False
# 8                              False                         True
# 9                              False                         True
#
#    TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                        True                                   True
# 4                        True                                   True
# 5                        True                                   True
# 6                        True                                   True
# 7                       False                                  False
# 8                        True                                   True
# 9                        True                                   True
#
#    TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 0                        True                 True               False
# 1                        True                 True                True
# 2                        True                False                True
# 3                        True                 True                True
# 4                        True                 True                True
# 5                        True                False                True
# 6                        True                False                True
# 7                       False                 True                True
# 8                        True                False                True
# 9                        True                 True               False
#
#    CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
# 5                  True               False               False
# 6                 False               False               False
# 7                 False               False               False
# 8                 False               False               False
# 9                 False               False               False
#
#    CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
# 5                False               False                False
# 6                False               False                False
# 7                False               False                False
# 8                False               False                False
# 9                False               False                False
#
#    FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
# 5                    True                  False                  False
# 6                    True                  False                  False
# 7                    True                  False                  False
# 8                    True                  False                  False
# 9                    True                  False                  False
#
#    FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 0                   False                  False                    False
# 1                   False                  False                    False
# 2                   False                  False                    False
# 3                   False                  False                    False
# 4                   False                  False                    False
# 5                   False                  False                    False
# 6                   False                  False                    False
# 7                   False                  False                    False
# 8                   False                  False                    False
# 9                   False                  False                    False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
# 5                   False                True                        False
# 6                    True               False                        False
# 7                   False               False                        False
# 8                   False                True                        False
# 9                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
# 5                     False                          False
# 6                     False                          False
# 7                     False                          False
# 8                     False                          False
# 9                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN k2label  \
# 0                     False                         False          7       A
# 1                     False                         False          5       A
# 2                     False                         False          3       A
# 3                     False                         False          9       A
# 4                     False                         False          6       A
# 5                     False                         False          6       A
# 6                     False                         False          5       A
# 7                     False                         False         12       A
# 8                     False                         False          5       A
# 9                     False                         False          6       A
#
#   k3label k4label k5label
# 0       A       A       B
# 1       A       A       B
# 2       A       A       A
# 3       A       A       A
# 4       A       A       B
# 5       A       A       A
# 6       A       A       A
# 7       A       A       B
# 8       A       A       A
# 9       A       A       B

# %%
# Drop the columns ID and Set
# Makes it muddled I just want to see the actual ditricts

df_no_id = df.drop(['ID', 'Set'], axis=1)

# %%
df_no_id.head()
# Out:
#   District      Block CropTillageDate  CropTillageDepth         CropEstMethod  \
# 0  Nalanda  Noorsarai      2022-07-20                 5  Manual_PuddledRandom
# 1  Nalanda     Rajgir      2022-07-18                 5  Manual_PuddledRandom
# 2     Gaya      Gurua      2022-06-30                 6  Manual_PuddledRandom
# 3     Gaya      Gurua      2022-06-16                 6  Manual_PuddledRandom
# 4  Nalanda  Noorsarai      2022-07-19                 4  Manual_PuddledRandom
#
#   RcNursEstDate SeedingSowingTransplanting  SeedlingsPerPit  \
# 0    2022-06-27                 2022-07-21              2.0
# 1    2022-06-20                 2022-07-20              2.0
# 2    2022-06-20                 2022-08-13              2.0
# 3    2022-06-17                 2022-07-17              2.0
# 4    2022-06-21                 2022-07-20              2.0
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# 1                           5.0                        Boring
# 2                           4.0                        Boring
# 3                           NaN                           NaN
# 4                           9.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  TransIrriCost_per_Acre  \
# 0                           Electric          200.0                   640.0
# 1                           Electric          125.0                   400.0
# 2                           Electric           80.0                   540.0
# 3                                NaN            NaN                     NaN
# 4                           Electric          300.0                   640.0
#
#    StandingWater  Ganaura  Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 0            2.0      0.0               NaN         0.0                  NaN
# 1            3.0      0.0               NaN         0.0                  NaN
# 2            2.0      1.0              6.75         1.0                 6.75
# 3            NaN      1.0              4.50         0.0                  NaN
# 4            2.0      0.0               NaN         0.0                  NaN
#
#   PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  BasalDAP_per_Acre  \
# 0                        NaN                  2       0.0                NaN
# 1                        NaN                  2      15.0               48.0
# 2                SoilApplied                  2       4.0               27.0
# 3                SoilApplied                  2       6.0               27.0
# 4                        NaN                  2      15.0               32.0
#
#    BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  1tdUrea  \
# 0       20.0                64.0         Broadcasting     15.0
# 1       10.0                32.0         Broadcasting     20.0
# 2        0.0                 NaN          SoilApplied      5.0
# 3        3.0                13.5         Broadcasting      5.0
# 4       30.0                64.0         Broadcasting     30.0
#
#    1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  2appDaysUrea  \
# 0             48.00          18.0      0.0               NaN           NaN
# 1             64.00          39.0      0.0               NaN           NaN
# 2             33.75          65.0      0.0               NaN           NaN
# 3             22.50           5.0      0.0               NaN           NaN
# 4             64.00          26.0      0.0               NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting     machine  2022-11-16             0.0
# 1           Broadcasting        hand  2022-11-25             3.0
# 2        RootApplication        hand  2022-12-12           480.0
# 3           Broadcasting        hand  2022-12-02           240.0
# 4           Broadcasting     machine  2022-11-30             0.0
#
#    Harv_hand_rent_per_Acre Threshing_date Threshing_method  Residue_length  \
# 0                      NaN     2022-11-16          machine              30
# 1                      9.6     2022-12-24          machine              24
# 2                   3240.0     2023-01-11          machine              30
# 3                   1080.0     2022-12-29             hand              26
# 4                      NaN     2022-12-02          machine              24
#
#    Residue_perc     Stubble_use      Acre  Yield  Yield_per_Acre  \
# 0            40  plowed_in_soil  0.312500  600.0     1920.000000
# 1            10  plowed_in_soil  0.312500  600.0     1920.000000
# 2            10  plowed_in_soil  0.148148  225.0     1518.750000
# 3            10  plowed_in_soil  0.222222  468.0     2106.000000
# 4            40  plowed_in_soil  0.468750  550.0     1173.333333
#
#    LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 0                          True                                   True
# 1                          True                                   True
# 2                          True                                   True
# 3                          True                                   True
# 4                          True                                  False
#
#    LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 0                              False                         False
# 1                               True                         False
# 2                              False                         False
# 3                              False                         False
# 4                               True                         False
#
#    LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 0                 False                        True
# 1                 False                        True
# 2                 False                       False
# 3                 False                        True
# 4                 False                        True
#
#    NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 0                            False                                  True
# 1                             True                                  True
# 2                             True                                  True
# 3                             True                                  True
# 4                            False                                  True
#
#    NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 0                             False                            True
# 1                              True                            True
# 2                              True                           False
# 3                              True                            True
# 4                             False                            True
#
#    TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 0                              False                         True
# 1                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
#
#    TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                        True                                   True
# 4                        True                                   True
#
#    TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 0                        True                 True               False
# 1                        True                 True                True
# 2                        True                False                True
# 3                        True                 True                True
# 4                        True                 True                True
#
#    CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
#
#    FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 0                   False                  False                    False
# 1                   False                  False                    False
# 2                   False                  False                    False
# 3                   False                  False                    False
# 4                   False                  False                    False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN k2label  \
# 0                     False                         False          7       A
# 1                     False                         False          5       A
# 2                     False                         False          3       A
# 3                     False                         False          9       A
# 4                     False                         False          6       A
#
#   k3label k4label k5label
# 0       A       A       B
# 1       A       A       B
# 2       A       A       A
# 3       A       A       A
# 4       A       A       B

# %% [markdown]
# ### Identify the different labels of K clustering and split them up into seperate dataframes so I can analyse them individually

# %%
print(df_no_id['k3label'].value_counts())
# Out:
# k3label
# A    3907
# B    1004
# C     249
# Name: count, dtype: int64

# %% [markdown]
# ### Diagrams from Jullietes Code

# %%
fig = px.box(df_no_id, x="CropTillageDepth", color="k3label", width=600, height=400)
fig.show()

fig = px.box(df_no_id, x="SeedlingsPerPit", color="k3label", width=600, height=400)
fig.show()

fig = px.histogram(df_no_id, x="TransplantingIrrigationSource", color="k3label", width=600, height=400)
fig.show()

#fig = px.histogram(df2, x="OrgFertilizers", color="k3label", width=600, height=400)
#fig.show()

fig = px.box(df_no_id, x="CropOrgFYM_per_Acre", color="k3label", width=600, height=400)
fig.show()

fig = px.histogram(df_no_id, x="Harv_method", facet_col="k3label", width=600, height=400)
fig.show()

fig = px.histogram(df_no_id, x="Threshing_method", facet_col="k3label", width=600, height=400)
fig.show()

fig = px.histogram(df_no_id, x="District", facet_col="k3label", width=800, height=400)
fig.show()

fig = px.histogram(df_no_id, x="Block", facet_col="k3label", width=900, height=400)
fig.show()

fig = px.box(df_no_id, x="Yield_per_Acre", color="k3label", width=900, height=400)
fig.show()

fig = px.box(df_no_id, x="Yield_per_Acre", color="k2label", width=900, height=400)
fig.show()

# %% [markdown]
# ## Attempt to figure out the factors that are primarily responsible for the clustering

# %%
df_no_id.dtypes.value_counts()
# Out:
# bool       36
# float64    24
# object     20
# int64       5
# Name: count, dtype: int64

# %%
# List all the object type columns 
obj_cols = df_no_id.select_dtypes(include=['object']).columns.tolist()
obj_cols
# Out:
# ['District',
#  'Block',
#  'CropTillageDate',
#  'CropEstMethod',
#  'RcNursEstDate',
#  'SeedingSowingTransplanting',
#  'TransplantingIrrigationSource',
#  'TransplantingIrrigationPowerSource',
#  'PCropSolidOrgFertAppMethod',
#  'MineralFertAppMethod',
#  'MineralFertAppMethod.1',
#  'Harv_method',
#  'Harv_date',
#  'Threshing_date',
#  'Threshing_method',
#  'Stubble_use',
#  'k2label',
#  'k3label',
#  'k4label',
#  'k5label']

# %% [markdown]
# *I'm going to leave this out for now, but I will definently return to the object types*

# %%
# List all the bool type columns 
bool_cols = df_no_id.select_dtypes(include=['bool']).columns.tolist()
bool_cols
# Out:
# ['LandPrepMethod_TractorPlough',
#  'LandPrepMethod_FourWheelTracRotavator',
#  'LandPrepMethod_WetTillagePuddling',
#  'LandPrepMethod_BullockPlough',
#  'LandPrepMethod_Other',
#  'NursDetFactor_CalendarDate',
#  'NursDetFactor_PreMonsoonShowers',
#  'NursDetFactor_IrrigWaterAvailability',
#  'NursDetFactor_LabourAvailability',
#  'NursDetFactor_SeedAvailability',
#  'TransDetFactor_LabourAvailability',
#  'TransDetFactor_CalendarDate',
#  'TransDetFactor_RainArrival',
#  'TransDetFactor_IrrigWaterAvailability',
#  'TransDetFactor_SeedlingAge',
#  'CropbasalFerts_Urea',
#  'CropbasalFerts_DAP',
#  'CropbasalFerts_Other',
#  'CropbasalFerts_NPK',
#  'CropbasalFerts_MoP',
#  'CropbasalFerts_NPKS',
#  'CropbasalFerts_SSP',
#  'CropbasalFerts_None',
#  'FirstTopDressFert_Urea',
#  'FirstTopDressFert_DAP',
#  'FirstTopDressFert_NPK',
#  'FirstTopDressFert_NPKS',
#  'FirstTopDressFert_SSP',
#  'FirstTopDressFert_Other',
#  'OrgFertilizers_Ganaura',
#  'OrgFertilizers_FYM',
#  'OrgFertilizers_VermiCompost',
#  'OrgFertilizers_Pranamrit',
#  'OrgFertilizers_Ghanajeevamrit',
#  'OrgFertilizers_Jeevamrit',
#  'OrgFertilizers_PoultryManure']

# %%
# List all the float and int type columns 

float_cols = df_no_id.select_dtypes(include=['float64', 'int64']).columns.tolist()
float_cols
# Out:
# ['CropTillageDepth',
#  'SeedlingsPerPit',
#  'TransplantingIrrigationHours',
#  'TransIrriCost',
#  'TransIrriCost_per_Acre',
#  'StandingWater',
#  'Ganaura',
#  'Ganaura_per_Acre',
#  'CropOrgFYM',
#  'CropOrgFYM_per_Acre',
#  'NoFertilizerAppln',
#  'BasalDAP',
#  'BasalDAP_per_Acre',
#  'BasalUrea',
#  'BasalUrea_per_Acre',
#  '1tdUrea',
#  '1tdUrea_per_Acre',
#  '1appDaysUrea',
#  '2tdUrea',
#  '2tdUrea_per_Acre',
#  '2appDaysUrea',
#  'Harv_hand_rent',
#  'Harv_hand_rent_per_Acre',
#  'Residue_length',
#  'Residue_perc',
#  'Acre',
#  'Yield',
#  'Yield_per_Acre',
#  'Nb_of_NaN']

# %%
kmeans_mean_numerical = df_no_id.groupby('k3label')[float_cols].mean()

# %%
for column in bool_cols:
    df_no_id[column] = df_no_id[column].astype(int)

# %%
kmeans_means_boolen = df_no_id.groupby('k3label')[bool_cols].mean()

# %%
kmeans_mean_numerical
# Out:
#          CropTillageDepth  SeedlingsPerPit  TransplantingIrrigationHours  \
# k3label
# A                4.652675         1.937216                      8.143680
# B                3.900398         4.546000                      8.018109
# C                4.000000         3.995968                      7.799197
#
#          TransIrriCost  TransIrriCost_per_Acre  StandingWater    Ganaura  \
# k3label
# A           327.047783             1439.001094       3.197074   3.862298
# B           483.415744             1900.659929       3.483573  41.127490
# C           771.163180             2213.727755       3.154472   3.305221
#
#          Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  NoFertilizerAppln  \
# k3label
# A               59.908211   25.837983            94.336095           2.305349
# B              430.818089    0.141434             7.824561           1.573705
# C               11.567399    0.016064            11.000000           2.899598
#
#           BasalDAP  BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre  \
# k3label
# A        10.595598          42.984777   6.488098           43.774905
# B         9.669323          47.236538  13.000996           52.144910
# C         0.000000                NaN   0.000000                 NaN
#
#            1tdUrea  1tdUrea_per_Acre  1appDaysUrea   2tdUrea  \
# k3label
# A        11.713847         45.300832     30.426132  2.937292
# B         5.113546         41.882657     18.436475  0.018924
# C         2.100402          6.608112     27.771084  1.164659
#
#          2tdUrea_per_Acre  2appDaysUrea  Harv_hand_rent  \
# k3label
# A               36.572582     58.731509      564.053494
# B               41.800000     37.500000      465.620518
# C                3.893658     59.491071       89.518072
#
#          Harv_hand_rent_per_Acre  Residue_length  Residue_perc      Acre  \
# k3label
# A                    2419.838648       26.473253     12.157666  0.294597
# B                    1742.394352       25.920319     10.418327  0.280413
# C                     288.154188       28.811245     10.000000  0.351771
#
#               Yield  Yield_per_Acre  Nb_of_NaN
# k3label
# A        585.688033     1943.383560   4.897108
# B        629.620053     2135.675323   6.134462
# C        585.178771     1652.861639   3.678715

# %%
kmeans_means_boolen
# Out:
#          LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# k3label
# A                            0.882519                               0.729204
# B                            0.987052                               0.046813
# C                            1.000000                               0.004016
#
#          LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# k3label
# A                                 0.394420                      0.038649
# B                                 0.373506                      0.350598
# C                                 0.000000                      1.000000
#
#          LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# k3label
# A                    0.004607                    0.627336
# B                    0.002988                    0.521912
# C                    0.000000                    0.995984
#
#          NursDetFactor_PreMonsoonShowers  \
# k3label
# A                               0.386998
# B                               0.347610
# C                               0.000000
#
#          NursDetFactor_IrrigWaterAvailability  \
# k3label
# A                                    0.711287
# B                                    0.597610
# C                                    0.939759
#
#          NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# k3label
# A                                0.466087                        0.561812
# B                                0.122510                        0.313745
# C                                0.000000                        0.000000
#
#          TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# k3label
# A                                      0.0                     0.635526
# B                                      0.0                     0.488048
# C                                      0.0                     0.987952
#
#          TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# k3label
# A                          0.610187                               0.802918
# B                          0.564741                               0.375498
# C                          0.204819                               0.000000
#
#          TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# k3label
# A                          0.722293             0.495009            0.914768
# B                          0.561753             0.986056            0.848606
# C                          0.791165             0.000000            0.000000
#
#          CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# k3label
# A                    0.024571            0.027131            0.001024
# B                    0.000000            0.001992            0.000996
# C                    0.000000            0.000000            0.000000
#
#          CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# k3label
# A                   0.014589            0.024059             0.003839
# B                   0.000996            0.000996             0.000000
# C                   0.000000            0.000000             1.000000
#
#          FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# k3label
# A                      0.944203               0.106732               0.008446
# B                      0.487052               0.103586               0.000000
# C                      1.000000               0.987952               0.000000
#
#          FirstTopDressFert_NPKS  FirstTopDressFert_SSP  \
# k3label
# A                      0.006399               0.001024
# B                      0.000000               0.000000
# C                      0.000000               0.000000
#
#          FirstTopDressFert_Other  OrgFertilizers_Ganaura  OrgFertilizers_FYM  \
# k3label
# A                       0.000256                0.333504            0.394676
# B                       0.000000                0.456175            0.076693
# C                       0.008032                0.811245            0.004016
#
#          OrgFertilizers_VermiCompost  OrgFertilizers_Pranamrit  \
# k3label
# A                           0.018684                  0.001792
# B                           0.000000                  0.000000
# C                           0.000000                  0.000000
#
#          OrgFertilizers_Ghanajeevamrit  OrgFertilizers_Jeevamrit  \
# k3label
# A                             0.018684                  0.000768
# B                             0.000000                  0.000000
# C                             0.000000                  0.000000
#
#          OrgFertilizers_PoultryManure
# k3label
# A                            0.001536
# B                            0.000996
# C                            0.000000

# %%
# Combine the two dataframes

kmeans_means = pd.concat([kmeans_mean_numerical, kmeans_means_boolen], axis=1)

kmeans_means
# Out:
#          CropTillageDepth  SeedlingsPerPit  TransplantingIrrigationHours  \
# k3label
# A                4.652675         1.937216                      8.143680
# B                3.900398         4.546000                      8.018109
# C                4.000000         3.995968                      7.799197
#
#          TransIrriCost  TransIrriCost_per_Acre  StandingWater    Ganaura  \
# k3label
# A           327.047783             1439.001094       3.197074   3.862298
# B           483.415744             1900.659929       3.483573  41.127490
# C           771.163180             2213.727755       3.154472   3.305221
#
#          Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  NoFertilizerAppln  \
# k3label
# A               59.908211   25.837983            94.336095           2.305349
# B              430.818089    0.141434             7.824561           1.573705
# C               11.567399    0.016064            11.000000           2.899598
#
#           BasalDAP  BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre  \
# k3label
# A        10.595598          42.984777   6.488098           43.774905
# B         9.669323          47.236538  13.000996           52.144910
# C         0.000000                NaN   0.000000                 NaN
#
#            1tdUrea  1tdUrea_per_Acre  1appDaysUrea   2tdUrea  \
# k3label
# A        11.713847         45.300832     30.426132  2.937292
# B         5.113546         41.882657     18.436475  0.018924
# C         2.100402          6.608112     27.771084  1.164659
#
#          2tdUrea_per_Acre  2appDaysUrea  Harv_hand_rent  \
# k3label
# A               36.572582     58.731509      564.053494
# B               41.800000     37.500000      465.620518
# C                3.893658     59.491071       89.518072
#
#          Harv_hand_rent_per_Acre  Residue_length  Residue_perc      Acre  \
# k3label
# A                    2419.838648       26.473253     12.157666  0.294597
# B                    1742.394352       25.920319     10.418327  0.280413
# C                     288.154188       28.811245     10.000000  0.351771
#
#               Yield  Yield_per_Acre  Nb_of_NaN  LandPrepMethod_TractorPlough  \
# k3label
# A        585.688033     1943.383560   4.897108                      0.882519
# B        629.620053     2135.675323   6.134462                      0.987052
# C        585.178771     1652.861639   3.678715                      1.000000
#
#          LandPrepMethod_FourWheelTracRotavator  \
# k3label
# A                                     0.729204
# B                                     0.046813
# C                                     0.004016
#
#          LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# k3label
# A                                 0.394420                      0.038649
# B                                 0.373506                      0.350598
# C                                 0.000000                      1.000000
#
#          LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# k3label
# A                    0.004607                    0.627336
# B                    0.002988                    0.521912
# C                    0.000000                    0.995984
#
#          NursDetFactor_PreMonsoonShowers  \
# k3label
# A                               0.386998
# B                               0.347610
# C                               0.000000
#
#          NursDetFactor_IrrigWaterAvailability  \
# k3label
# A                                    0.711287
# B                                    0.597610
# C                                    0.939759
#
#          NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# k3label
# A                                0.466087                        0.561812
# B                                0.122510                        0.313745
# C                                0.000000                        0.000000
#
#          TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# k3label
# A                                      0.0                     0.635526
# B                                      0.0                     0.488048
# C                                      0.0                     0.987952
#
#          TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# k3label
# A                          0.610187                               0.802918
# B                          0.564741                               0.375498
# C                          0.204819                               0.000000
#
#          TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# k3label
# A                          0.722293             0.495009            0.914768
# B                          0.561753             0.986056            0.848606
# C                          0.791165             0.000000            0.000000
#
#          CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# k3label
# A                    0.024571            0.027131            0.001024
# B                    0.000000            0.001992            0.000996
# C                    0.000000            0.000000            0.000000
#
#          CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# k3label
# A                   0.014589            0.024059             0.003839
# B                   0.000996            0.000996             0.000000
# C                   0.000000            0.000000             1.000000
#
#          FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# k3label
# A                      0.944203               0.106732               0.008446
# B                      0.487052               0.103586               0.000000
# C                      1.000000               0.987952               0.000000
#
#          FirstTopDressFert_NPKS  FirstTopDressFert_SSP  \
# k3label
# A                      0.006399               0.001024
# B                      0.000000               0.000000
# C                      0.000000               0.000000
#
#          FirstTopDressFert_Other  OrgFertilizers_Ganaura  OrgFertilizers_FYM  \
# k3label
# A                       0.000256                0.333504            0.394676
# B                       0.000000                0.456175            0.076693
# C                       0.008032                0.811245            0.004016
#
#          OrgFertilizers_VermiCompost  OrgFertilizers_Pranamrit  \
# k3label
# A                           0.018684                  0.001792
# B                           0.000000                  0.000000
# C                           0.000000                  0.000000
#
#          OrgFertilizers_Ghanajeevamrit  OrgFertilizers_Jeevamrit  \
# k3label
# A                             0.018684                  0.000768
# B                             0.000000                  0.000000
# C                             0.000000                  0.000000
#
#          OrgFertilizers_PoultryManure
# k3label
# A                            0.001536
# B                            0.000996
# C                            0.000000

# %%
kmeans_means.head()
# Out:
#          CropTillageDepth  SeedlingsPerPit  TransplantingIrrigationHours  \
# k3label
# A                4.652675         1.937216                      8.143680
# B                3.900398         4.546000                      8.018109
# C                4.000000         3.995968                      7.799197
#
#          TransIrriCost  TransIrriCost_per_Acre  StandingWater    Ganaura  \
# k3label
# A           327.047783             1439.001094       3.197074   3.862298
# B           483.415744             1900.659929       3.483573  41.127490
# C           771.163180             2213.727755       3.154472   3.305221
#
#          Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  NoFertilizerAppln  \
# k3label
# A               59.908211   25.837983            94.336095           2.305349
# B              430.818089    0.141434             7.824561           1.573705
# C               11.567399    0.016064            11.000000           2.899598
#
#           BasalDAP  BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre  \
# k3label
# A        10.595598          42.984777   6.488098           43.774905
# B         9.669323          47.236538  13.000996           52.144910
# C         0.000000                NaN   0.000000                 NaN
#
#            1tdUrea  1tdUrea_per_Acre  1appDaysUrea   2tdUrea  \
# k3label
# A        11.713847         45.300832     30.426132  2.937292
# B         5.113546         41.882657     18.436475  0.018924
# C         2.100402          6.608112     27.771084  1.164659
#
#          2tdUrea_per_Acre  2appDaysUrea  Harv_hand_rent  \
# k3label
# A               36.572582     58.731509      564.053494
# B               41.800000     37.500000      465.620518
# C                3.893658     59.491071       89.518072
#
#          Harv_hand_rent_per_Acre  Residue_length  Residue_perc      Acre  \
# k3label
# A                    2419.838648       26.473253     12.157666  0.294597
# B                    1742.394352       25.920319     10.418327  0.280413
# C                     288.154188       28.811245     10.000000  0.351771
#
#               Yield  Yield_per_Acre  Nb_of_NaN  LandPrepMethod_TractorPlough  \
# k3label
# A        585.688033     1943.383560   4.897108                      0.882519
# B        629.620053     2135.675323   6.134462                      0.987052
# C        585.178771     1652.861639   3.678715                      1.000000
#
#          LandPrepMethod_FourWheelTracRotavator  \
# k3label
# A                                     0.729204
# B                                     0.046813
# C                                     0.004016
#
#          LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# k3label
# A                                 0.394420                      0.038649
# B                                 0.373506                      0.350598
# C                                 0.000000                      1.000000
#
#          LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# k3label
# A                    0.004607                    0.627336
# B                    0.002988                    0.521912
# C                    0.000000                    0.995984
#
#          NursDetFactor_PreMonsoonShowers  \
# k3label
# A                               0.386998
# B                               0.347610
# C                               0.000000
#
#          NursDetFactor_IrrigWaterAvailability  \
# k3label
# A                                    0.711287
# B                                    0.597610
# C                                    0.939759
#
#          NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# k3label
# A                                0.466087                        0.561812
# B                                0.122510                        0.313745
# C                                0.000000                        0.000000
#
#          TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# k3label
# A                                      0.0                     0.635526
# B                                      0.0                     0.488048
# C                                      0.0                     0.987952
#
#          TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# k3label
# A                          0.610187                               0.802918
# B                          0.564741                               0.375498
# C                          0.204819                               0.000000
#
#          TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# k3label
# A                          0.722293             0.495009            0.914768
# B                          0.561753             0.986056            0.848606
# C                          0.791165             0.000000            0.000000
#
#          CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# k3label
# A                    0.024571            0.027131            0.001024
# B                    0.000000            0.001992            0.000996
# C                    0.000000            0.000000            0.000000
#
#          CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# k3label
# A                   0.014589            0.024059             0.003839
# B                   0.000996            0.000996             0.000000
# C                   0.000000            0.000000             1.000000
#
#          FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# k3label
# A                      0.944203               0.106732               0.008446
# B                      0.487052               0.103586               0.000000
# C                      1.000000               0.987952               0.000000
#
#          FirstTopDressFert_NPKS  FirstTopDressFert_SSP  \
# k3label
# A                      0.006399               0.001024
# B                      0.000000               0.000000
# C                      0.000000               0.000000
#
#          FirstTopDressFert_Other  OrgFertilizers_Ganaura  OrgFertilizers_FYM  \
# k3label
# A                       0.000256                0.333504            0.394676
# B                       0.000000                0.456175            0.076693
# C                       0.008032                0.811245            0.004016
#
#          OrgFertilizers_VermiCompost  OrgFertilizers_Pranamrit  \
# k3label
# A                           0.018684                  0.001792
# B                           0.000000                  0.000000
# C                           0.000000                  0.000000
#
#          OrgFertilizers_Ghanajeevamrit  OrgFertilizers_Jeevamrit  \
# k3label
# A                             0.018684                  0.000768
# B                             0.000000                  0.000000
# C                             0.000000                  0.000000
#
#          OrgFertilizers_PoultryManure
# k3label
# A                            0.001536
# B                            0.000996
# C                            0.000000

# %%
# I will be using a descion tree / tree based methods so for all intent and purposes I will NOT be scaling the data
# I might try scaling it later and seeing what it does but for now I will not be scaling the data

nan_cols = [i for i in kmeans_means.columns if kmeans_means[i].isnull().any()]

# %%
nan_cols
# Out:
# ['BasalDAP_per_Acre', 'BasalUrea_per_Acre']

# %%
# Remove the nan columns - FOR NOW
kmeans_means = kmeans_means.drop(nan_cols, axis=1)

# %%
X = kmeans_means
y = kmeans_means.index

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=2, random_state=123)

# %%
clf.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=2, random_state=123)

# %%
feature_importances = pd.DataFrame(clf.feature_importances_, index=X.columns)

# %%
feature_importances
# Out:
#                                       0
# CropTillageDepth               0.010526
# SeedlingsPerPit                0.057895
# TransplantingIrrigationHours   0.021053
# TransIrriCost                  0.005263
# TransIrriCost_per_Acre         0.010526
# ...                                 ...
# OrgFertilizers_VermiCompost    0.015789
# OrgFertilizers_Pranamrit       0.015789
# OrgFertilizers_Ghanajeevamrit  0.010526
# OrgFertilizers_Jeevamrit       0.000000
# OrgFertilizers_PoultryManure   0.000000
#
# [63 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create the bar chart
plt.figure(figsize=(10,6))
sns.barplot(x=feature_importances.index, y=feature_importances[0])

# add labels and title
plt.xlabel("Features", labelpad=20, weight='bold', size=12)
plt.ylabel("Importance", labelpad=20, weight='bold', size=12)
plt.title("Feature Importances by Random Forest Classifier", weight='bold', size=16)

# rotate x-axis labels
plt.xticks(rotation=90)

# show the plot
plt.show()

# %%
# sort the feature_importances dataframe by importance score
sorted_importances = feature_importances.sort_values(by=0, ascending=False)

# select the top 5 features
top_5 = sorted_importances[:8]

# create the bar chart
plt.figure(figsize=(10,6))
sns.barplot(x=top_5.index, y=top_5[0])

# add labels and title
plt.xlabel("Features", labelpad=20, weight='bold', size=12)
plt.ylabel("Importance", labelpad=20, weight='bold', size=12)
plt.title("Top 5 Feature Importances by Random Forest Classifier for kmeans3 A/B/C", weight='bold', size=16)

# rotate x-axis labels
plt.xticks(rotation=90)

# show the plot
plt.show()

# %% [markdown]
# ## Random Stuff Shaw is doing

# %%
df_dict = dict(tuple(df_no_id.groupby('k3label')))
df_A = df_dict['A']
df_B = df_dict['B']
df_C = df_dict['C']

# %%
df_A.head()
# Out:
#   District      Block CropTillageDate  CropTillageDepth         CropEstMethod  \
# 0  Nalanda  Noorsarai      2022-07-20                 5  Manual_PuddledRandom
# 1  Nalanda     Rajgir      2022-07-18                 5  Manual_PuddledRandom
# 2     Gaya      Gurua      2022-06-30                 6  Manual_PuddledRandom
# 3     Gaya      Gurua      2022-06-16                 6  Manual_PuddledRandom
# 4  Nalanda  Noorsarai      2022-07-19                 4  Manual_PuddledRandom
#
#   RcNursEstDate SeedingSowingTransplanting  SeedlingsPerPit  \
# 0    2022-06-27                 2022-07-21              2.0
# 1    2022-06-20                 2022-07-20              2.0
# 2    2022-06-20                 2022-08-13              2.0
# 3    2022-06-17                 2022-07-17              2.0
# 4    2022-06-21                 2022-07-20              2.0
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# 1                           5.0                        Boring
# 2                           4.0                        Boring
# 3                           NaN                           NaN
# 4                           9.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  TransIrriCost_per_Acre  \
# 0                           Electric          200.0                   640.0
# 1                           Electric          125.0                   400.0
# 2                           Electric           80.0                   540.0
# 3                                NaN            NaN                     NaN
# 4                           Electric          300.0                   640.0
#
#    StandingWater  Ganaura  Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 0            2.0      0.0               NaN         0.0                  NaN
# 1            3.0      0.0               NaN         0.0                  NaN
# 2            2.0      1.0              6.75         1.0                 6.75
# 3            NaN      1.0              4.50         0.0                  NaN
# 4            2.0      0.0               NaN         0.0                  NaN
#
#   PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  BasalDAP_per_Acre  \
# 0                        NaN                  2       0.0                NaN
# 1                        NaN                  2      15.0               48.0
# 2                SoilApplied                  2       4.0               27.0
# 3                SoilApplied                  2       6.0               27.0
# 4                        NaN                  2      15.0               32.0
#
#    BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  1tdUrea  \
# 0       20.0                64.0         Broadcasting     15.0
# 1       10.0                32.0         Broadcasting     20.0
# 2        0.0                 NaN          SoilApplied      5.0
# 3        3.0                13.5         Broadcasting      5.0
# 4       30.0                64.0         Broadcasting     30.0
#
#    1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  2appDaysUrea  \
# 0             48.00          18.0      0.0               NaN           NaN
# 1             64.00          39.0      0.0               NaN           NaN
# 2             33.75          65.0      0.0               NaN           NaN
# 3             22.50           5.0      0.0               NaN           NaN
# 4             64.00          26.0      0.0               NaN           NaN
#
#   MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 0           Broadcasting     machine  2022-11-16             0.0
# 1           Broadcasting        hand  2022-11-25             3.0
# 2        RootApplication        hand  2022-12-12           480.0
# 3           Broadcasting        hand  2022-12-02           240.0
# 4           Broadcasting     machine  2022-11-30             0.0
#
#    Harv_hand_rent_per_Acre Threshing_date Threshing_method  Residue_length  \
# 0                      NaN     2022-11-16          machine              30
# 1                      9.6     2022-12-24          machine              24
# 2                   3240.0     2023-01-11          machine              30
# 3                   1080.0     2022-12-29             hand              26
# 4                      NaN     2022-12-02          machine              24
#
#    Residue_perc     Stubble_use      Acre  Yield  Yield_per_Acre  \
# 0            40  plowed_in_soil  0.312500  600.0     1920.000000
# 1            10  plowed_in_soil  0.312500  600.0     1920.000000
# 2            10  plowed_in_soil  0.148148  225.0     1518.750000
# 3            10  plowed_in_soil  0.222222  468.0     2106.000000
# 4            40  plowed_in_soil  0.468750  550.0     1173.333333
#
#    LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 0                          True                                   True
# 1                          True                                   True
# 2                          True                                   True
# 3                          True                                   True
# 4                          True                                  False
#
#    LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 0                              False                         False
# 1                               True                         False
# 2                              False                         False
# 3                              False                         False
# 4                               True                         False
#
#    LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 0                 False                        True
# 1                 False                        True
# 2                 False                       False
# 3                 False                        True
# 4                 False                        True
#
#    NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 0                            False                                  True
# 1                             True                                  True
# 2                             True                                  True
# 3                             True                                  True
# 4                            False                                  True
#
#    NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 0                             False                            True
# 1                              True                            True
# 2                              True                           False
# 3                              True                            True
# 4                             False                            True
#
#    TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 0                              False                         True
# 1                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
#
#    TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                        True                                   True
# 4                        True                                   True
#
#    TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 0                        True                 True               False
# 1                        True                 True                True
# 2                        True                False                True
# 3                        True                 True                True
# 4                        True                 True                True
#
#    CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
#
#    FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 0                   False                  False                    False
# 1                   False                  False                    False
# 2                   False                  False                    False
# 3                   False                  False                    False
# 4                   False                  False                    False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN k2label  \
# 0                     False                         False          7       A
# 1                     False                         False          5       A
# 2                     False                         False          3       A
# 3                     False                         False          9       A
# 4                     False                         False          6       A
#
#   k3label k4label k5label
# 0       A       A       B
# 1       A       A       B
# 2       A       A       A
# 3       A       A       A
# 4       A       A       B

# %%
df_B.head()
# Out:
#    District      Block CropTillageDate  CropTillageDepth  \
# 21  Nalanda  Noorsarai      2022-07-16                 5
# 27    Jamui      Jamui      2022-06-25                 4
# 28    Jamui      Jamui      2022-07-08                 4
# 30    Jamui     Khaira      2022-07-26                 3
# 39    Jamui      Jamui      2022-07-01                 3
#
#            CropEstMethod RcNursEstDate SeedingSowingTransplanting  \
# 21  Manual_PuddledRandom    2022-06-18                 2022-07-17
# 27  Manual_PuddledRandom    2022-06-29                 2022-08-14
# 28  Manual_PuddledRandom    2022-07-06                 2022-07-26
# 30  Manual_PuddledRandom    2022-06-27                 2022-07-27
# 39  Manual_PuddledRandom    2022-07-08                 2022-08-25
#
#     SeedlingsPerPit  TransplantingIrrigationHours  \
# 21              1.0                           6.0
# 27              3.0                           4.0
# 28              3.0                           4.0
# 30              3.0                           2.0
# 39              3.0                           4.0
#
#    TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# 21                        Boring                           Electric
# 27                        Boring                           Electric
# 28                        Boring                           Electric
# 30                        Boring                           Electric
# 39                        Boring                           Electric
#
#     TransIrriCost  TransIrriCost_per_Acre  StandingWater  Ganaura  \
# 21          120.0                   320.0            3.0      0.0
# 27          400.0                  2200.0            1.0      3.0
# 28          400.0                  1760.0            1.0      4.0
# 30            NaN                     NaN           11.0      0.0
# 39          300.0                  1320.0            2.0      4.0
#
#     Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 21               NaN         0.0                  NaN
# 27              16.5         0.0                  NaN
# 28              17.6         0.0                  NaN
# 30               NaN         0.0                  NaN
# 39              17.6         0.0                  NaN
#
#    PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  BasalDAP_per_Acre  \
# 21                        NaN                  1       0.0                NaN
# 27               Broadcasting                  2      15.0               82.5
# 28               Broadcasting                  2      10.0               44.0
# 30                        NaN                  1       8.0               35.2
# 39               Broadcasting                  2      15.0               66.0
#
#     BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  1tdUrea  \
# 21       25.0           66.666667         Broadcasting      0.0
# 27       15.0           82.500000         Broadcasting     10.0
# 28       10.0           44.000000         Broadcasting      5.0
# 30       11.0           48.400000         Broadcasting      0.0
# 39       15.0           66.000000         Broadcasting     10.0
#
#     1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  2appDaysUrea  \
# 21               NaN           NaN      0.0               NaN           NaN
# 27              55.0          10.0      0.0               NaN           NaN
# 28              22.0           5.0      0.0               NaN           NaN
# 30               NaN           NaN      0.0               NaN           NaN
# 39              44.0           5.0      0.0               NaN           NaN
#
#    MineralFertAppMethod.1 Harv_method   Harv_date  Harv_hand_rent  \
# 21                    NaN        hand  2022-10-20          1200.0
# 27           Broadcasting        hand  2022-11-11           200.0
# 28           Broadcasting        hand  2022-11-09           300.0
# 30                    NaN        hand  2022-11-11           100.0
# 39           Broadcasting        hand  2022-11-17           250.0
#
#     Harv_hand_rent_per_Acre Threshing_date Threshing_method  Residue_length  \
# 21                   3200.0     2022-11-02          machine              25
# 27                   1100.0     2023-01-23          machine              26
# 28                   1320.0     2023-01-23          machine              26
# 30                    440.0     2023-01-03          machine              28
# 39                   1100.0     2023-01-19          machine              26
#
#     Residue_perc     Stubble_use      Acre   Yield  Yield_per_Acre  \
# 21            10  plowed_in_soil  0.375000   720.0          1920.0
# 27            10  plowed_in_soil  0.181818   320.0          1760.0
# 28            10  plowed_in_soil  0.227273  4000.0         17600.0
# 30            10  plowed_in_soil  0.227273   400.0          1760.0
# 39            10  plowed_in_soil  0.227273   400.0          1760.0
#
#     LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 21                          True                                  False
# 27                          True                                  False
# 28                          True                                  False
# 30                          True                                  False
# 39                          True                                  False
#
#     LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 21                              False                         False
# 27                               True                          True
# 28                               True                          True
# 30                              False                         False
# 39                               True                          True
#
#     LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 21                 False                        True
# 27                 False                        True
# 28                 False                        True
# 30                 False                       False
# 39                 False                        True
#
#     NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 21                            False                                  True
# 27                            False                                 False
# 28                            False                                 False
# 30                            False                                  True
# 39                            False                                 False
#
#     NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 21                             False                           False
# 27                             False                           False
# 28                             False                           False
# 30                             False                            True
# 39                             False                           False
#
#     TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 21                              False                        False
# 27                              False                         True
# 28                              False                         True
# 30                              False                        False
# 39                              False                         True
#
#     TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 21                       False                                   True
# 27                       False                                  False
# 28                       False                                  False
# 30                        True                                   True
# 39                       False                                  False
#
#     TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 21                        True                 True               False
# 27                       False                 True                True
# 28                       False                 True                True
# 30                        True                 True                True
# 39                       False                 True                True
#
#     CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 21                 False               False               False
# 27                 False               False               False
# 28                 False               False               False
# 30                 False               False               False
# 39                 False               False               False
#
#     CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 21                False               False                False
# 27                False               False                False
# 28                False               False                False
# 30                False               False                False
# 39                False               False                False
#
#     FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 21                   False                  False                  False
# 27                    True                  False                  False
# 28                    True                  False                  False
# 30                   False                  False                  False
# 39                    True                  False                  False
#
#     FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 21                   False                  False                    False
# 27                   False                  False                    False
# 28                   False                  False                    False
# 30                   False                  False                    False
# 39                   False                  False                    False
#
#     OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 21                   False               False                        False
# 27                    True               False                        False
# 28                    True               False                        False
# 30                   False               False                        False
# 39                    True               False                        False
#
#     OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 21                     False                          False
# 27                     False                          False
# 28                     False                          False
# 30                     False                          False
# 39                     False                          False
#
#     OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN k2label  \
# 21                     False                         False          9       A
# 27                     False                         False          3       A
# 28                     False                         False          3       A
# 30                     False                         False         10       A
# 39                     False                         False          3       A
#
#    k3label k4label k5label
# 21       B       B       B
# 27       B       B       C
# 28       B       B       C
# 30       B       B       B
# 39       B       B       C

# %%
df_C.head()
# Out:
#     District  Block CropTillageDate  CropTillageDepth         CropEstMethod  \
# 13     Jamui  Jamui      2022-07-23                 4  Manual_PuddledRandom
# 14     Jamui  Jamui      2022-06-29                 4  Manual_PuddledRandom
# 52     Jamui  Jamui      2022-07-25                 4  Manual_PuddledRandom
# 104    Jamui  Jamui      2022-07-27                 4  Manual_PuddledRandom
# 146    Jamui  Jamui      2022-07-22                 4  Manual_PuddledRandom
#
#     RcNursEstDate SeedingSowingTransplanting  SeedlingsPerPit  \
# 13     2022-06-19                 2022-07-29              4.0
# 14     2022-06-21                 2022-07-27              4.0
# 52     2022-06-19                 2022-08-01              4.0
# 104    2022-06-20                 2022-07-31              4.0
# 146    2022-06-20                 2022-07-26              4.0
#
#      TransplantingIrrigationHours TransplantingIrrigationSource  \
# 13                            5.0                        Boring
# 14                            2.0                        Boring
# 52                            5.0                        Boring
# 104                           2.0                        Boring
# 146                           2.0                        Boring
#
#     TransplantingIrrigationPowerSource  TransIrriCost  TransIrriCost_per_Acre  \
# 13                            Electric         1000.0                  2200.0
# 14                            Electric          400.0                  2200.0
# 52                            Electric         1000.0                  2200.0
# 104                           Electric          500.0                  2200.0
# 146                           Electric          500.0                  2200.0
#
#      StandingWater  Ganaura  Ganaura_per_Acre  CropOrgFYM  \
# 13             3.0      4.0               8.8         0.0
# 14             3.0      2.0              11.0         0.0
# 52             3.0      5.0              11.0         0.0
# 104            3.0      2.0               8.8         0.0
# 146            3.0      3.0              13.2         0.0
#
#      CropOrgFYM_per_Acre PCropSolidOrgFertAppMethod  NoFertilizerAppln  \
# 13                   NaN               Broadcasting                  3
# 14                   NaN               Broadcasting                  3
# 52                   NaN               Broadcasting                  3
# 104                  NaN               Broadcasting                  2
# 146                  NaN               Broadcasting                  3
#
#      BasalDAP  BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre  \
# 13        0.0                NaN        0.0                 NaN
# 14        0.0                NaN        0.0                 NaN
# 52        0.0                NaN        0.0                 NaN
# 104       0.0                NaN        0.0                 NaN
# 146       0.0                NaN        0.0                 NaN
#
#     MineralFertAppMethod  1tdUrea  1tdUrea_per_Acre  1appDaysUrea  2tdUrea  \
# 13          Broadcasting      2.0               4.4          30.0      1.0
# 14          Broadcasting      2.0              11.0          30.0      1.0
# 52          Broadcasting      2.0               4.4          30.0      1.0
# 104         Broadcasting      2.0               8.8           1.0      0.0
# 146         Broadcasting      2.0               8.8          30.0      1.0
#
#      2tdUrea_per_Acre  2appDaysUrea MineralFertAppMethod.1 Harv_method  \
# 13                2.2          60.0           Broadcasting        hand
# 14                5.5          60.0           Broadcasting        hand
# 52                2.2          60.0           Broadcasting        hand
# 104               NaN           NaN           Broadcasting        hand
# 146               4.4          60.0           Broadcasting        hand
#
#       Harv_date  Harv_hand_rent  Harv_hand_rent_per_Acre Threshing_date  \
# 13   2022-11-30            90.0                    198.0     2023-02-02
# 14   2022-11-26            90.0                    495.0     2023-01-27
# 52   2022-11-20            90.0                    198.0     2023-02-02
# 104  2022-11-24            90.0                    396.0     2023-02-11
# 146  2022-11-25            90.0                    396.0     2023-01-26
#
#     Threshing_method  Residue_length  Residue_perc     Stubble_use      Acre  \
# 13              hand              29            10  plowed_in_soil  0.454545
# 14              hand              29            10  plowed_in_soil  0.181818
# 52              hand              29            10  plowed_in_soil  0.454545
# 104             hand              30            10  plowed_in_soil  0.227273
# 146             hand              29            10  plowed_in_soil  0.227273
#
#      Yield  Yield_per_Acre  LandPrepMethod_TractorPlough  \
# 13   800.0          1760.0                          True
# 14   280.0          1540.0                          True
# 52   800.0          1760.0                          True
# 104  400.0          1760.0                          True
# 146  390.0          1716.0                          True
#
#      LandPrepMethod_FourWheelTracRotavator  LandPrepMethod_WetTillagePuddling  \
# 13                                   False                              False
# 14                                   False                              False
# 52                                   False                              False
# 104                                  False                              False
# 146                                  False                              False
#
#      LandPrepMethod_BullockPlough  LandPrepMethod_Other  \
# 13                           True                 False
# 14                           True                 False
# 52                           True                 False
# 104                          True                 False
# 146                          True                 False
#
#      NursDetFactor_CalendarDate  NursDetFactor_PreMonsoonShowers  \
# 13                         True                            False
# 14                         True                            False
# 52                         True                            False
# 104                        True                            False
# 146                        True                            False
#
#      NursDetFactor_IrrigWaterAvailability  NursDetFactor_LabourAvailability  \
# 13                                   True                             False
# 14                                   True                             False
# 52                                   True                             False
# 104                                  True                             False
# 146                                  True                             False
#
#      NursDetFactor_SeedAvailability  TransDetFactor_LabourAvailability  \
# 13                            False                              False
# 14                            False                              False
# 52                            False                              False
# 104                           False                              False
# 146                           False                              False
#
#      TransDetFactor_CalendarDate  TransDetFactor_RainArrival  \
# 13                          True                        True
# 14                          True                       False
# 52                          True                       False
# 104                         True                       False
# 146                         True                       False
#
#      TransDetFactor_IrrigWaterAvailability  TransDetFactor_SeedlingAge  \
# 13                                   False                       False
# 14                                   False                        True
# 52                                   False                        True
# 104                                  False                        True
# 146                                  False                        True
#
#      CropbasalFerts_Urea  CropbasalFerts_DAP  CropbasalFerts_Other  \
# 13                 False               False                 False
# 14                 False               False                 False
# 52                 False               False                 False
# 104                False               False                 False
# 146                False               False                 False
#
#      CropbasalFerts_NPK  CropbasalFerts_MoP  CropbasalFerts_NPKS  \
# 13                False               False                False
# 14                False               False                False
# 52                False               False                False
# 104               False               False                False
# 146               False               False                False
#
#      CropbasalFerts_SSP  CropbasalFerts_None  FirstTopDressFert_Urea  \
# 13                False                 True                    True
# 14                False                 True                    True
# 52                False                 True                    True
# 104               False                 True                    True
# 146               False                 True                    True
#
#      FirstTopDressFert_DAP  FirstTopDressFert_NPK  FirstTopDressFert_NPKS  \
# 13                    True                  False                   False
# 14                    True                  False                   False
# 52                    True                  False                   False
# 104                   True                  False                   False
# 146                   True                  False                   False
#
#      FirstTopDressFert_SSP  FirstTopDressFert_Other  OrgFertilizers_Ganaura  \
# 13                   False                    False                    True
# 14                   False                    False                    True
# 52                   False                    False                    True
# 104                  False                    False                    True
# 146                  False                    False                    True
#
#      OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 13                False                        False
# 14                False                        False
# 52                False                        False
# 104               False                        False
# 146               False                        False
#
#      OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 13                      False                          False
# 14                      False                          False
# 52                      False                          False
# 104                     False                          False
# 146                     False                          False
#
#      OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  Nb_of_NaN  \
# 13                      False                         False          3
# 14                      False                         False          3
# 52                      False                         False          3
# 104                     False                         False          5
# 146                     False                         False          3
#
#     k2label k3label k4label k5label
# 13        B       C       C       D
# 14        B       C       C       D
# 52        B       C       C       D
# 104       B       C       C       D
# 146       B       C       C       D

# %% [markdown]
# #### What are the factors that I think will be important in determining the clusters?

# %% [markdown]
# ##### Fertilisers?
#
# I will first start with the 7 types of fertilisers we have available:
#
# 1. "Urea" - Very common for rice and wheat it would seem from various papers due to its high nitrogen content
# 2. "DAP" (Diammonium Phosphate)
# 3. "Other" (? - Mixtuer of fertilisers or some unknown fertiliser)
# 4. "NPK" - Very common for rice - Usual applications come in steps meaning if this appears again for most columns its probably just indicative of rice farming
# 5. "MoP" - Potash fertiliser - potassium chloride - Common for Maize and a few other crops - Ideally for diesease resistance in all crops - Very cheap relatively which would explain why Bahir would use it
# 6. "NPKS" - Nitrogen, Phosphorus, Potassium and Sulphur - Common for wheat and rice - Also very suitable for humid climates again explaining why Bahir would use it
# 7. "SSP" - Single Super Phosphate - Phosphorus, Sulphur and Calcium + micro - nutrients [Phosphorus, gives best results in neutral soils. But in case of alkaline, excessive presence of calcium makes complexes with phosphorus and ultimately results in poor phosphorus recovery. So bringing soil reaction to neutral by adding gypsum and leaching can only improve P use efficiency of SSP. ](https://kribhco.net/ssp.html#:~:text=SSP%20is%20the%20most%20popular,Description%20Properties%20Efficient%20Use)
# 8. "None" (Technically not a fertiliser)
