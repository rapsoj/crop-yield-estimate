# %%
import scaling
import feature_engineering
import cleaning
import os

import pandas as pd
import numpy as np
import calendar
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")


train_path = "T:\crop-yield-estimate\data\Train.csv"
df_train = cleaning.clean_data(train_path)
df_train = feature_engineering.get_features(df_train)

# %%
df_train.head()
# Out:
#                 ID District      Block  CultLand  CropCultLand  \
# 0  ID_GTFAC7PEVWQ9  Nalanda  Noorsarai        45            40
# 1  ID_TK40ARLSPOKS  Nalanda     Rajgir        26            26
# 2  ID_1FJY2CRIMLZZ     Gaya      Gurua        10            10
# 3  ID_I3IPXS4DB7NE     Gaya      Gurua        15            15
# 4  ID_4T8YQWXWHB4A  Nalanda  Noorsarai        60            60
#
#                                LandPreparationMethod CropTillageDate  \
# 0               TractorPlough FourWheelTracRotavator      2022-07-20
# 1  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2               TractorPlough FourWheelTracRotavator      2022-06-30
# 3               TractorPlough FourWheelTracRotavator      2022-06-16
# 4                   TractorPlough WetTillagePuddling      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# 1                 5  Manual_PuddledRandom    2022-06-20
# 2                 6  Manual_PuddledRandom    2022-06-20
# 3                 6  Manual_PuddledRandom    2022-06-17
# 4                 4  Manual_PuddledRandom    2022-06-21
#
#   SeedingSowingTransplanting  SeedlingsPerPit  \
# 0                 2022-07-21              2.0
# 1                 2022-07-20              2.0
# 2                 2022-08-13              2.0
# 3                 2022-07-17              2.0
# 4                 2022-07-20              2.0
#
#                                        NursDetFactor  \
# 0  CalendarDate IrrigWaterAvailability SeedAvaila...
# 1  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 2  PreMonsoonShowers IrrigWaterAvailability Labou...
# 3  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 4  CalendarDate IrrigWaterAvailability SeedAvaila...
#
#                                       TransDetFactor  \
# 0  CalendarDate SeedlingAge RainArrival IrrigWate...
# 1  CalendarDate SeedlingAge RainArrival IrrigWate...
# 2  SeedlingAge IrrigWaterAvailability LaborAvaila...
# 3  CalendarDate SeedlingAge RainArrival IrrigWate...
# 4  SeedlingAge RainArrival IrrigWaterAvailability...
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# 1                           5.0                        Boring
# 2                           4.0                        Boring
# 3                           NaN                           NaN
# 4                           9.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  StandingWater  \
# 0                           Electric          200.0            2.0
# 1                           Electric          125.0            3.0
# 2                           Electric           80.0            2.0
# 3                                NaN            NaN            NaN
# 4                           Electric          300.0            2.0
#
#   OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0           None      0.0         0.0                        NaN
# 1           None      0.0         0.0                        NaN
# 2    Ganaura FYM      1.0         1.0                SoilApplied
# 3        Ganaura      1.0         0.0                SoilApplied
# 4           None      0.0         0.0                        NaN
#
#    NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea  \
# 0                  2           Urea       0.0       20.0
# 1                  2       DAP Urea      15.0       10.0
# 2                  2            DAP       4.0        0.0
# 3                  2       DAP Urea       6.0        3.0
# 4                  2       Urea DAP      15.0       30.0
#
#   MineralFertAppMethod_1 FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0           Broadcasting              Urea     15.0          18.0      0.0
# 1           Broadcasting              Urea     20.0          39.0      0.0
# 2            SoilApplied              Urea      5.0          65.0      0.0
# 3           Broadcasting              Urea      5.0           5.0      0.0
# 4           Broadcasting              Urea     30.0          26.0      0.0
#
#    2appDaysUrea MineralFertAppMethod_2 Harv_method  Harv_date  Harv_hand_rent  \
# 0           NaN           Broadcasting     machine 2022-11-16             0.0
# 1           NaN           Broadcasting        hand 2022-11-25             3.0
# 2           NaN        RootApplication        hand 2022-12-12           480.0
# 3           NaN           Broadcasting        hand 2022-12-02           240.0
# 4           NaN           Broadcasting     machine 2022-11-30             0.0
#
#   Threshing_date Threshing_method  Residue_length  Residue_perc  \
# 0     2022-11-16          machine              30            40
# 1     2022-12-24          machine              24            10
# 2     2023-01-11          machine              30            10
# 3     2022-12-29             hand              26            10
# 4     2022-12-02          machine              24            40
#
#       Stubble_use      Acre  Yield  LandPrepMethod_TractorPlough  \
# 0  plowed_in_soil  0.312500    600                          True
# 1  plowed_in_soil  0.312500    600                          True
# 2  plowed_in_soil  0.148148    225                          True
# 3  plowed_in_soil  0.222222    468                          True
# 4  plowed_in_soil  0.468750    550                          True
#
#    LandPrepMethod_FourWheelTracRotavator  LandPrepMethod_WetTillagePuddling  \
# 0                                   True                              False
# 1                                   True                               True
# 2                                   True                              False
# 3                                   True                              False
# 4                                  False                               True
#
#    LandPrepMethod_BullockPlough  LandPrepMethod_Other  \
# 0                         False                 False
# 1                         False                 False
# 2                         False                 False
# 3                         False                 False
# 4                         False                 False
#
#    NursDetFactor_CalendarDate  NursDetFactor_PreMonsoonShowers  \
# 0                        True                            False
# 1                        True                             True
# 2                       False                             True
# 3                        True                             True
# 4                        True                            False
#
#    NursDetFactor_IrrigWaterAvailability  NursDetFactor_LabourAvailability  \
# 0                                  True                             False
# 1                                  True                              True
# 2                                  True                              True
# 3                                  True                              True
# 4                                  True                             False
#
#    NursDetFactor_SeedAvailability  TransDetFactor_LabourAvailability  \
# 0                            True                               True
# 1                            True                               True
# 2                           False                               True
# 3                            True                               True
# 4                            True                               True
#
#    TransDetFactor_CalendarDate  TransDetFactor_RainArrival  \
# 0                         True                        True
# 1                         True                        True
# 2                        False                       False
# 3                         True                        True
# 4                        False                        True
#
#    TransDetFactor_IrrigWaterAvailability  TransDetFactor_SeedlingAge  \
# 0                                   True                        True
# 1                                   True                        True
# 2                                   True                        True
# 3                                   True                        True
# 4                                   True                        True
#
#    CropbasalFerts_Urea  CropbasalFerts_DAP  CropbasalFerts_NPK  \
# 0                 True               False               False
# 1                 True                True               False
# 2                False                True               False
# 3                 True                True               False
# 4                 True                True               False
#
#    CropbasalFerts_MoP  CropbasalFerts_NPKS  CropbasalFerts_SSP  \
# 0               False                False               False
# 1               False                False               False
# 2               False                False               False
# 3               False                False               False
# 4               False                False               False
#
#    CropbasalFerts_Other  CropbasalFerts_None  FirstTopDressFert_Urea  \
# 0                 False                False                    True
# 1                 False                False                    True
# 2                 False                False                    True
# 3                 False                False                    True
# 4                 False                False                    True
#
#    FirstTopDressFert_DAP  FirstTopDressFert_NPK  FirstTopDressFert_NPKS  \
# 0                  False                  False                   False
# 1                  False                  False                   False
# 2                  False                  False                   False
# 3                  False                  False                   False
# 4                  False                  False                   False
#
#    FirstTopDressFert_SSP  FirstTopDressFert_Other  FirstTopDressFert_None  \
# 0                  False                    False                   False
# 1                  False                    False                   False
# 2                  False                    False                   False
# 3                  False                    False                   False
# 4                  False                    False                   False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  \
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 4                     False                         False
#
#    OrgFertilizers_None  Nb_of_NaN TpIrrigationSource_Imputed  \
# 0                 True          2                     Boring
# 1                 True          2                     Boring
# 2                False          1                     Boring
# 3                False          6                     Boring
# 4                 True          2                     Boring
#
#   TpIrrigationPowerSource_Imputed  TpIrrigationHours_Imputed  Ganaura_capped  \
# 0                        Electric                        5.0             0.0
# 1                        Electric                        5.0             0.0
# 2                        Electric                        4.0             1.0
# 3                        Electric                        4.0             1.0
# 4                        Electric                        9.0             0.0
#
#    TransplantingIrrigationHours_per_Acre  TpIrrigationHours_Imputed_per_Acre  \
# 0                                   16.0                                16.0
# 1                                   16.0                                16.0
# 2                                   27.0                                27.0
# 3                                    NaN                                18.0
# 4                                   19.2                                19.2
#
#    TransIrriCost_per_Acre  Ganaura_per_Acre  CropOrgFYM_per_Acre  \
# 0                   640.0              0.00                 0.00
# 1                   400.0              0.00                 0.00
# 2                   540.0              6.75                 6.75
# 3                     NaN              4.50                 0.00
# 4                   640.0              0.00                 0.00
#
#    BasalDAP_per_Acre  BasalUrea_per_Acre  1tdUrea_per_Acre  2tdUrea_per_Acre  \
# 0                0.0                64.0             48.00               0.0
# 1               48.0                32.0             64.00               0.0
# 2               27.0                 0.0             33.75               0.0
# 3               27.0                13.5             22.50               0.0
# 4               32.0                64.0             64.00               0.0
#
#    Harv_hand_rent_per_Acre  Yield_per_Acre  RcNursEstDate_NaN  \
# 0                      0.0     1920.000000              False
# 1                      9.6     1920.000000              False
# 2                   3240.0     1518.750000              False
# 3                   1080.0     2106.000000              False
# 4                      0.0     1173.333333              False
#
#    SeedlingsPerPit_NaN  TransplantingIrrigationSource_NaN  \
# 0                False                              False
# 1                False                              False
# 2                False                              False
# 3                False                               True
# 4                False                              False
#
#    TransplantingIrrigationPowerSource_NaN  TransplantingIrrigationHours_NaN  \
# 0                                   False                             False
# 1                                   False                             False
# 2                                   False                             False
# 3                                    True                              True
# 4                                   False                             False
#
#    Days_bw_Nurs_SowTransp  Days_bw_Nurs_Harv  Days_bw_Nurs_Till  \
# 0                    24.0              142.0               23.0
# 1                    30.0              158.0               28.0
# 2                    54.0              175.0               10.0
# 3                    30.0              168.0               -1.0
# 4                    29.0              162.0               28.0
#
#    Days_bw_Till_SowTransp  Days_bw_Till_Harv  Days_bw_SowTransp_Harv  \
# 0                     1.0              119.0                   118.0
# 1                     2.0              130.0                   128.0
# 2                    44.0              165.0                   121.0
# 3                    31.0              169.0                   138.0
# 4                     1.0              134.0                   133.0
#
#    Days_bw_Harv_Thresh  NursingDate_ModeDiff  TillageDate_ModeDiff  \
# 0                  0.0                  -1.0                     0
# 1                 29.0                  -8.0                    -2
# 2                 30.0                  -8.0                   -20
# 3                 27.0                 -11.0                   -34
# 4                  2.0                  -7.0                    -1
#
#    SowTransplantDate_ModeDiff  HarvestDate_ModeDiff  ThreshingDate_ModeDiff  \
# 0                          -7                    11                     -36
# 1                          -8                    20                       2
# 2                          16                    37                      20
# 3                         -11                    27                       7
# 4                          -8                    25                     -20
#
#    Days_bw_Nurs_SowTransp_ModeDiff  Days_bw_Nurs_Harv_ModeDiff  \
# 0                              0.0                        15.0
# 1                              6.0                        31.0
# 2                             30.0                        48.0
# 3                              6.0                        41.0
# 4                              5.0                        35.0
#
#    Days_bw_Nurs_Till_ModeDiff  Days_bw_Till_SowTransp_ModeDiff  \
# 0                         1.0                              0.0
# 1                         6.0                              1.0
# 2                       -12.0                             43.0
# 3                       -23.0                             30.0
# 4                         6.0                              0.0
#
#    Days_bw_Till_Harv_ModeDiff  Days_bw_SowTransp_Harv_ModeDiff  \
# 0                       -13.0                             -6.0
# 1                        -2.0                              4.0
# 2                        33.0                             -3.0
# 3                        37.0                             14.0
# 4                         2.0                              9.0
#
#    Days_bw_Harv_Thresh_ModeDiff CropTillageMonth NursingMonth  \
# 0                         -10.0             July         June
# 1                          19.0             July         June
# 2                          20.0             June         June
# 3                          17.0             June         June
# 4                          -8.0             July         June
#
#   SowTransplantMonth HarvestMonth ThreshingMonth CropTillageSeason  \
# 0               July     November       November           Monsoon
# 1               July     November       December           Monsoon
# 2             August     December        January           Monsoon
# 3               July     December       December           Monsoon
# 4               July     November       December           Monsoon
#
#   NursingSeason SowTransplantSeason HarvestSeason ThreshingSeason  \
# 0       Monsoon             Monsoon  Post-Monsoon    Post-Monsoon
# 1       Monsoon             Monsoon  Post-Monsoon    Post-Monsoon
# 2       Monsoon             Monsoon  Post-Monsoon          Winter
# 3       Monsoon             Monsoon  Post-Monsoon    Post-Monsoon
# 4       Monsoon             Monsoon  Post-Monsoon    Post-Monsoon
#
#    Total_Crop_Cycle_Duration  Num_LandPrepMethod  Num_NursDetFactor  \
# 0                      119.0                   2                  2
# 1                      159.0                   3                  3
# 2                      195.0                   2                  2
# 3                      196.0                   2                  2
# 4                      136.0                   2                  2
#
#    Num_TransDetFactor  Num_OrgFertilizers  Num_CropbasalFerts  \
# 0                   5                   0                   1
# 1                   5                   0                   2
# 2                   3                   2                   1
# 3                   5                   1                   2
# 4                   4                   0                   2
#
#    Num_TopDressFert  Latitude  Longitude  Elevation
# 0                 1   25.2748    85.4569       63.0
# 1                 1   25.0262    85.4174       67.0
# 2                 1   24.6696    84.7720      114.0
# 3                 1   24.6696    84.7720      114.0
# 4                 1   25.2748    85.4569       63.0

# %%
# Lets see all the columns
pd.set_option('display.max_columns', None)

# %%
filtered_columns = df_train.filter(like='NursDetFactor_')
df_nurs = filtered_columns.copy()
df_merged = df_nurs.merge(df_train[['ID']], left_index=True, right_index=True)
df_merged.head()
# Out:
#    NursDetFactor_CalendarDate  NursDetFactor_PreMonsoonShowers  \
# 0                        True                            False
# 1                        True                             True
# 2                       False                             True
# 3                        True                             True
# 4                        True                            False
#
#    NursDetFactor_IrrigWaterAvailability  NursDetFactor_LabourAvailability  \
# 0                                  True                             False
# 1                                  True                              True
# 2                                  True                              True
# 3                                  True                              True
# 4                                  True                             False
#
#    NursDetFactor_SeedAvailability               ID
# 0                            True  ID_GTFAC7PEVWQ9
# 1                            True  ID_TK40ARLSPOKS
# 2                           False  ID_1FJY2CRIMLZZ
# 3                            True  ID_I3IPXS4DB7NE
# 4                            True  ID_4T8YQWXWHB4A

# %%
date_variables = ["CropTillageMonth", "HarvestMonth", "ThreshingMonth"]

# %%
df_train["CropTillageMonth"].value_counts()
# Out:
# CropTillageMonth
# July      2908
# June       860
# August     101
# May          1
# Name: count, dtype: int64

# %%
df_train["ID"]
# Out:
# 0       ID_GTFAC7PEVWQ9
# 1       ID_TK40ARLSPOKS
# 2       ID_1FJY2CRIMLZZ
# 3       ID_I3IPXS4DB7NE
# 4       ID_4T8YQWXWHB4A
#              ...
# 3865    ID_7ZZQ6R4XB4FK
# 3866    ID_PVVDF6LK6FO8
# 3867    ID_RBYVUPRATVMW
# 3868    ID_ARE9QWENJNJ2
# 3869    ID_KEPOQDTCZC6S
# Name: ID, Length: 3870, dtype: object

# %%
# DO THIS IN CLEANING PY
df_train[df_train["CropTillageMonth"] == "May"]["ID"]
# Out:
# 379    ID_N2FQH4S194A9
# Name: ID, dtype: object

# %%
# What categorical columns have entries that do not appear more than 20 times?
for col in date_variables:
     print(df_train[col].value_counts())
     print('\n')
# Out:
# CropTillageMonth
# July      2908
# June       860
# August     101
# May          1
# Name: count, dtype: int64
#
#
# HarvestMonth
# November     2494
# October       807
# December      554
# January         8
# September       5
# February        1
# March           1
# Name: count, dtype: int64
#
#
# ThreshingMonth
# December    1370
# November    1008
# January      683
# October      523
# February     236
# March         50
# Name: count, dtype: int64

# %%
# DO THIS IN CLEANING PY
df_train["HarvestMonth"] = df_train["HarvestMonth"].replace({'January': 'December','September': 'October', 'March': 'December', 'February':'December'})

# %%
# What categorical columns have entries that do not appear more than 20 times?
for col in date_variables:
     print(df_train[col].value_counts())
     print('\n')
# Out:
# CropTillageMonth
# July      2908
# June       860
# August     101
# May          1
# Name: count, dtype: int64
#
#
# HarvestMonth
# November    2494
# October      812
# December     564
# Name: count, dtype: int64
#
#
# ThreshingMonth
# December    1370
# November    1008
# January      683
# October      523
# February     236
# March         50
# Name: count, dtype: int64

# %%
# Get the count of unique values in each categorical column
categorical_columns = df_train.select_dtypes(include=['object']).columns
small_sample_columns = []

for col in categorical_columns:
    value_counts = df_train[col].value_counts()
    small_samples = value_counts[value_counts < 20]
    
    if not small_samples.empty:
        small_sample_columns.append(col)

print("Columns with small samples (under 20):")
print(small_sample_columns)
# Out:
# Columns with small samples (under 20):
# ['ID', 'Block', 'LandPreparationMethod', 'NursDetFactor', 'TransDetFactor', 'TransplantingIrrigationSource', 'TransplantingIrrigationPowerSource', 'OrgFertilizers', 'PCropSolidOrgFertAppMethod', 'CropbasalFerts', 'MineralFertAppMethod_1', 'FirstTopDressFert', 'TpIrrigationSource_Imputed', 'TpIrrigationPowerSource_Imputed', 'CropTillageMonth', 'CropTillageSeason', 'HarvestSeason']

# %%
for col in small_sample_columns:
    if col != "ID":
        value_counts = df_train[col].value_counts()
        small_samples = value_counts[value_counts < 20]
        print(small_samples)
        print('\n')
# Out:
# Block
# Gaya    1
# Name: count, dtype: int64
#
#
# LandPreparationMethod
# TractorPlough WetTillagePuddling                                         17
# WetTillagePuddling FourWheelTracRotavator TractorPlough                  15
# WetTillagePuddling TractorPlough BullockPlough FourWheelTracRotavator    13
# TractorPlough WetTillagePuddling BullockPlough                           10
# WetTillagePuddling FourWheelTracRotavator TractorPlough BullockPlough     9
# WetTillagePuddling BullockPlough TractorPlough FourWheelTracRotavator     8
# BullockPlough TractorPlough                                               8
# BullockPlough FourWheelTracRotavator TractorPlough WetTillagePuddling     7
# WetTillagePuddling Other                                                  7
# WetTillagePuddling BullockPlough TractorPlough                            7
# Other                                                                     6
# TractorPlough FourWheelTracRotavator BullockPlough                        3
# BullockPlough TractorPlough WetTillagePuddling                            3
# FourWheelTracRotavator WetTillagePuddling                                 2
# BullockPlough TractorPlough WetTillagePuddling FourWheelTracRotavator     2
# WetTillagePuddling BullockPlough FourWheelTracRotavator TractorPlough     2
# TractorPlough WetTillagePuddling BullockPlough FourWheelTracRotavator     2
# TractorPlough BullockPlough WetTillagePuddling                            2
# TractorPlough Other                                                       1
# TractorPlough FourWheelTracRotavator BullockPlough WetTillagePuddling     1
# BullockPlough                                                             1
# BullockPlough WetTillagePuddling                                          1
# TractorPlough WetTillagePuddling FourWheelTracRotavator BullockPlough     1
# FourWheelTracRotavator WetTillagePuddling BullockPlough TractorPlough     1
# FourWheelTracRotavator WetTillagePuddling TractorPlough                   1
# FourWheelTracRotavator BullockPlough WetTillagePuddling TractorPlough     1
# FourWheelTracRotavator BullockPlough                                      1
# TractorPlough FourWheelTracRotavator WetTillagePuddling BullockPlough     1
# Name: count, dtype: int64
#
#
# NursDetFactor
# CalendarDate IrrigWaterAvailability PreMonsoonShowers                                        17
# IrrigWaterAvailability SeedAvailability CalendarDate                                         16
# PreMonsoonShowers IrrigWaterAvailability LabourAvailability                                  15
# CalendarDate SeedAvailability LabourAvailability                                             15
# IrrigWaterAvailability PreMonsoonShowers                                                     13
#                                                                                              ..
# IrrigWaterAvailability CalendarDate PreMonsoonShowers LabourAvailability                      1
# LabourAvailability SeedAvailability IrrigWaterAvailability PreMonsoonShowers                  1
# CalendarDate PreMonsoonShowers SeedAvailability IrrigWaterAvailability LabourAvailability     1
# CalendarDate SeedAvailability PreMonsoonShowers IrrigWaterAvailability                        1
# LabourAvailability IrrigWaterAvailability PreMonsoonShowers                                   1
# Name: count, Length: 100, dtype: int64
#
#
# TransDetFactor
# CalendarDate RainArrival SeedlingAge IrrigWaterAvailability                      17
# SeedlingAge CalendarDate                                                         16
# CalendarDate RainArrival IrrigWaterAvailability                                  16
# IrrigWaterAvailability LaborAvailability                                         16
# LaborAvailability IrrigWaterAvailability RainArrival SeedlingAge                 15
#                                                                                  ..
# LaborAvailability RainArrival SeedlingAge CalendarDate                            1
# IrrigWaterAvailability LaborAvailability RainArrival CalendarDate SeedlingAge     1
# CalendarDate LaborAvailability SeedlingAge RainArrival                            1
# RainArrival CalendarDate SeedlingAge                                              1
# RainArrival SeedlingAge CalendarDate IrrigWaterAvailability                       1
# Name: count, Length: 124, dtype: int64
#
#
# TransplantingIrrigationSource
# TubeWell    12
# Well         3
# Name: count, dtype: int64
#
#
# TransplantingIrrigationPowerSource
# Solar    2
# Name: count, dtype: int64
#
#
# OrgFertilizers
# VermiCompost                               19
# Ganaura FYM VermiCompost                   10
# FYM Ganaura                                10
# Ganaura FYM VermiCompost Ghanajeevamrit    10
# FYM VermiCompost                            8
# Ganaura Ghanajeevamrit                      5
# Ganaura VermiCompost Ghanajeevamrit         4
# VermiCompost FYM                            4
# Ganaura Jeevamrit                           2
# Ganaura Pranamrit Ghanajeevamrit            2
# Ghanajeevamrit Ganaura                      2
# PoultryManure                               2
# Ganaura PoultryManure                       2
# Ganaura Ghanajeevamrit FYM                  2
# Ghanajeevamrit Ganaura FYM                  1
# Ghanajeevamrit FYM Ganaura                  1
# Ganaura Pranamrit FYM                       1
# Ganaura Pranamrit                           1
# Ganaura FYM PoultryManure VermiCompost      1
# Ganaura VermiCompost FYM                    1
# FYM Ghanajeevamrit                          1
# Ganaura Ghanajeevamrit VermiCompost         1
# Ganaura FYM PoultryManure                   1
# Jeevamrit                                   1
# FYM Ganaura VermiCompost                    1
# Pranamrit                                   1
# Ganaura FYM Ghanajeevamrit VermiCompost     1
# Name: count, dtype: int64
#
#
# PCropSolidOrgFertAppMethod
# RootApplication    9
# Spray              3
# Name: count, dtype: int64
#
#
# CropbasalFerts
# DAP Urea NPKS        18
# NPK Urea              8
# Urea DAP SSP          7
# Urea NPKS             6
# Urea DAP NPKS         3
# DAP NPKS              3
# DAP SSP               3
# Urea NPKS DAP         3
# DAP NPK Urea          2
# DAP Urea NPK          1
# Urea DAP MoP          1
# SSP Urea              1
# NPKS                  1
# DAP NPKS Urea         1
# NPKS DAP Urea         1
# DAP Urea NPKS MoP     1
# DAP NPKS Urea SSP     1
# Urea SSP              1
# Urea NPK              1
# DAP NPKS Other        1
# NPK DAP Urea          1
# DAP Urea SSP MoP      1
# DAP MoP               1
# DAP Urea NPKS SSP     1
# DAP Urea MoP          1
# Urea SSP DAP          1
# Urea Other DAP        1
# Name: count, dtype: int64
#
#
# MineralFertAppMethod_1
# RootApplication    18
# Name: count, dtype: int64
#
#
# FirstTopDressFert
# NPKS Urea       6
# Urea NPKS       5
# NPK             3
# DAP NPKS        3
# NPK Urea        2
# DAP NPK Urea    1
# Urea NPK        1
# DAP NPK         1
# Urea SSP        1
# Other Urea      1
# Name: count, dtype: int64
#
#
# TpIrrigationSource_Imputed
# TubeWell    12
# Well         3
# Name: count, dtype: int64
#
#
# TpIrrigationPowerSource_Imputed
# Solar    2
# Name: count, dtype: int64
#
#
# CropTillageMonth
# May    1
# Name: count, dtype: int64
#
#
# CropTillageSeason
# Summer    1
# Name: count, dtype: int64
#
#
# HarvestSeason
# Winter     10
# Monsoon     5
# Name: count, dtype: int64

# %% [markdown]
# NursDetFactor has very low SHAPley value so instead of dropping the rows with low values I will drop the column itself
