# %%
import scaling
import feature_engineering
import cleaning
import os

import pandas as pd
import numpy as np
import calendar
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")


train_path = "/home/shaw/crop-yield-estimate/data/Train.csv"
df_train = cleaning.clean_data(train_path)

# %%
df_train.head()
# Out:
#                 ID District      Block  CultLand  CropCultLand  \
# 0  ID_GTFAC7PEVWQ9  Nalanda  Noorsarai        45            40
# 1  ID_TK40ARLSPOKS  Nalanda     Rajgir        26            26
# 2  ID_1FJY2CRIMLZZ     Gaya      Gurua        10            10
# 3  ID_I3IPXS4DB7NE     Gaya      Gurua        15            15
# 4  ID_4T8YQWXWHB4A  Nalanda  Noorsarai        60            60
#
#                                LandPreparationMethod CropTillageDate  \
# 0               TractorPlough FourWheelTracRotavator      2022-07-20
# 1  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2               TractorPlough FourWheelTracRotavator      2022-06-30
# 3               TractorPlough FourWheelTracRotavator      2022-06-16
# 4                   TractorPlough WetTillagePuddling      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  ...  \
# 0                 5  Manual_PuddledRandom    2022-06-27  ...
# 1                 5  Manual_PuddledRandom    2022-06-20  ...
# 2                 6  Manual_PuddledRandom    2022-06-20  ...
# 3                 6  Manual_PuddledRandom    2022-06-17  ...
# 4                 4  Manual_PuddledRandom    2022-06-21  ...
#
#   OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                    False                          False
# 1                    False                          False
# 2                    False                          False
# 3                    False                          False
# 4                    False                          False
#
#   OrgFertilizers_Jeevamrit OrgFertilizers_PoultryManure  OrgFertilizers_None  \
# 0                    False                        False                 True
# 1                    False                        False                 True
# 2                    False                        False                False
# 3                    False                        False                False
# 4                    False                        False                 True
#
#   Nb_of_NaN TpIrrigationSource_Imputed  TpIrrigationPowerSource_Imputed  \
# 0         2                     Boring                         Electric
# 1         2                     Boring                         Electric
# 2         1                     Boring                         Electric
# 3         6                     Boring                         Electric
# 4         2                     Boring                         Electric
#
#    TpIrrigationHours_Imputed Ganaura_capped
# 0                        5.0            0.0
# 1                        5.0            0.0
# 2                        4.0            1.0
# 3                        4.0            1.0
# 4                        9.0            0.0
#
# [5 rows x 87 columns]

# %%
# Lets see all the columns
pd.set_option('display.max_columns', None)

# %%
df_train.head()
# Out:
#                 ID District      Block  CultLand  CropCultLand  \
# 0  ID_GTFAC7PEVWQ9  Nalanda  Noorsarai        45            40
# 1  ID_TK40ARLSPOKS  Nalanda     Rajgir        26            26
# 2  ID_1FJY2CRIMLZZ     Gaya      Gurua        10            10
# 3  ID_I3IPXS4DB7NE     Gaya      Gurua        15            15
# 4  ID_4T8YQWXWHB4A  Nalanda  Noorsarai        60            60
#
#                                LandPreparationMethod CropTillageDate  \
# 0               TractorPlough FourWheelTracRotavator      2022-07-20
# 1  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2               TractorPlough FourWheelTracRotavator      2022-06-30
# 3               TractorPlough FourWheelTracRotavator      2022-06-16
# 4                   TractorPlough WetTillagePuddling      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# 1                 5  Manual_PuddledRandom    2022-06-20
# 2                 6  Manual_PuddledRandom    2022-06-20
# 3                 6  Manual_PuddledRandom    2022-06-17
# 4                 4  Manual_PuddledRandom    2022-06-21
#
#   SeedingSowingTransplanting  SeedlingsPerPit  \
# 0                 2022-07-21              2.0
# 1                 2022-07-20              2.0
# 2                 2022-08-13              2.0
# 3                 2022-07-17              2.0
# 4                 2022-07-20              2.0
#
#                                        NursDetFactor  \
# 0  CalendarDate IrrigWaterAvailability SeedAvaila...
# 1  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 2  PreMonsoonShowers IrrigWaterAvailability Labou...
# 3  CalendarDate PreMonsoonShowers IrrigWaterAvail...
# 4  CalendarDate IrrigWaterAvailability SeedAvaila...
#
#                                       TransDetFactor  \
# 0  CalendarDate SeedlingAge RainArrival IrrigWate...
# 1  CalendarDate SeedlingAge RainArrival IrrigWate...
# 2  SeedlingAge IrrigWaterAvailability LaborAvaila...
# 3  CalendarDate SeedlingAge RainArrival IrrigWate...
# 4  SeedlingAge RainArrival IrrigWaterAvailability...
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# 1                           5.0                        Boring
# 2                           4.0                        Boring
# 3                           NaN                           NaN
# 4                           9.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  StandingWater  \
# 0                           Electric          200.0            2.0
# 1                           Electric          125.0            3.0
# 2                           Electric           80.0            2.0
# 3                                NaN            NaN            NaN
# 4                           Electric          300.0            2.0
#
#   OrgFertilizers  Ganaura  CropOrgFYM PCropSolidOrgFertAppMethod  \
# 0           None      0.0         0.0                        NaN
# 1           None      0.0         0.0                        NaN
# 2    Ganaura FYM      1.0         1.0                SoilApplied
# 3        Ganaura      1.0         0.0                SoilApplied
# 4           None      0.0         0.0                        NaN
#
#    NoFertilizerAppln CropbasalFerts  BasalDAP  BasalUrea  \
# 0                  2           Urea       0.0       20.0
# 1                  2       DAP Urea      15.0       10.0
# 2                  2            DAP       4.0        0.0
# 3                  2       DAP Urea       6.0        3.0
# 4                  2       Urea DAP      15.0       30.0
#
#   MineralFertAppMethod_1 FirstTopDressFert  1tdUrea  1appDaysUrea  2tdUrea  \
# 0           Broadcasting              Urea     15.0          18.0      0.0
# 1           Broadcasting              Urea     20.0          39.0      0.0
# 2            SoilApplied              Urea      5.0          65.0      0.0
# 3           Broadcasting              Urea      5.0           5.0      0.0
# 4           Broadcasting              Urea     30.0          26.0      0.0
#
#    2appDaysUrea MineralFertAppMethod_2 Harv_method  Harv_date  Harv_hand_rent  \
# 0           NaN           Broadcasting     machine 2022-11-16             0.0
# 1           NaN           Broadcasting        hand 2022-11-25             3.0
# 2           NaN        RootApplication        hand 2022-12-12           480.0
# 3           NaN           Broadcasting        hand 2022-12-02           240.0
# 4           NaN           Broadcasting     machine 2022-11-30             0.0
#
#   Threshing_date Threshing_method  Residue_length  Residue_perc  \
# 0     2022-11-16          machine              30            40
# 1     2022-12-24          machine              24            10
# 2     2023-01-11          machine              30            10
# 3     2022-12-29             hand              26            10
# 4     2022-12-02          machine              24            40
#
#       Stubble_use      Acre  Yield  LandPrepMethod_TractorPlough  \
# 0  plowed_in_soil  0.312500    600                          True
# 1  plowed_in_soil  0.312500    600                          True
# 2  plowed_in_soil  0.148148    225                          True
# 3  plowed_in_soil  0.222222    468                          True
# 4  plowed_in_soil  0.468750    550                          True
#
#    LandPrepMethod_FourWheelTracRotavator  LandPrepMethod_WetTillagePuddling  \
# 0                                   True                              False
# 1                                   True                               True
# 2                                   True                              False
# 3                                   True                              False
# 4                                  False                               True
#
#    LandPrepMethod_BullockPlough  LandPrepMethod_Other  \
# 0                         False                 False
# 1                         False                 False
# 2                         False                 False
# 3                         False                 False
# 4                         False                 False
#
#    NursDetFactor_CalendarDate  NursDetFactor_PreMonsoonShowers  \
# 0                        True                            False
# 1                        True                             True
# 2                       False                             True
# 3                        True                             True
# 4                        True                            False
#
#    NursDetFactor_IrrigWaterAvailability  NursDetFactor_LabourAvailability  \
# 0                                  True                             False
# 1                                  True                              True
# 2                                  True                              True
# 3                                  True                              True
# 4                                  True                             False
#
#    NursDetFactor_SeedAvailability  TransDetFactor_LabourAvailability  \
# 0                            True                               True
# 1                            True                               True
# 2                           False                               True
# 3                            True                               True
# 4                            True                               True
#
#    TransDetFactor_CalendarDate  TransDetFactor_RainArrival  \
# 0                         True                        True
# 1                         True                        True
# 2                        False                       False
# 3                         True                        True
# 4                        False                        True
#
#    TransDetFactor_IrrigWaterAvailability  TransDetFactor_SeedlingAge  \
# 0                                   True                        True
# 1                                   True                        True
# 2                                   True                        True
# 3                                   True                        True
# 4                                   True                        True
#
#    CropbasalFerts_Urea  CropbasalFerts_DAP  CropbasalFerts_NPK  \
# 0                 True               False               False
# 1                 True                True               False
# 2                False                True               False
# 3                 True                True               False
# 4                 True                True               False
#
#    CropbasalFerts_MoP  CropbasalFerts_NPKS  CropbasalFerts_SSP  \
# 0               False                False               False
# 1               False                False               False
# 2               False                False               False
# 3               False                False               False
# 4               False                False               False
#
#    CropbasalFerts_Other  CropbasalFerts_None  FirstTopDressFert_Urea  \
# 0                 False                False                    True
# 1                 False                False                    True
# 2                 False                False                    True
# 3                 False                False                    True
# 4                 False                False                    True
#
#    FirstTopDressFert_DAP  FirstTopDressFert_NPK  FirstTopDressFert_NPKS  \
# 0                  False                  False                   False
# 1                  False                  False                   False
# 2                  False                  False                   False
# 3                  False                  False                   False
# 4                  False                  False                   False
#
#    FirstTopDressFert_SSP  FirstTopDressFert_Other  FirstTopDressFert_None  \
# 0                  False                    False                   False
# 1                  False                    False                   False
# 2                  False                    False                   False
# 3                  False                    False                   False
# 4                  False                    False                   False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  \
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 4                     False                         False
#
#    OrgFertilizers_None  Nb_of_NaN TpIrrigationSource_Imputed  \
# 0                 True          2                     Boring
# 1                 True          2                     Boring
# 2                False          1                     Boring
# 3                False          6                     Boring
# 4                 True          2                     Boring
#
#   TpIrrigationPowerSource_Imputed  TpIrrigationHours_Imputed  Ganaura_capped
# 0                        Electric                        5.0             0.0
# 1                        Electric                        5.0             0.0
# 2                        Electric                        4.0             1.0
# 3                        Electric                        4.0             1.0
# 4                        Electric                        9.0             0.0

# %%
# What categorical columns have entries that do not appear more than 20 times?




for col in df_train.columns:
    if df_train[col].dtype == 'object':
            print(df_train[col].value_counts())
            print('\n')
# Out:
# ID
# ID_GTFAC7PEVWQ9    1
# ID_XAK09MV7FD0K    1
# ID_BZKO6B5IX3CX    1
# ID_FOSNA2L61KRK    1
# ID_2BUEEZ8NNHBR    1
#                   ..
# ID_9GTPKCPCEXP5    1
# ID_9ZO7Y0Z7C8L5    1
# ID_8FFGVSJRVTQ7    1
# ID_TH0DL26XYV6V    1
# ID_KEPOQDTCZC6S    1
# Name: count, Length: 3870, dtype: int64
#
#
# District
# Nalanda     1193
# Jamui       1127
# Vaishali     980
# Gaya         570
# Name: count, dtype: int64
#
#
# Block
# Rajgir        850
# Jamui         626
# Mahua         607
# Khaira        500
# Gurua         357
# Noorsarai     343
# Chehrakala    239
# Wazirganj     213
# Garoul        134
# Gaya            1
# Name: count, dtype: int64
#
#
# LandPreparationMethod
# TractorPlough                                                            1038
# TractorPlough FourWheelTracRotavator                                     1025
# WetTillagePuddling TractorPlough FourWheelTracRotavator                   569
# WetTillagePuddling TractorPlough BullockPlough                            234
# WetTillagePuddling FourWheelTracRotavator                                 211
# TractorPlough BullockPlough                                               173
# WetTillagePuddling TractorPlough                                          135
# FourWheelTracRotavator TractorPlough                                       93
# FourWheelTracRotavator                                                     71
# WetTillagePuddling                                                         44
# WetTillagePuddling TractorPlough FourWheelTracRotavator BullockPlough      41
# TractorPlough WetTillagePuddling FourWheelTracRotavator                    34
# TractorPlough FourWheelTracRotavator WetTillagePuddling                    27
# FourWheelTracRotavator TractorPlough WetTillagePuddling                    22
# WetTillagePuddling FourWheelTracRotavator BullockPlough TractorPlough      20
# TractorPlough WetTillagePuddling                                           17
# WetTillagePuddling FourWheelTracRotavator TractorPlough                    15
# WetTillagePuddling TractorPlough BullockPlough FourWheelTracRotavator      13
# TractorPlough WetTillagePuddling BullockPlough                             10
# WetTillagePuddling FourWheelTracRotavator TractorPlough BullockPlough       9
# WetTillagePuddling BullockPlough TractorPlough FourWheelTracRotavator       8
# BullockPlough TractorPlough                                                 8
# BullockPlough FourWheelTracRotavator TractorPlough WetTillagePuddling       7
# WetTillagePuddling Other                                                    7
# WetTillagePuddling BullockPlough TractorPlough                              7
# Other                                                                       6
# TractorPlough FourWheelTracRotavator BullockPlough                          3
# BullockPlough TractorPlough WetTillagePuddling                              3
# FourWheelTracRotavator WetTillagePuddling                                   2
# BullockPlough TractorPlough WetTillagePuddling FourWheelTracRotavator       2
# WetTillagePuddling BullockPlough FourWheelTracRotavator TractorPlough       2
# TractorPlough WetTillagePuddling BullockPlough FourWheelTracRotavator       2
# TractorPlough BullockPlough WetTillagePuddling                              2
# TractorPlough Other                                                         1
# TractorPlough FourWheelTracRotavator BullockPlough WetTillagePuddling       1
# BullockPlough                                                               1
# BullockPlough WetTillagePuddling                                            1
# TractorPlough WetTillagePuddling FourWheelTracRotavator BullockPlough       1
# FourWheelTracRotavator WetTillagePuddling BullockPlough TractorPlough       1
# FourWheelTracRotavator WetTillagePuddling TractorPlough                     1
# FourWheelTracRotavator BullockPlough WetTillagePuddling TractorPlough       1
# FourWheelTracRotavator BullockPlough                                        1
# TractorPlough FourWheelTracRotavator WetTillagePuddling BullockPlough       1
# Name: count, dtype: int64
#
#
# CropEstMethod
# Manual_PuddledRandom      3346
# Manual_PuddledLine         235
# LineSowingAfterTillage     206
# Broadcasting                83
# Name: count, dtype: int64
#
#
# NursDetFactor
# CalendarDate PreMonsoonShowers IrrigWaterAvailability LabourAvailability SeedAvailability    560
# CalendarDate IrrigWaterAvailability                                                          379
# CalendarDate                                                                                 324
# CalendarDate IrrigWaterAvailability SeedAvailability                                         306
# LabourAvailability                                                                           196
#                                                                                             ...
# IrrigWaterAvailability CalendarDate PreMonsoonShowers LabourAvailability                       1
# LabourAvailability SeedAvailability IrrigWaterAvailability PreMonsoonShowers                   1
# CalendarDate PreMonsoonShowers SeedAvailability IrrigWaterAvailability LabourAvailability      1
# CalendarDate SeedAvailability PreMonsoonShowers IrrigWaterAvailability                         1
# LabourAvailability IrrigWaterAvailability PreMonsoonShowers                                    1
# Name: count, Length: 125, dtype: int64
#
#
# TransDetFactor
# CalendarDate SeedlingAge RainArrival IrrigWaterAvailability LaborAvailability    858
# CalendarDate                                                                     301
# SeedlingAge RainArrival IrrigWaterAvailability LaborAvailability                 183
# IrrigWaterAvailability                                                           174
# CalendarDate SeedlingAge RainArrival IrrigWaterAvailability                      169
#                                                                                 ...
# LaborAvailability RainArrival SeedlingAge CalendarDate                             1
# IrrigWaterAvailability LaborAvailability RainArrival CalendarDate SeedlingAge      1
# CalendarDate LaborAvailability SeedlingAge RainArrival                             1
# RainArrival CalendarDate SeedlingAge                                               1
# RainArrival SeedlingAge CalendarDate IrrigWaterAvailability                        1
# Name: count, Length: 155, dtype: int64
#
#
# TransplantingIrrigationSource
# Boring      3228
# Canal        373
# Rainfed      103
# Pond          36
# TubeWell      12
# Well           3
# Name: count, dtype: int64
#
#
# TransplantingIrrigationPowerSource
# Electric    2645
# Diesel       720
# Solar          2
# Name: count, dtype: int64
#
#
# OrgFertilizers
# None                                       1335
# Ganaura                                    1295
# FYM                                        1035
# Ganaura FYM                                  84
# Ganaura FYM Ghanajeevamrit                   26
# VermiCompost                                 19
# Ganaura FYM VermiCompost                     10
# FYM Ganaura                                  10
# Ganaura FYM VermiCompost Ghanajeevamrit      10
# FYM VermiCompost                              8
# Ganaura Ghanajeevamrit                        5
# Ganaura VermiCompost Ghanajeevamrit           4
# VermiCompost FYM                              4
# Ganaura Jeevamrit                             2
# Ganaura Pranamrit Ghanajeevamrit              2
# Ghanajeevamrit Ganaura                        2
# PoultryManure                                 2
# Ganaura PoultryManure                         2
# Ganaura Ghanajeevamrit FYM                    2
# Ghanajeevamrit Ganaura FYM                    1
# Ghanajeevamrit FYM Ganaura                    1
# Ganaura Pranamrit FYM                         1
# Ganaura Pranamrit                             1
# Ganaura FYM PoultryManure VermiCompost        1
# Ganaura VermiCompost FYM                      1
# FYM Ghanajeevamrit                            1
# Ganaura Ghanajeevamrit VermiCompost           1
# Ganaura FYM PoultryManure                     1
# Jeevamrit                                     1
# FYM Ganaura VermiCompost                      1
# Pranamrit                                     1
# Ganaura FYM Ghanajeevamrit VermiCompost       1
# Name: count, dtype: int64
#
#
# PCropSolidOrgFertAppMethod
# SoilApplied        1680
# Broadcasting        841
# RootApplication       9
# Spray                 3
# Name: count, dtype: int64
#
#
# CropbasalFerts
# DAP Urea             1640
# DAP                  1379
# Urea                  308
# None                  188
# Urea DAP              134
# DAP Other              70
# DAP Urea SSP           51
# NPK                    29
# DAP Urea NPKS          18
# NPK Urea                8
# Urea DAP SSP            7
# Urea NPKS               6
# Urea DAP NPKS           3
# DAP NPKS                3
# DAP SSP                 3
# Urea NPKS DAP           3
# DAP NPK Urea            2
# DAP Urea NPK            1
# Urea DAP MoP            1
# SSP Urea                1
# NPKS                    1
# DAP NPKS Urea           1
# NPKS DAP Urea           1
# DAP Urea NPKS MoP       1
# DAP NPKS Urea SSP       1
# Urea SSP                1
# Urea NPK                1
# DAP NPKS Other          1
# NPK DAP Urea            1
# DAP Urea SSP MoP        1
# DAP MoP                 1
# DAP Urea NPKS SSP       1
# DAP Urea MoP            1
# Urea SSP DAP            1
# Urea Other DAP          1
# Name: count, dtype: int64
#
#
# MineralFertAppMethod_1
# Broadcasting       3214
# SoilApplied         638
# RootApplication      18
# Name: count, dtype: int64
#
#
# FirstTopDressFert
# Urea            2798
# None             485
# DAP Urea         322
# Urea DAP         177
# DAP               64
# NPKS Urea          6
# Urea NPKS          5
# NPK                3
# DAP NPKS           3
# NPK Urea           2
# DAP NPK Urea       1
# Urea NPK           1
# DAP NPK            1
# Urea SSP           1
# Other Urea         1
# Name: count, dtype: int64
#
#
# MineralFertAppMethod_2
# Broadcasting       3288
# SoilApplied          64
# RootApplication      37
# Name: count, dtype: int64
#
#
# Harv_method
# hand       3642
# machine     228
# Name: count, dtype: int64
#
#
# Threshing_method
# machine    2098
# hand       1772
# Name: count, dtype: int64
#
#
# Stubble_use
# plowed_in_soil    3846
# burned              24
# Name: count, dtype: int64
#
#
# TpIrrigationSource_Imputed
# Boring      3343
# Canal        373
# Rainfed      103
# Pond          36
# TubeWell      12
# Well           3
# Name: count, dtype: int64
#
#
# TpIrrigationPowerSource_Imputed
# Electric    3148
# Diesel       720
# Solar          2
# Name: count, dtype: int64
