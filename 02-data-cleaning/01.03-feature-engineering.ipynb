# %% [markdown]
# <a href="https://colab.research.google.com/github/rapsoj/crop-yield-estimate/blob/main/01.02-feature-engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #01.02 Feature Engineering
# Creating new features to improve predictions for the Digital Green Crop Yield Estimate Challenge.

# %% [markdown]
# # Prepare Workspace

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('cleaned_fulldf.csv')

# %%
data.head()
# Out:
#                 ID    Set District      Block  CultLand CropTillageDate  \
# 0  ID_GTFAC7PEVWQ9  train  Nalanda  Noorsarai        45      2022-07-20
# 1  ID_TK40ARLSPOKS  train  Nalanda     Rajgir        26      2022-07-18
# 2  ID_1FJY2CRIMLZZ  train     Gaya      Gurua        10      2022-06-30
# 3  ID_I3IPXS4DB7NE  train     Gaya      Gurua        15      2022-06-16
# 4  ID_4T8YQWXWHB4A  train  Nalanda  Noorsarai        60      2022-07-19
#
#   CropTillageMonth  CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0             July                 5  Manual_PuddledRandom    2022-06-27
# 1             July                 5  Manual_PuddledRandom    2022-06-20
# 2             June                 6  Manual_PuddledRandom    2022-06-20
# 3             June                 6  Manual_PuddledRandom    2022-06-17
# 4             July                 4  Manual_PuddledRandom    2022-06-21
#
#   NursingMonth SeedingSowingTransplanting SowTransplantMonth  SeedlingsPerPit  \
# 0         June                 2022-07-21               July              2.0
# 1         June                 2022-07-20               July              2.0
# 2         June                 2022-08-13             August              2.0
# 3         June                 2022-07-17               July              2.0
# 4         June                 2022-07-20               July              2.0
#
#    TransplantingIrrigationHours TransplantingIrrigationSource  \
# 0                           5.0                        Boring
# 1                           5.0                        Boring
# 2                           4.0                        Boring
# 3                           4.0                        Boring
# 4                           9.0                        Boring
#
#   TransplantingIrrigationPowerSource  TransIrriCost  TransIrriCost_per_Acre  \
# 0                           Electric          200.0                   640.0
# 1                           Electric          125.0                   400.0
# 2                           Electric           80.0                   540.0
# 3                                NaN          250.0                  1125.0
# 4                           Electric          300.0                   640.0
#
#    StandingWater  Ganaura  Ganaura_capped  Ganaura_per_Acre  CropOrgFYM  \
# 0            2.0      0.0             0.0              0.00         0.0
# 1            3.0      0.0             0.0              0.00         0.0
# 2            2.0      1.0             1.0              6.75         1.0
# 3            NaN      1.0             1.0              4.50         0.0
# 4            2.0      0.0             0.0              0.00         0.0
#
#    CropOrgFYM_per_Acre PCropSolidOrgFertAppMethod  NoFertilizerAppln  \
# 0                 0.00                        NaN                  2
# 1                 0.00                        NaN                  2
# 2                 6.75                SoilApplied                  2
# 3                 0.00                SoilApplied                  2
# 4                 0.00                        NaN                  2
#
#    BasalDAP  BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre  \
# 0       0.0                0.0       20.0                64.0
# 1      15.0               48.0       10.0                32.0
# 2       4.0               27.0        0.0                 0.0
# 3       6.0               27.0        3.0                13.5
# 4      15.0               32.0       30.0                64.0
#
#   MineralFertAppMethod  1tdUrea  1tdUrea_per_Acre  1appDaysUrea  2tdUrea  \
# 0         Broadcasting     15.0             48.00          18.0      0.0
# 1         Broadcasting     20.0             64.00          39.0      0.0
# 2          SoilApplied      5.0             33.75          65.0      0.0
# 3         Broadcasting      5.0             22.50           5.0      0.0
# 4         Broadcasting     30.0             64.00          26.0      0.0
#
#    2tdUrea_per_Acre  2appDaysUrea MineralFertAppMethod.1 Harv_method  \
# 0               0.0           NaN           Broadcasting     machine
# 1               0.0           NaN           Broadcasting        hand
# 2               0.0           NaN        RootApplication        hand
# 3               0.0           NaN           Broadcasting        hand
# 4               0.0           NaN           Broadcasting     machine
#
#     Harv_date HarvestMonth  Harv_hand_rent  Harv_hand_rent_per_Acre  \
# 0  2022-11-16     November             0.0                      0.0
# 1  2022-11-25     November             3.0                      9.6
# 2  2022-12-12     December           480.0                   3240.0
# 3  2022-12-02     December           240.0                   1080.0
# 4  2022-11-30     November             0.0                      0.0
#
#   Threshing_date ThreshingMonth Threshing_method  Residue_length  \
# 0     2022-11-16       November          machine              30
# 1     2022-12-24       December          machine              24
# 2     2023-01-11        January          machine              30
# 3     2022-12-29       December             hand              26
# 4     2022-12-02       December          machine              24
#
#    Residue_perc     Stubble_use      Acre  Yield  Yield_per_Acre  \
# 0            40  plowed_in_soil  0.312500    600     1920.000000
# 1            10  plowed_in_soil  0.312500    600     1920.000000
# 2            10  plowed_in_soil  0.148148    225     1518.750000
# 3            10  plowed_in_soil  0.222222    468     2106.000000
# 4            40  plowed_in_soil  0.468750    550     1173.333333
#
#    LandPrepMethod_TractorPlough  LandPrepMethod_FourWheelTracRotavator  \
# 0                          True                                   True
# 1                          True                                   True
# 2                          True                                   True
# 3                          True                                   True
# 4                          True                                  False
#
#    LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 0                              False                         False
# 1                               True                         False
# 2                              False                         False
# 3                              False                         False
# 4                               True                         False
#
#    LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 0                 False                        True
# 1                 False                        True
# 2                 False                       False
# 3                 False                        True
# 4                 False                        True
#
#    NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 0                            False                                  True
# 1                             True                                  True
# 2                             True                                  True
# 3                             True                                  True
# 4                            False                                  True
#
#    NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 0                             False                            True
# 1                              True                            True
# 2                              True                           False
# 3                              True                            True
# 4                             False                            True
#
#    TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 0                              False                         True
# 1                              False                         True
# 2                              False                        False
# 3                              False                         True
# 4                              False                        False
#
#    TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 0                        True                                   True
# 1                        True                                   True
# 2                       False                                   True
# 3                        True                                   True
# 4                        True                                   True
#
#    TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 0                        True                 True               False
# 1                        True                 True                True
# 2                        True                False                True
# 3                        True                 True                True
# 4                        True                 True                True
#
#    CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 0                 False               False               False
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#    CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 0                    True                  False                  False
# 1                    True                  False                  False
# 2                    True                  False                  False
# 3                    True                  False                  False
# 4                    True                  False                  False
#
#    FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 0                   False                  False                    False
# 1                   False                  False                    False
# 2                   False                  False                    False
# 3                   False                  False                    False
# 4                   False                  False                    False
#
#    OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 0                   False               False                        False
# 1                   False               False                        False
# 2                    True                True                        False
# 3                    True               False                        False
# 4                   False               False                        False
#
#    OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 0                     False                          False
# 1                     False                          False
# 2                     False                          False
# 3                     False                          False
# 4                     False                          False
#
#    OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  \
# 0                     False                         False
# 1                     False                         False
# 2                     False                         False
# 3                     False                         False
# 4                     False                         False
#
#    Days_bw_Nurs_SowTransp  Days_bw_SowTransp_Harv  Days_bw_Harv_Thresh  \
# 0                    24.0                   118.0                  0.0
# 1                    30.0                   128.0                 29.0
# 2                    54.0                   121.0                 30.0
# 3                    30.0                   138.0                 27.0
# 4                    29.0                   133.0                  2.0
#
#    Days_bw_Nurs_Harv  Nb_of_NaN
# 0              142.0          2
# 1              158.0          2
# 2              175.0          1
# 3              168.0          6
# 4              162.0          2

# %% [markdown]
# ### Perform Feature Engineering

# %%
# Create feature for past month yield per acre 'Past_Yield_per_Acre'
data['Harv_date'] = pd.to_datetime(data['Harv_date'])
data.sort_values(['District', 'Harv_date'], inplace=True)

# Group the DataFrame by 'District' and calculate the rolling average
data['Past_YpA_Avg'] = data.groupby('District')['Yield_per_Acre'].rolling(
    window = 30).mean().reset_index(0, drop=True)

# Fill NaN values in the 'past_month_avg' column with 0 if needed
data['Past_YpA_Avg'].fillna(0, inplace=True)

# %%
# Create feature for days between harvesting and threshing 'Days_Harv_Thresh'
data['Threshing_date'] = pd.to_datetime(data['Threshing_date'])
data['Days_Harv_Thresh'] = (
    data['Threshing_date'] - data['Harv_date']).dt.days

# %%
data.head()
# Out:
#                    ID    Set District      Block  CultLand CropTillageDate  \
# 1201  ID_OEGIGBAY4B8L  train     Gaya  Wazirganj        30      2022-06-28
# 5071  ID_OEGIGBAY4B8L   test     Gaya  Wazirganj        30      2022-06-28
# 3298  ID_ECOLA7UOIRKC  train     Gaya  Wazirganj        50      2022-07-01
# 3649  ID_T882H8WXTQWU  train     Gaya  Wazirganj        40      2022-06-28
# 7168  ID_ECOLA7UOIRKC   test     Gaya  Wazirganj        50      2022-07-01
#
#      CropTillageMonth  CropTillageDepth         CropEstMethod RcNursEstDate  \
# 1201             June                 4  Manual_PuddledRandom    2022-06-20
# 5071             June                 4  Manual_PuddledRandom    2022-06-20
# 3298             July                 5  Manual_PuddledRandom    2022-06-25
# 3649             June                 5  Manual_PuddledRandom    2022-06-28
# 7168             July                 5  Manual_PuddledRandom    2022-06-25
#
#      NursingMonth SeedingSowingTransplanting SowTransplantMonth  \
# 1201         June                 2022-07-23               July
# 5071         June                 2022-07-23               July
# 3298         June                 2022-07-28               July
# 3649         June                 2022-07-26               July
# 7168         June                 2022-07-28               July
#
#       SeedlingsPerPit  TransplantingIrrigationHours  \
# 1201              3.0                           6.0
# 5071              3.0                           6.0
# 3298              4.0                           5.0
# 3649              2.0                           8.0
# 7168              4.0                           5.0
#
#      TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# 1201                        Boring                             Diesel
# 5071                        Boring                             Diesel
# 3298                         Canal                                NaN
# 3649                        Boring                           Electric
# 7168                         Canal                                NaN
#
#       TransIrriCost  TransIrriCost_per_Acre  StandingWater  Ganaura  \
# 1201          100.0                   270.0            2.0      0.0
# 5071          100.0                   270.0            2.0      0.0
# 3298            0.0                     0.0            2.0      0.0
# 3649           80.0                   270.0            2.0      0.0
# 7168            0.0                     0.0            2.0      0.0
#
#       Ganaura_capped  Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 1201             0.0               0.0         4.0               10.800
# 5071             0.0               0.0         4.0               10.800
# 3298             0.0               0.0         0.0                0.000
# 3649             0.0               0.0         3.0               10.125
# 7168             0.0               0.0         0.0                0.000
#
#      PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  \
# 1201                SoilApplied                  2      10.0
# 5071                SoilApplied                  2      10.0
# 3298                        NaN                  2      12.0
# 3649                SoilApplied                  2       8.0
# 7168                        NaN                  2      12.0
#
#       BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  \
# 1201               27.0       10.0                27.0         Broadcasting
# 5071               27.0       10.0                27.0         Broadcasting
# 3298               27.0       12.0                27.0         Broadcasting
# 3649               27.0        8.0                27.0         Broadcasting
# 7168               27.0       12.0                27.0         Broadcasting
#
#       1tdUrea  1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  \
# 1201     15.0              40.5          45.0      0.0               0.0
# 5071     15.0              40.5          45.0      0.0               0.0
# 3298     18.0              40.5          45.0      0.0               0.0
# 3649     12.0              40.5          45.0      0.0               0.0
# 7168     18.0              40.5          45.0      0.0               0.0
#
#       2appDaysUrea MineralFertAppMethod.1 Harv_method  Harv_date HarvestMonth  \
# 1201           NaN           Broadcasting        hand 2022-10-08      October
# 5071           NaN           Broadcasting        hand 2022-10-08      October
# 3298           NaN           Broadcasting        hand 2022-10-10      October
# 3649           NaN           Broadcasting        hand 2022-10-10      October
# 7168           NaN           Broadcasting        hand 2022-10-10      October
#
#       Harv_hand_rent  Harv_hand_rent_per_Acre Threshing_date ThreshingMonth  \
# 1201           100.0                    270.0     2022-10-22        October
# 5071           100.0                    270.0     2022-10-22        October
# 3298           100.0                    225.0     2022-10-27        October
# 3649           100.0                    337.5     2022-10-28        October
# 7168           100.0                    225.0     2022-10-27        October
#
#      Threshing_method  Residue_length  Residue_perc     Stubble_use      Acre  \
# 1201          machine              25            10  plowed_in_soil  0.370370
# 5071          machine              25            10  plowed_in_soil  0.370370
# 3298          machine              25            10  plowed_in_soil  0.444444
# 3649             hand              25            10  plowed_in_soil  0.296296
# 7168          machine              25            10  plowed_in_soil  0.444444
#
#       Yield  Yield_per_Acre  LandPrepMethod_TractorPlough  \
# 1201    800          2160.0                         False
# 5071    800          2160.0                         False
# 3298    960          2160.0                         False
# 3649    640          2160.0                         False
# 7168    960          2160.0                         False
#
#       LandPrepMethod_FourWheelTracRotavator  \
# 1201                                   True
# 5071                                   True
# 3298                                   True
# 3649                                   True
# 7168                                   True
#
#       LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 1201                               True                         False
# 5071                               True                         False
# 3298                               True                         False
# 3649                               True                         False
# 7168                               True                         False
#
#       LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 1201                 False                        True
# 5071                 False                        True
# 3298                 False                        True
# 3649                 False                        True
# 7168                 False                        True
#
#       NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 1201                             True                                  True
# 5071                             True                                  True
# 3298                             True                                  True
# 3649                             True                                  True
# 7168                             True                                  True
#
#       NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 1201                             False                            True
# 5071                             False                            True
# 3298                             False                            True
# 3649                             False                            True
# 7168                             False                            True
#
#       TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 1201                              False                         True
# 5071                              False                         True
# 3298                              False                         True
# 3649                              False                         True
# 7168                              False                         True
#
#       TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 1201                        True                                   True
# 5071                        True                                   True
# 3298                        True                                   True
# 3649                        True                                   True
# 7168                        True                                   True
#
#       TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 1201                        True                 True                True
# 5071                        True                 True                True
# 3298                        True                 True                True
# 3649                        True                 True                True
# 7168                        True                 True                True
#
#       CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 1201                 False               False               False
# 5071                 False               False               False
# 3298                 False               False               False
# 3649                 False               False               False
# 7168                 False               False               False
#
#       CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 1201                False               False                False
# 5071                False               False                False
# 3298                False               False                False
# 3649                False               False                False
# 7168                False               False                False
#
#       FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 1201                    True                  False                  False
# 5071                    True                  False                  False
# 3298                    True                  False                  False
# 3649                    True                  False                  False
# 7168                    True                  False                  False
#
#       FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 1201                   False                  False                    False
# 5071                   False                  False                    False
# 3298                   False                  False                    False
# 3649                   False                  False                    False
# 7168                   False                  False                    False
#
#       OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 1201                   False                True                        False
# 5071                   False                True                        False
# 3298                   False               False                        False
# 3649                   False                True                        False
# 7168                   False               False                        False
#
#       OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 1201                     False                          False
# 5071                     False                          False
# 3298                     False                          False
# 3649                     False                          False
# 7168                     False                          False
#
#       OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  \
# 1201                     False                         False
# 5071                     False                         False
# 3298                     False                         False
# 3649                     False                         False
# 7168                     False                         False
#
#       Days_bw_Nurs_SowTransp  Days_bw_SowTransp_Harv  Days_bw_Harv_Thresh  \
# 1201                    33.0                    77.0                 14.0
# 5071                    33.0                    77.0                 14.0
# 3298                    33.0                    74.0                 17.0
# 3649                    28.0                    76.0                 18.0
# 7168                    33.0                    74.0                 17.0
#
#       Days_bw_Nurs_Harv  Nb_of_NaN  Past_YpA_Avg
# 1201              110.0          1           0.0
# 5071              110.0          1           0.0
# 3298              107.0          4           0.0
# 3649              104.0          1           0.0
# 7168              107.0          4           0.0

# %%
# Function to assign season based on month names for India's climatic pattern
def assign_season(month_name):
    if month_name in ['June', 'July', 'August', 'September']:  # Monsoon season
        return 'Monsoon'
    elif month_name in ['October', 'November', 'December']:  # Post-Monsoon season
        return 'Post-Monsoon'
    elif month_name in ['January', 'February', 'March']:  # Winter season
        return 'Winter'
    elif month_name in ['April', 'May']:  # Summer season
        return 'Summer'

# %%
# Apply the function to assign season
data['Season'] = data['CropTillageMonth'].apply(assign_season)

data[['CropTillageDate', 'Season']].head()  # Displaying the first few rows for verification
# Out:
#      CropTillageDate   Season
# 1201      2022-06-28  Monsoon
# 5071      2022-06-28  Monsoon
# 3298      2022-07-01  Monsoon
# 3649      2022-06-28  Monsoon
# 7168      2022-07-01  Monsoon

# %%
data['Season'].value_counts()  # Count of each season
# Out:
# Season
# Monsoon    7738
# Summer        2
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['ID', 'Set', 'District', 'Block', 'CultLand', 'CropTillageDate',
#        'CropTillageMonth', 'CropTillageDepth', 'CropEstMethod',
#        'RcNursEstDate', 'NursingMonth', 'SeedingSowingTransplanting',
#        'SowTransplantMonth', 'SeedlingsPerPit', 'TransplantingIrrigationHours',
#        'TransplantingIrrigationSource', 'TransplantingIrrigationPowerSource',
#        'TransIrriCost', 'TransIrriCost_per_Acre', 'StandingWater', 'Ganaura',
#        'Ganaura_capped', 'Ganaura_per_Acre', 'CropOrgFYM',
#        'CropOrgFYM_per_Acre', 'PCropSolidOrgFertAppMethod',
#        'NoFertilizerAppln', 'BasalDAP', 'BasalDAP_per_Acre', 'BasalUrea',
#        'BasalUrea_per_Acre', 'MineralFertAppMethod', '1tdUrea',
#        '1tdUrea_per_Acre', '1appDaysUrea', '2tdUrea', '2tdUrea_per_Acre',
#        '2appDaysUrea', 'MineralFertAppMethod.1', 'Harv_method', 'Harv_date',
#        'HarvestMonth', 'Harv_hand_rent', 'Harv_hand_rent_per_Acre',
#        'Threshing_date', 'ThreshingMonth', 'Threshing_method',
#        'Residue_length', 'Residue_perc', 'Stubble_use', 'Acre', 'Yield',
#        'Yield_per_Acre', 'LandPrepMethod_TractorPlough',
#        'LandPrepMethod_FourWheelTracRotavator',
#        'LandPrepMethod_WetTillagePuddling', 'LandPrepMethod_BullockPlough',
#        'LandPrepMethod_Other', 'NursDetFactor_CalendarDate',
#        'NursDetFactor_PreMonsoonShowers',
#        'NursDetFactor_IrrigWaterAvailability',
#        'NursDetFactor_LabourAvailability', 'NursDetFactor_SeedAvailability',
#        'TransDetFactor_LabourAvailability', 'TransDetFactor_CalendarDate',
#        'TransDetFactor_RainArrival', 'TransDetFactor_IrrigWaterAvailability',
#        'TransDetFactor_SeedlingAge', 'CropbasalFerts_Urea',
#        'CropbasalFerts_DAP', 'CropbasalFerts_Other', 'CropbasalFerts_NPK',
#        'CropbasalFerts_MoP', 'CropbasalFerts_NPKS', 'CropbasalFerts_SSP',
#        'CropbasalFerts_None', 'FirstTopDressFert_Urea',
#        'FirstTopDressFert_DAP', 'FirstTopDressFert_NPK',
#        'FirstTopDressFert_NPKS', 'FirstTopDressFert_SSP',
#        'FirstTopDressFert_Other', 'OrgFertilizers_Ganaura',
#        'OrgFertilizers_FYM', 'OrgFertilizers_VermiCompost',
#        'OrgFertilizers_Pranamrit', 'OrgFertilizers_Ghanajeevamrit',
#        'OrgFertilizers_Jeevamrit', 'OrgFertilizers_PoultryManure',
#        'Days_bw_Nurs_SowTransp', 'Days_bw_SowTransp_Harv',
#        'Days_bw_Harv_Thresh', 'Days_bw_Nurs_Harv', 'Nb_of_NaN', 'Past_YpA_Avg',
#        'Season'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', None)

# %%
data['harvest-thresh-duration'] = (data['Threshing_date'] - data['CropTillageDate']).dt.days

# %%
data['Harv_date']
# Out:
# 1201   2022-10-08
# 5071   2022-10-08
# 3298   2022-10-10
# 3649   2022-10-10
# 7168   2022-10-10
#           ...
# 7005   2022-11-23
# 7163   2022-11-23
# 7685   2022-11-23
# 974    2023-02-02
# 4844   2023-02-02
# Name: Harv_date, Length: 7740, dtype: datetime64[ns]

# %%
data['tillage-harvest-duration'] = (data['Harv_date'] - data['CropTillageDate']).dt.days

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
data.isna().sum()
# View all rows and columns
# Out:
# ID                                          0
# Set                                         0
# District                                    0
# Block                                       0
# CultLand                                    0
# CropTillageDate                             0
# CropTillageMonth                            0
# CropTillageDepth                            0
# CropEstMethod                               0
# RcNursEstDate                             166
# NursingMonth                              166
# SeedingSowingTransplanting                  0
# SowTransplantMonth                          0
# SeedlingsPerPit                           578
# TransplantingIrrigationHours                0
# TransplantingIrrigationSource               0
# TransplantingIrrigationPowerSource       1006
# TransIrriCost                               0
# TransIrriCost_per_Acre                      0
# StandingWater                             476
# Ganaura                                     0
# Ganaura_capped                              0
# Ganaura_per_Acre                            0
# CropOrgFYM                                  0
# CropOrgFYM_per_Acre                         0
# PCropSolidOrgFertAppMethod               2674
# NoFertilizerAppln                           0
# BasalDAP                                    0
# BasalDAP_per_Acre                           0
# BasalUrea                                   0
# BasalUrea_per_Acre                          0
# MineralFertAppMethod                        0
# 1tdUrea                                     0
# 1tdUrea_per_Acre                            0
# 1appDaysUrea                             1112
# 2tdUrea                                     0
# 2tdUrea_per_Acre                            0
# 2appDaysUrea                             5388
# MineralFertAppMethod.1                    962
# Harv_method                                 0
# Harv_date                                   0
# HarvestMonth                                0
# Harv_hand_rent                              0
# Harv_hand_rent_per_Acre                     0
# Threshing_date                              0
# ThreshingMonth                              0
# Threshing_method                            0
# Residue_length                              0
# Residue_perc                                0
# Stubble_use                                 0
# Acre                                        0
# Yield                                       0
# Yield_per_Acre                              0
# LandPrepMethod_TractorPlough                0
# LandPrepMethod_FourWheelTracRotavator       0
# LandPrepMethod_WetTillagePuddling           0
# LandPrepMethod_BullockPlough                0
# LandPrepMethod_Other                        0
# NursDetFactor_CalendarDate                  0
# NursDetFactor_PreMonsoonShowers             0
# NursDetFactor_IrrigWaterAvailability        0
# NursDetFactor_LabourAvailability            0
# NursDetFactor_SeedAvailability              0
# TransDetFactor_LabourAvailability           0
# TransDetFactor_CalendarDate                 0
# TransDetFactor_RainArrival                  0
# TransDetFactor_IrrigWaterAvailability       0
# TransDetFactor_SeedlingAge                  0
# CropbasalFerts_Urea                         0
# CropbasalFerts_DAP                          0
# CropbasalFerts_Other                        0
# CropbasalFerts_NPK                          0
# CropbasalFerts_MoP                          0
# CropbasalFerts_NPKS                         0
# CropbasalFerts_SSP                          0
# CropbasalFerts_None                         0
# FirstTopDressFert_Urea                      0
# FirstTopDressFert_DAP                       0
# FirstTopDressFert_NPK                       0
# FirstTopDressFert_NPKS                      0
# FirstTopDressFert_SSP                       0
# FirstTopDressFert_Other                     0
# OrgFertilizers_Ganaura                      0
# OrgFertilizers_FYM                          0
# OrgFertilizers_VermiCompost                 0
# OrgFertilizers_Pranamrit                    0
# OrgFertilizers_Ghanajeevamrit               0
# OrgFertilizers_Jeevamrit                    0
# OrgFertilizers_PoultryManure                0
# Days_bw_Nurs_SowTransp                    166
# Days_bw_SowTransp_Harv                      0
# Days_bw_Harv_Thresh                         0
# Days_bw_Nurs_Harv                           0
# Nb_of_NaN                                   0
# Past_YpA_Avg                                0
# Season                                      0
# tillage-harvest-duration                    0
# harvest-thresh-duration                     0
# dtype: int64

# %%
pd.set_option('display.max_rows', 10)
data.head()
# Out:
#                    ID    Set District      Block  CultLand CropTillageDate  \
# 1201  ID_OEGIGBAY4B8L  train     Gaya  Wazirganj        30      2022-06-28
# 5071  ID_OEGIGBAY4B8L   test     Gaya  Wazirganj        30      2022-06-28
# 3298  ID_ECOLA7UOIRKC  train     Gaya  Wazirganj        50      2022-07-01
# 3649  ID_T882H8WXTQWU  train     Gaya  Wazirganj        40      2022-06-28
# 7168  ID_ECOLA7UOIRKC   test     Gaya  Wazirganj        50      2022-07-01
#
#      CropTillageMonth  CropTillageDepth         CropEstMethod RcNursEstDate  \
# 1201             June                 4  Manual_PuddledRandom    2022-06-20
# 5071             June                 4  Manual_PuddledRandom    2022-06-20
# 3298             July                 5  Manual_PuddledRandom    2022-06-25
# 3649             June                 5  Manual_PuddledRandom    2022-06-28
# 7168             July                 5  Manual_PuddledRandom    2022-06-25
#
#      NursingMonth SeedingSowingTransplanting SowTransplantMonth  \
# 1201         June                 2022-07-23               July
# 5071         June                 2022-07-23               July
# 3298         June                 2022-07-28               July
# 3649         June                 2022-07-26               July
# 7168         June                 2022-07-28               July
#
#       SeedlingsPerPit  TransplantingIrrigationHours  \
# 1201              3.0                           6.0
# 5071              3.0                           6.0
# 3298              4.0                           5.0
# 3649              2.0                           8.0
# 7168              4.0                           5.0
#
#      TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# 1201                        Boring                             Diesel
# 5071                        Boring                             Diesel
# 3298                         Canal                                NaN
# 3649                        Boring                           Electric
# 7168                         Canal                                NaN
#
#       TransIrriCost  TransIrriCost_per_Acre  StandingWater  Ganaura  \
# 1201          100.0                   270.0            2.0      0.0
# 5071          100.0                   270.0            2.0      0.0
# 3298            0.0                     0.0            2.0      0.0
# 3649           80.0                   270.0            2.0      0.0
# 7168            0.0                     0.0            2.0      0.0
#
#       Ganaura_capped  Ganaura_per_Acre  CropOrgFYM  CropOrgFYM_per_Acre  \
# 1201             0.0               0.0         4.0               10.800
# 5071             0.0               0.0         4.0               10.800
# 3298             0.0               0.0         0.0                0.000
# 3649             0.0               0.0         3.0               10.125
# 7168             0.0               0.0         0.0                0.000
#
#      PCropSolidOrgFertAppMethod  NoFertilizerAppln  BasalDAP  \
# 1201                SoilApplied                  2      10.0
# 5071                SoilApplied                  2      10.0
# 3298                        NaN                  2      12.0
# 3649                SoilApplied                  2       8.0
# 7168                        NaN                  2      12.0
#
#       BasalDAP_per_Acre  BasalUrea  BasalUrea_per_Acre MineralFertAppMethod  \
# 1201               27.0       10.0                27.0         Broadcasting
# 5071               27.0       10.0                27.0         Broadcasting
# 3298               27.0       12.0                27.0         Broadcasting
# 3649               27.0        8.0                27.0         Broadcasting
# 7168               27.0       12.0                27.0         Broadcasting
#
#       1tdUrea  1tdUrea_per_Acre  1appDaysUrea  2tdUrea  2tdUrea_per_Acre  \
# 1201     15.0              40.5          45.0      0.0               0.0
# 5071     15.0              40.5          45.0      0.0               0.0
# 3298     18.0              40.5          45.0      0.0               0.0
# 3649     12.0              40.5          45.0      0.0               0.0
# 7168     18.0              40.5          45.0      0.0               0.0
#
#       2appDaysUrea MineralFertAppMethod.1 Harv_method  Harv_date HarvestMonth  \
# 1201           NaN           Broadcasting        hand 2022-10-08      October
# 5071           NaN           Broadcasting        hand 2022-10-08      October
# 3298           NaN           Broadcasting        hand 2022-10-10      October
# 3649           NaN           Broadcasting        hand 2022-10-10      October
# 7168           NaN           Broadcasting        hand 2022-10-10      October
#
#       Harv_hand_rent  Harv_hand_rent_per_Acre Threshing_date ThreshingMonth  \
# 1201           100.0                    270.0     2022-10-22        October
# 5071           100.0                    270.0     2022-10-22        October
# 3298           100.0                    225.0     2022-10-27        October
# 3649           100.0                    337.5     2022-10-28        October
# 7168           100.0                    225.0     2022-10-27        October
#
#      Threshing_method  Residue_length  Residue_perc     Stubble_use      Acre  \
# 1201          machine              25            10  plowed_in_soil  0.370370
# 5071          machine              25            10  plowed_in_soil  0.370370
# 3298          machine              25            10  plowed_in_soil  0.444444
# 3649             hand              25            10  plowed_in_soil  0.296296
# 7168          machine              25            10  plowed_in_soil  0.444444
#
#       Yield  Yield_per_Acre  LandPrepMethod_TractorPlough  \
# 1201    800          2160.0                         False
# 5071    800          2160.0                         False
# 3298    960          2160.0                         False
# 3649    640          2160.0                         False
# 7168    960          2160.0                         False
#
#       LandPrepMethod_FourWheelTracRotavator  \
# 1201                                   True
# 5071                                   True
# 3298                                   True
# 3649                                   True
# 7168                                   True
#
#       LandPrepMethod_WetTillagePuddling  LandPrepMethod_BullockPlough  \
# 1201                               True                         False
# 5071                               True                         False
# 3298                               True                         False
# 3649                               True                         False
# 7168                               True                         False
#
#       LandPrepMethod_Other  NursDetFactor_CalendarDate  \
# 1201                 False                        True
# 5071                 False                        True
# 3298                 False                        True
# 3649                 False                        True
# 7168                 False                        True
#
#       NursDetFactor_PreMonsoonShowers  NursDetFactor_IrrigWaterAvailability  \
# 1201                             True                                  True
# 5071                             True                                  True
# 3298                             True                                  True
# 3649                             True                                  True
# 7168                             True                                  True
#
#       NursDetFactor_LabourAvailability  NursDetFactor_SeedAvailability  \
# 1201                             False                            True
# 5071                             False                            True
# 3298                             False                            True
# 3649                             False                            True
# 7168                             False                            True
#
#       TransDetFactor_LabourAvailability  TransDetFactor_CalendarDate  \
# 1201                              False                         True
# 5071                              False                         True
# 3298                              False                         True
# 3649                              False                         True
# 7168                              False                         True
#
#       TransDetFactor_RainArrival  TransDetFactor_IrrigWaterAvailability  \
# 1201                        True                                   True
# 5071                        True                                   True
# 3298                        True                                   True
# 3649                        True                                   True
# 7168                        True                                   True
#
#       TransDetFactor_SeedlingAge  CropbasalFerts_Urea  CropbasalFerts_DAP  \
# 1201                        True                 True                True
# 5071                        True                 True                True
# 3298                        True                 True                True
# 3649                        True                 True                True
# 7168                        True                 True                True
#
#       CropbasalFerts_Other  CropbasalFerts_NPK  CropbasalFerts_MoP  \
# 1201                 False               False               False
# 5071                 False               False               False
# 3298                 False               False               False
# 3649                 False               False               False
# 7168                 False               False               False
#
#       CropbasalFerts_NPKS  CropbasalFerts_SSP  CropbasalFerts_None  \
# 1201                False               False                False
# 5071                False               False                False
# 3298                False               False                False
# 3649                False               False                False
# 7168                False               False                False
#
#       FirstTopDressFert_Urea  FirstTopDressFert_DAP  FirstTopDressFert_NPK  \
# 1201                    True                  False                  False
# 5071                    True                  False                  False
# 3298                    True                  False                  False
# 3649                    True                  False                  False
# 7168                    True                  False                  False
#
#       FirstTopDressFert_NPKS  FirstTopDressFert_SSP  FirstTopDressFert_Other  \
# 1201                   False                  False                    False
# 5071                   False                  False                    False
# 3298                   False                  False                    False
# 3649                   False                  False                    False
# 7168                   False                  False                    False
#
#       OrgFertilizers_Ganaura  OrgFertilizers_FYM  OrgFertilizers_VermiCompost  \
# 1201                   False                True                        False
# 5071                   False                True                        False
# 3298                   False               False                        False
# 3649                   False                True                        False
# 7168                   False               False                        False
#
#       OrgFertilizers_Pranamrit  OrgFertilizers_Ghanajeevamrit  \
# 1201                     False                          False
# 5071                     False                          False
# 3298                     False                          False
# 3649                     False                          False
# 7168                     False                          False
#
#       OrgFertilizers_Jeevamrit  OrgFertilizers_PoultryManure  \
# 1201                     False                         False
# 5071                     False                         False
# 3298                     False                         False
# 3649                     False                         False
# 7168                     False                         False
#
#       Days_bw_Nurs_SowTransp  Days_bw_SowTransp_Harv  Days_bw_Harv_Thresh  \
# 1201                    33.0                    77.0                 14.0
# 5071                    33.0                    77.0                 14.0
# 3298                    33.0                    74.0                 17.0
# 3649                    28.0                    76.0                 18.0
# 7168                    33.0                    74.0                 17.0
#
#       Days_bw_Nurs_Harv  Nb_of_NaN  Past_YpA_Avg   Season  \
# 1201              110.0          1           0.0  Monsoon
# 5071              110.0          1           0.0  Monsoon
# 3298              107.0          4           0.0  Monsoon
# 3649              104.0          1           0.0  Monsoon
# 7168              107.0          4           0.0  Monsoon
#
#       tillage-harvest-duration  harvest-thresh-duration
# 1201                       102                      116
# 5071                       102                      116
# 3298                       101                      118
# 3649                       104                      122
# 7168                       101                      118

# %%
data['harvest-thresh-duration'].describe()
# Out:
# count    7740.000000
# mean      153.918863
# std        32.015432
# min        65.000000
# 25%       134.000000
# 50%       151.000000
# 75%       171.000000
# max       279.000000
# Name: harvest-thresh-duration, dtype: float64

# %%
data['tillage-harvest-duration'].describe()
# Out:
# count    7740.000000
# mean      124.058398
# std        18.935318
# min        61.000000
# 25%       111.000000
# 50%       125.000000
# 75%       135.000000
# max       250.000000
# Name: tillage-harvest-duration, dtype: float64
