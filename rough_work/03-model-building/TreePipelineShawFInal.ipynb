# %% [markdown]
# # DONT EDIT - MESSAGE TO MYSELF

# %%
# Import system libraries

import os
import sys

# Import data cleaning libraries
import pandas as pd
import numpy as np
import calendar
from datetime import datetime

# Import machine learning libraries
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from sklearn.ensemble import VotingRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
import xgboost as xgb

# Import data visualisation libraries
import matplotlib.pyplot as plt

# Import warning libraries
import warnings
warnings.filterwarnings("ignore")

# Set working directory
# Set this to your own path
os.chdir('/home/shaw/Documents/GitHub/crop-yield-estimate/')
# Set this to your own path
sys.path.insert(0, '/home/shaw/Documents/GitHub/crop-yield-estimate/pipeline')

# Import preprocessing libraries
from preprocessing import clustering
from preprocessing import dim_reduction
from preprocessing import feature_selection
from preprocessing import scaling
from preprocessing import feature_engineering
from preprocessing import cleaning

# Preprocess data
train_path = "data/Train.csv"
test_path = "data/Test.csv"
df = cleaning.clean_data(train_path, test_path)
df = feature_engineering.get_features(df)
df = scaling.scale_features(df)
df = feature_selection.select_features(df)
df = dim_reduction.reduce_dim(df)
df = clustering.get_clusters(df)


# Split data into training and test sets
df_train = df[df['Yield'].isna() == False]
df_test = df[df['Yield'].isna() == True]

# %%
top_cols = ['SeedlingsPerPit','Ganaura','CropOrgFYM','NoFertilizerAppln','BasalDAP',
            'BasalUrea','2appDaysUrea','Harv_hand_rent','Residue_length',
            'TransplantingIrrigationHours_per_Acre','TransIrriCost_per_Acre',
            'CropOrgFYM_per_Acre','BasalDAP_per_Acre','BasalUrea_per_Acre','1tdUrea_per_Acre',
            'Harv_hand_rent_per_Acre','TpIrrigationCost_Imputed_per_Acre',
            'Days_bw_SowTransp_Harv','Days_bw_Harv_Thresh','NursingDate_ModeDiff',
            'TillageDate_ModeDiff','HarvestDate_ModeDiff','ThreshingDate_ModeDiff',
            'Num_LandPrepMethod','Num_CropbasalFerts','Num_TopDressFert','Latitude',
            'Longitude','CropEstMethod_LineSowingAfterTillage','Threshing_method_machine',
            'Stubble_use_plowed_in_soil','LandPrepMethod_FourWheelTracRotavator_True',
            'LandPrepMethod_WetTillagePuddling_True','NursDetFactor_PreMonsoonShowers_True',
            'NursDetFactor_LabourAvailability_True','FirstTopDressFert_DAP_True',
            'HarvestMonth_November','ThreshingMonth_January','Block_Chehrakala',
            'PCropSolidOrgFertAppMethod_Broadcasting','PCropSolidOrgFertAppMethod_SoilApplied',
            'MineralFertAppMethod_1_Broadcasting','MineralFertAppMethod_1_SoilApplied','PC4',
            'PC10','PC21','top_shapley_k2_label_1', 'TpIrrigationHours_Imputed',
            'TpIrrigationCost_Imputed', 'SeedlingsPerPit_Imputed', 'NursingDate_ModeDiff_Imputed',
            '2appDaysUrea_Imputed']#,'Error_Prediction','Block_Prediction']#,'Linear_Yield_Prediction']

# Remove the specified columns from top_cols
columns_to_remove = ['SeedlingsPerPit', 'TransplantingIrrigationHours', 'TransIrriCost', 'StandingWater',
                     '1appDaysUrea', '2appDaysUrea', 'TransplantingIrrigationHours_per_Acre',
                     'TransIrriCost_per_Acre', 'TransplantingIrrigationHours_per_Acre_capped',
                     'TransIrriCost_per_Acre_capped', 'Days_bw_Nurs_SowTransp', 'Days_bw_Nurs_Harv',
                     'Days_bw_Nurs_Till', 'NursingDate_ModeDiff', 'Days_bw_Nurs_SowTransp_ModeDiff',
                     'Days_bw_Nurs_Harv_ModeDiff', 'Days_bw_Nurs_Till_ModeDiff', '2appDaysUrea_MeanDiff']

for column in columns_to_remove:
    if column in top_cols:
     top_cols.remove(column)

# %%
# Split data
outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
X = X[top_cols]


# Initialize an array to store fold-wise predictions
k = 5
fold_wise_predictions = np.zeros((len(df_test), k))

# Define number of splits for k-fold cross-validation
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# Iterate over each fold and train XGBoost model
for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Instantiate an XGBoost regressor model
    best_params = {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100,
                   'alpha': 0, 'lambda': 0}
    xgb_reg = xgb.XGBRegressor(**best_params, colsample_bytree=0.3)
#


    # Tuned Tree estimators
    lgbm = LGBMRegressor(boosting_type='goss', n_estimators=1000, learning_rate=0.08, num_leaves=100, max_depth=7)
    catboost = CatBoostRegressor(depth=10, iterations=1000, learning_rate=0.5, l2_leaf_reg=5)


    # Define the VotingRegressor
    voting_regressor = VotingRegressor(
        estimators=[
            ('lgbm', lgbm),
            ('catboost', catboost),
            ('xgboost', xgb_reg)
        ], weights=[2, 3, 1]
    )


    # Fit the model
    voting_regressor.fit(X_tr, y_tr)

    # Make predictions
    test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
    test_folds_pred = voting_regressor.predict(
        test_predictors) * df_test["Acre"]


    # Store fold-wise predictions
    fold_wise_predictions[:, i] = test_folds_pred

    
# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                 df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
    df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv('submission/SubmissionShawFinalRepeatTest.csv', index=False)

print("---Predictions made---")

# %% [markdown]
# # EDIT THIS ONE !!!!

# %%
import xgboost as xgb
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import VotingRegressor
import shap
from sklearn.svm import SVC
from sklearn.linear_model import SGDRegressor
from joblib import load

# Load the model
model = load(
    '/home/shaw/Documents/GitHub/crop-yield-estimate/stacked_regressor9072.410412769656.joblib')


# Split data
outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
X = X[top_cols]


# Initialize an array to store fold-wise predictions
k = 5
fold_wise_predictions = np.zeros((len(df_test), k))

# Define number of splits for k-fold cross-validation
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# Iterate over each fold and train XGBoost model
for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    

    # Fit the model
    model.fit(X_tr, y_tr)

    # Make predictions
    test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
    test_folds_pred = model.predict(
        test_predictors) * df_test["Acre"]

    # Store fold-wise predictions
    fold_wise_predictions[:, i] = test_folds_pred


# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                 df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
    df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv(
    'submission/SubmissionShawFinalRepeatTest.csv', index=False)

print("---Predictions made---")
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2722
# [LightGBM] [Info] Number of data points in the train set: 3096, number of used features: 47
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 1882.305577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 695:	learn: 1.3363103	total: 18.7s	remaining: 8.18s
# 696:	learn: 1.3329802	total: 18.8s	remaining: 8.15s
# 697:	learn: 1.3267505	total: 18.8s	remaining: 8.13s
# 698:	learn: 1.3181132	total: 18.8s	remaining: 8.1s
# 699:	learn: 1.3153400	total: 18.8s	remaining: 8.07s
# 700:	learn: 1.3068315	total: 18.9s	remaining: 8.05s
# 701:	learn: 1.2993148	total: 18.9s	remaining: 8.02s
# 702:	learn: 1.2943676	total: 18.9s	remaining: 7.99s
# 703:	learn: 1.2850085	total: 18.9s	remaining: 7.96s
# 704:	learn: 1.2807534	total: 19s	remaining: 7.94s
# 705:	learn: 1.2743923	total: 19s	remaining: 7.91s
# 706:	learn: 1.2685401	total: 19s	remaining: 7.88s
# 707:	learn: 1.2613918	total: 19.1s	remaining: 7.86s
# 708:	learn: 1.2463932	total: 19.1s	remaining: 7.83s
# 709:	learn: 1.2372713	total: 19.1s	remaining: 7.8s
# 710:	learn: 1.2354486	total: 19.1s	remaining: 7.77s
# 711:	learn: 1.2272770	total: 19.2s	remaining: 7.75s
# 712:	learn: 1.2203309	total: 19.2s	remaining: 7.72s
# 713:	learn: 1.2158611	total: 19.2s	remaining: 7.69s
# 714:	learn: 1.2109172	total: 19.2s	remaining: 7.66s
# 715:	learn: 1.2026438	total: 19.3s	remaining: 7.64s
# 716:	learn: 1.2011105	total: 19.3s	remaining: 7.62s
# 717:	learn: 1.2005323	total: 19.3s	remaining: 7.59s
# 718:	learn: 1.1984755	total: 19.4s	remaining: 7.56s
# 719:	learn: 1.1944798	total: 19.4s	remaining: 7.54s
# 720:	learn: 1.1856004	total: 19.4s	remaining: 7.51s
# 721:	learn: 1.1818997	total: 19.4s	remaining: 7.48s
# 722:	learn: 1.1780476	total: 19.5s	remaining: 7.45s
# 723:	learn: 1.1697634	total: 19.5s	remaining: 7.43s
# 724:	learn: 1.1661636	total: 19.5s	remaining: 7.4s
# 725:	learn: 1.1594537	total: 19.5s	remaining: 7.37s
# 726:	learn: 1.1541091	total: 19.6s	remaining: 7.34s
# 727:	learn: 1.1472696	total: 19.6s	remaining: 7.32s
# 728:	learn: 1.1429952	total: 19.6s	remaining: 7.29s
# 729:	learn: 1.1387000	total: 19.6s	remaining: 7.26s
# 730:	learn: 1.1363510	total: 19.7s	remaining: 7.24s
# 731:	learn: 1.1219159	total: 19.7s	remaining: 7.22s
# 732:	learn: 1.1141786	total: 19.8s	remaining: 7.2s
# 733:	learn: 1.1059140	total: 19.8s	remaining: 7.17s
# 734:	learn: 1.1007265	total: 19.8s	remaining: 7.15s
# 735:	learn: 1.0927974	total: 19.9s	remaining: 7.12s
# 736:	learn: 1.0873571	total: 19.9s	remaining: 7.1s
# 737:	learn: 1.0796162	total: 19.9s	remaining: 7.07s
# 738:	learn: 1.0727434	total: 19.9s	remaining: 7.04s
# 739:	learn: 1.0649830	total: 20s	remaining: 7.01s
# 740:	learn: 1.0591835	total: 20s	remaining: 6.99s
# 741:	learn: 1.0519381	total: 20s	remaining: 6.96s
# 742:	learn: 1.0479935	total: 20s	remaining: 6.93s
# 743:	learn: 1.0440491	total: 20.1s	remaining: 6.9s
# 744:	learn: 1.0371966	total: 20.1s	remaining: 6.88s
# 745:	learn: 1.0286724	total: 20.1s	remaining: 6.86s
# 746:	learn: 1.0231632	total: 20.2s	remaining: 6.83s
# 747:	learn: 1.0172474	total: 20.2s	remaining: 6.8s
# 748:	learn: 1.0043431	total: 20.2s	remaining: 6.77s
# 749:	learn: 1.0014682	total: 20.2s	remaining: 6.75s
# 750:	learn: 0.9980366	total: 20.3s	remaining: 6.72s
# 751:	learn: 0.9943500	total: 20.3s	remaining: 6.69s
# 752:	learn: 0.9902263	total: 20.3s	remaining: 6.66s
# 753:	learn: 0.9880460	total: 20.3s	remaining: 6.63s
# 754:	learn: 0.9839626	total: 20.4s	remaining: 6.61s
# 755:	learn: 0.9829979	total: 20.4s	remaining: 6.58s
# 756:	learn: 0.9751078	total: 20.4s	remaining: 6.55s
# 757:	learn: 0.9659453	total: 20.4s	remaining: 6.53s
# 758:	learn: 0.9609021	total: 20.5s	remaining: 6.5s
# 759:	learn: 0.9512655	total: 20.5s	remaining: 6.47s
# 760:	learn: 0.9475370	total: 20.5s	remaining: 6.45s
# 761:	learn: 0.9424977	total: 20.6s	remaining: 6.42s
# 762:	learn: 0.9342734	total: 20.6s	remaining: 6.39s
# 763:	learn: 0.9241568	total: 20.6s	remaining: 6.36s
# 764:	learn: 0.9194804	total: 20.6s	remaining: 6.34s
# 765:	learn: 0.9123666	total: 20.6s	remaining: 6.31s
# 766:	learn: 0.9070229	total: 20.7s	remaining: 6.28s
# 767:	learn: 0.9017123	total: 20.7s	remaining: 6.25s
# 768:	learn: 0.8960321	total: 20.7s	remaining: 6.23s
# 769:	learn: 0.8897239	total: 20.8s	remaining: 6.2s
# 770:	learn: 0.8775064	total: 20.8s	remaining: 6.17s
# 771:	learn: 0.8681652	total: 20.8s	remaining: 6.14s
# 772:	learn: 0.8630648	total: 20.8s	remaining: 6.12s
# 773:	learn: 0.8580254	total: 20.9s	remaining: 6.09s
# 774:	learn: 0.8569906	total: 20.9s	remaining: 6.06s
# 775:	learn: 0.8522210	total: 20.9s	remaining: 6.04s
# 776:	learn: 0.8508591	total: 21s	remaining: 6.01s
# 777:	learn: 0.8459046	total: 21s	remaining: 5.99s
# 778:	learn: 0.8377857	total: 21s	remaining: 5.96s
# 779:	learn: 0.8312148	total: 21s	remaining: 5.93s
# 780:	learn: 0.8297652	total: 21.1s	remaining: 5.91s
# 781:	learn: 0.8245474	total: 21.1s	remaining: 5.88s
# 782:	learn: 0.8163791	total: 21.1s	remaining: 5.85s
# 783:	learn: 0.8086853	total: 21.1s	remaining: 5.83s
# 784:	learn: 0.8073929	total: 21.2s	remaining: 5.8s
# 785:	learn: 0.8033285	total: 21.2s	remaining: 5.77s
# 786:	learn: 0.7979187	total: 21.2s	remaining: 5.74s
# 787:	learn: 0.7950716	total: 21.2s	remaining: 5.72s
# 788:	learn: 0.7862938	total: 21.3s	remaining: 5.69s
# 789:	learn: 0.7798417	total: 21.3s	remaining: 5.66s
# 790:	learn: 0.7767994	total: 21.3s	remaining: 5.63s
# 791:	learn: 0.7745364	total: 21.4s	remaining: 5.61s
# 792:	learn: 0.7681902	total: 21.4s	remaining: 5.58s
# 793:	learn: 0.7648291	total: 21.4s	remaining: 5.55s
# 794:	learn: 0.7647443	total: 21.4s	remaining: 5.53s
# 795:	learn: 0.7579750	total: 21.5s	remaining: 5.5s
# 796:	learn: 0.7545531	total: 21.5s	remaining: 5.47s
# 797:	learn: 0.7501225	total: 21.5s	remaining: 5.45s
# 798:	learn: 0.7472085	total: 21.5s	remaining: 5.42s
# 799:	learn: 0.7455498	total: 21.6s	remaining: 5.39s
# 800:	learn: 0.7411841	total: 21.6s	remaining: 5.36s
# 801:	learn: 0.7318984	total: 21.6s	remaining: 5.34s
# 802:	learn: 0.7298020	total: 21.6s	remaining: 5.31s
# 803:	learn: 0.7277967	total: 21.7s	remaining: 5.28s
# 804:	learn: 0.7240474	total: 21.7s	remaining: 5.25s
# 805:	learn: 0.7206024	total: 21.7s	remaining: 5.23s
# 806:	learn: 0.7169013	total: 21.8s	remaining: 5.2s
# 807:	learn: 0.7118721	total: 21.8s	remaining: 5.18s
# 808:	learn: 0.7088935	total: 21.8s	remaining: 5.15s
# 809:	learn: 0.7032644	total: 21.8s	remaining: 5.12s
# 810:	learn: 0.6987003	total: 21.9s	remaining: 5.09s
# 811:	learn: 0.6936398	total: 21.9s	remaining: 5.07s
# 812:	learn: 0.6857758	total: 21.9s	remaining: 5.04s
# 813:	learn: 0.6855042	total: 21.9s	remaining: 5.01s
# 814:	learn: 0.6852915	total: 22s	remaining: 4.99s
# 815:	learn: 0.6785711	total: 22s	remaining: 4.96s
# 816:	learn: 0.6769634	total: 22s	remaining: 4.93s
# 817:	learn: 0.6759946	total: 22s	remaining: 4.9s
# 818:	learn: 0.6733830	total: 22.1s	remaining: 4.88s
# 819:	learn: 0.6704899	total: 22.1s	remaining: 4.85s
# 820:	learn: 0.6689315	total: 22.1s	remaining: 4.82s
# 821:	learn: 0.6673325	total: 22.1s	remaining: 4.79s
# 822:	learn: 0.6659373	total: 22.2s	remaining: 4.78s
# 823:	learn: 0.6644966	total: 22.2s	remaining: 4.75s
# 824:	learn: 0.6573498	total: 22.3s	remaining: 4.73s
# 825:	learn: 0.6530938	total: 22.3s	remaining: 4.7s
# 826:	learn: 0.6468969	total: 22.3s	remaining: 4.67s
# 827:	learn: 0.6427989	total: 22.4s	remaining: 4.64s
# 828:	learn: 0.6376513	total: 22.4s	remaining: 4.62s
# 829:	learn: 0.6325384	total: 22.4s	remaining: 4.59s
# 830:	learn: 0.6292796	total: 22.4s	remaining: 4.56s
# 831:	learn: 0.6290876	total: 22.5s	remaining: 4.54s
# 832:	learn: 0.6254929	total: 22.5s	remaining: 4.51s
# 833:	learn: 0.6221144	total: 22.5s	remaining: 4.48s
# 834:	learn: 0.6200813	total: 22.5s	remaining: 4.45s
# 835:	learn: 0.6175745	total: 22.6s	remaining: 4.43s
# 836:	learn: 0.6150995	total: 22.6s	remaining: 4.4s
# 837:	learn: 0.6123186	total: 22.6s	remaining: 4.38s
# 838:	learn: 0.6087041	total: 22.7s	remaining: 4.35s
# 839:	learn: 0.6079276	total: 22.7s	remaining: 4.32s
# 840:	learn: 0.6048349	total: 22.7s	remaining: 4.29s
# 841:	learn: 0.6019342	total: 22.7s	remaining: 4.27s
# 842:	learn: 0.5949160	total: 22.8s	remaining: 4.24s
# 843:	learn: 0.5932636	total: 22.8s	remaining: 4.21s
# 844:	learn: 0.5886813	total: 22.8s	remaining: 4.19s
# 845:	learn: 0.5830399	total: 22.8s	remaining: 4.16s
# 846:	learn: 0.5811916	total: 22.9s	remaining: 4.13s
# 847:	learn: 0.5803355	total: 22.9s	remaining: 4.1s
# 848:	learn: 0.5788625	total: 22.9s	remaining: 4.08s
# 849:	learn: 0.5761912	total: 23s	remaining: 4.05s
# 850:	learn: 0.5741069	total: 23s	remaining: 4.02s
# 851:	learn: 0.5701995	total: 23s	remaining: 4s
# 852:	learn: 0.5663374	total: 23s	remaining: 3.97s
# 853:	learn: 0.5654507	total: 23.1s	remaining: 3.94s
# 854:	learn: 0.5637124	total: 23.1s	remaining: 3.91s
# 855:	learn: 0.5619937	total: 23.1s	remaining: 3.89s
# 856:	learn: 0.5587735	total: 23.1s	remaining: 3.86s
# 857:	learn: 0.5512896	total: 23.2s	remaining: 3.83s
# 858:	learn: 0.5474743	total: 23.2s	remaining: 3.81s
# 859:	learn: 0.5426123	total: 23.2s	remaining: 3.78s
# 860:	learn: 0.5397054	total: 23.3s	remaining: 3.75s
# 861:	learn: 0.5352256	total: 23.3s	remaining: 3.73s
# 862:	learn: 0.5320764	total: 23.3s	remaining: 3.7s
# 863:	learn: 0.5293624	total: 23.3s	remaining: 3.67s
# 864:	learn: 0.5237176	total: 23.4s	remaining: 3.65s
# 865:	learn: 0.5205091	total: 23.4s	remaining: 3.62s
# 866:	learn: 0.5187287	total: 23.4s	remaining: 3.59s
# 867:	learn: 0.5158623	total: 23.4s	remaining: 3.56s
# 868:	learn: 0.5143372	total: 23.5s	remaining: 3.54s
# 869:	learn: 0.5107836	total: 23.5s	remaining: 3.51s
# 870:	learn: 0.5090303	total: 23.5s	remaining: 3.48s
# 871:	learn: 0.5056978	total: 23.5s	remaining: 3.46s
# 872:	learn: 0.5027403	total: 23.6s	remaining: 3.43s
# 873:	learn: 0.4995804	total: 23.6s	remaining: 3.4s
# 874:	learn: 0.4981122	total: 23.6s	remaining: 3.38s
# 875:	learn: 0.4936674	total: 23.7s	remaining: 3.35s
# 876:	learn: 0.4922873	total: 23.7s	remaining: 3.32s
# 877:	learn: 0.4920060	total: 23.7s	remaining: 3.29s
# 878:	learn: 0.4898422	total: 23.7s	remaining: 3.27s
# 879:	learn: 0.4863625	total: 23.8s	remaining: 3.24s
# 880:	learn: 0.4861436	total: 23.8s	remaining: 3.21s
# 881:	learn: 0.4842465	total: 23.8s	remaining: 3.19s
# 882:	learn: 0.4784297	total: 23.8s	remaining: 3.16s
# 883:	learn: 0.4769736	total: 23.9s	remaining: 3.13s
# 884:	learn: 0.4749579	total: 23.9s	remaining: 3.1s
# 885:	learn: 0.4721169	total: 23.9s	remaining: 3.08s
# 886:	learn: 0.4683370	total: 23.9s	remaining: 3.05s
# 887:	learn: 0.4636622	total: 24s	remaining: 3.02s
# 888:	learn: 0.4605100	total: 24s	remaining: 3s
# 889:	learn: 0.4593548	total: 24s	remaining: 2.97s
# 890:	learn: 0.4544530	total: 24s	remaining: 2.94s
# 891:	learn: 0.4521845	total: 24.1s	remaining: 2.92s
# 892:	learn: 0.4503021	total: 24.1s	remaining: 2.89s
# 893:	learn: 0.4488472	total: 24.1s	remaining: 2.86s
# 894:	learn: 0.4476061	total: 24.2s	remaining: 2.84s
# 895:	learn: 0.4421576	total: 24.2s	remaining: 2.81s
# 896:	learn: 0.4403925	total: 24.2s	remaining: 2.78s
# 897:	learn: 0.4376230	total: 24.2s	remaining: 2.75s
# 898:	learn: 0.4336647	total: 24.3s	remaining: 2.73s
# 899:	learn: 0.4290122	total: 24.3s	remaining: 2.7s
# 900:	learn: 0.4270263	total: 24.3s	remaining: 2.67s
# 901:	learn: 0.4246241	total: 24.4s	remaining: 2.65s
# 902:	learn: 0.4224743	total: 24.4s	remaining: 2.62s
# 903:	learn: 0.4201524	total: 24.4s	remaining: 2.59s
# 904:	learn: 0.4191550	total: 24.4s	remaining: 2.56s
# 905:	learn: 0.4159560	total: 24.5s	remaining: 2.54s
# 906:	learn: 0.4147443	total: 24.5s	remaining: 2.51s
# 907:	learn: 0.4107536	total: 24.5s	remaining: 2.48s
# 908:	learn: 0.4102464	total: 24.5s	remaining: 2.46s
# 909:	learn: 0.4085729	total: 24.6s	remaining: 2.43s
# 910:	learn: 0.4062462	total: 24.6s	remaining: 2.4s
# 911:	learn: 0.4038630	total: 24.6s	remaining: 2.37s
# 912:	learn: 0.4011345	total: 24.6s	remaining: 2.35s
# 913:	learn: 0.4006687	total: 24.7s	remaining: 2.32s
# 914:	learn: 0.4005354	total: 24.7s	remaining: 2.29s
# 915:	learn: 0.3997217	total: 24.7s	remaining: 2.27s
# 916:	learn: 0.3961268	total: 24.7s	remaining: 2.24s
# 917:	learn: 0.3904855	total: 24.8s	remaining: 2.21s
# 918:	learn: 0.3883229	total: 24.8s	remaining: 2.18s
# 919:	learn: 0.3851815	total: 24.8s	remaining: 2.16s
# 920:	learn: 0.3819934	total: 24.8s	remaining: 2.13s
# 921:	learn: 0.3810147	total: 24.9s	remaining: 2.1s
# 922:	learn: 0.3801680	total: 24.9s	remaining: 2.08s
# 923:	learn: 0.3777603	total: 24.9s	remaining: 2.05s
# 924:	learn: 0.3751710	total: 25s	remaining: 2.02s
# 925:	learn: 0.3726638	total: 25s	remaining: 2s
# 926:	learn: 0.3702517	total: 25s	remaining: 1.97s
# 927:	learn: 0.3682927	total: 25s	remaining: 1.94s
# 928:	learn: 0.3664858	total: 25.1s	remaining: 1.92s
# 929:	learn: 0.3617378	total: 25.1s	remaining: 1.89s
# 930:	learn: 0.3596663	total: 25.1s	remaining: 1.86s
# 931:	learn: 0.3567342	total: 25.1s	remaining: 1.83s
# 932:	learn: 0.3559813	total: 25.2s	remaining: 1.81s
# 933:	learn: 0.3541089	total: 25.2s	remaining: 1.78s
# 934:	learn: 0.3521909	total: 25.2s	remaining: 1.75s
# 935:	learn: 0.3508118	total: 25.2s	remaining: 1.73s
# 936:	learn: 0.3499219	total: 25.3s	remaining: 1.7s
# 937:	learn: 0.3492636	total: 25.3s	remaining: 1.67s
# 938:	learn: 0.3471266	total: 25.3s	remaining: 1.64s
# 939:	learn: 0.3471095	total: 25.3s	remaining: 1.62s
# 940:	learn: 0.3456952	total: 25.4s	remaining: 1.59s
# 941:	learn: 0.3428113	total: 25.4s	remaining: 1.56s
# 942:	learn: 0.3408527	total: 25.4s	remaining: 1.54s
# 943:	learn: 0.3397880	total: 25.5s	remaining: 1.51s
# 944:	learn: 0.3388606	total: 25.5s	remaining: 1.48s
# 945:	learn: 0.3372124	total: 25.5s	remaining: 1.46s
# 946:	learn: 0.3342775	total: 25.5s	remaining: 1.43s
# 947:	learn: 0.3315659	total: 25.6s	remaining: 1.4s
# 948:	learn: 0.3290285	total: 25.6s	remaining: 1.37s
# 949:	learn: 0.3268240	total: 25.6s	remaining: 1.35s
# 950:	learn: 0.3251729	total: 25.6s	remaining: 1.32s
# 951:	learn: 0.3232067	total: 25.7s	remaining: 1.29s
# 952:	learn: 0.3211333	total: 25.7s	remaining: 1.27s
# 953:	learn: 0.3186399	total: 25.7s	remaining: 1.24s
# 954:	learn: 0.3169021	total: 25.8s	remaining: 1.21s
# 955:	learn: 0.3137068	total: 25.8s	remaining: 1.19s
# 956:	learn: 0.3122804	total: 25.8s	remaining: 1.16s
# 957:	learn: 0.3110979	total: 25.8s	remaining: 1.13s
# 958:	learn: 0.3092407	total: 25.9s	remaining: 1.1s
# 959:	learn: 0.3087738	total: 25.9s	remaining: 1.08s
# 960:	learn: 0.3087640	total: 25.9s	remaining: 1.05s
# 961:	learn: 0.3064287	total: 25.9s	remaining: 1.02s
# 962:	learn: 0.3041026	total: 26s	remaining: 998ms
# 963:	learn: 0.3020281	total: 26s	remaining: 971ms
# 964:	learn: 0.2985539	total: 26s	remaining: 944ms
# 965:	learn: 0.2962194	total: 26s	remaining: 917ms
# 966:	learn: 0.2942984	total: 26.1s	remaining: 890ms
# 967:	learn: 0.2917148	total: 26.1s	remaining: 863ms
# 968:	learn: 0.2889821	total: 26.1s	remaining: 836ms
# 969:	learn: 0.2871002	total: 26.1s	remaining: 809ms
# 970:	learn: 0.2868512	total: 26.2s	remaining: 782ms
# 971:	learn: 0.2863800	total: 26.2s	remaining: 755ms
# 972:	learn: 0.2839748	total: 26.2s	remaining: 728ms
# 973:	learn: 0.2826722	total: 26.2s	remaining: 701ms
# 974:	learn: 0.2826312	total: 26.3s	remaining: 674ms
# 975:	learn: 0.2804238	total: 26.3s	remaining: 647ms
# 976:	learn: 0.2796130	total: 26.3s	remaining: 620ms
# 977:	learn: 0.2790022	total: 26.4s	remaining: 593ms
# 978:	learn: 0.2762095	total: 26.4s	remaining: 566ms
# 979:	learn: 0.2753091	total: 26.4s	remaining: 539ms
# 980:	learn: 0.2732159	total: 26.4s	remaining: 512ms
# 981:	learn: 0.2720536	total: 26.5s	remaining: 485ms
# 982:	learn: 0.2715107	total: 26.5s	remaining: 458ms
# 983:	learn: 0.2691709	total: 26.5s	remaining: 431ms
# 984:	learn: 0.2672284	total: 26.5s	remaining: 404ms
# 985:	learn: 0.2658548	total: 26.6s	remaining: 377ms
# 986:	learn: 0.2650792	total: 26.6s	remaining: 350ms
# 987:	learn: 0.2648239	total: 26.6s	remaining: 323ms
# 988:	learn: 0.2634785	total: 26.6s	remaining: 296ms
# 989:	learn: 0.2612856	total: 26.7s	remaining: 269ms
# 990:	learn: 0.2586853	total: 26.7s	remaining: 242ms
# 991:	learn: 0.2586367	total: 26.7s	remaining: 216ms
# 992:	learn: 0.2563773	total: 26.8s	remaining: 189ms
# 993:	learn: 0.2559746	total: 26.8s	remaining: 162ms
# 994:	learn: 0.2558612	total: 26.8s	remaining: 135ms
# 995:	learn: 0.2538809	total: 26.8s	remaining: 108ms
# 996:	learn: 0.2526648	total: 26.9s	remaining: 80.8ms
# 997:	learn: 0.2526593	total: 26.9s	remaining: 53.9ms
# 998:	learn: 0.2511598	total: 26.9s	remaining: 26.9ms
# 999:	learn: 0.2508082	total: 27s	remaining: 0us
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# ---Predictions made---

# %%
# !pip list --format=freeze > requirements.txt
