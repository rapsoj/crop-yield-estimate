# %% [markdown]
# # DONT EDIT - MESSAGE TO MYSELF

# %%
# Import system libraries

import os
import sys

# Import data cleaning libraries
import pandas as pd
import numpy as np
import calendar
from datetime import datetime

# Import machine learning libraries
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, GridSearchCV

# Import data visualisation libraries
import matplotlib.pyplot as plt

# Import warning libraries
import warnings
warnings.filterwarnings("ignore")

# Set working directory
# Set this to your own path
os.chdir('/home/shaw/Documents/GitHub/crop-yield-estimate/')
# Set this to your own path
sys.path.insert(0, '/home/shaw/Documents/GitHub/crop-yield-estimate/pipeline')

# Import preprocessing libraries
from preprocessing import clustering
from preprocessing import dim_reduction
from preprocessing import feature_selection
from preprocessing import scaling
from preprocessing import feature_engineering
from preprocessing import cleaning

# Preprocess data
train_path = "data/Train.csv"
test_path = "data/Test.csv"
df = cleaning.clean_data(train_path, test_path)
df = feature_engineering.get_features(df)
df = scaling.scale_features(df)
df = feature_selection.select_features(df)
df = dim_reduction.reduce_dim(df)
df = clustering.get_clusters(df)


# Split data into training and test sets
df_train = df[df['Yield'].isna() == False]
df_test = df[df['Yield'].isna() == True]

# %%
top_cols = ['SeedlingsPerPit','Ganaura','CropOrgFYM','NoFertilizerAppln','BasalDAP',
            'BasalUrea','2appDaysUrea','Harv_hand_rent','Residue_length',
            'TransplantingIrrigationHours_per_Acre','TransIrriCost_per_Acre',
            'CropOrgFYM_per_Acre','BasalDAP_per_Acre','BasalUrea_per_Acre','1tdUrea_per_Acre',
            'Harv_hand_rent_per_Acre','TpIrrigationCost_Imputed_per_Acre',
            'Days_bw_SowTransp_Harv','Days_bw_Harv_Thresh','NursingDate_ModeDiff',
            'TillageDate_ModeDiff','HarvestDate_ModeDiff','ThreshingDate_ModeDiff',
            'Num_LandPrepMethod','Num_CropbasalFerts','Num_TopDressFert','Latitude',
            'Longitude','CropEstMethod_LineSowingAfterTillage','Threshing_method_machine',
            'Stubble_use_plowed_in_soil','LandPrepMethod_FourWheelTracRotavator_True',
            'LandPrepMethod_WetTillagePuddling_True','NursDetFactor_PreMonsoonShowers_True',
            'NursDetFactor_LabourAvailability_True','FirstTopDressFert_DAP_True',
            'HarvestMonth_November','ThreshingMonth_January','Block_Chehrakala',
            'PCropSolidOrgFertAppMethod_Broadcasting','PCropSolidOrgFertAppMethod_SoilApplied',
            'MineralFertAppMethod_1_Broadcasting','MineralFertAppMethod_1_SoilApplied','PC4',
            'PC10','PC21','top_shapley_k2_label_1', 'TpIrrigationHours_Imputed',
            'TpIrrigationCost_Imputed', 'SeedlingsPerPit_Imputed', 'NursingDate_ModeDiff_Imputed',
            '2appDaysUrea_Imputed']#,'Error_Prediction','Block_Prediction']#,'Linear_Yield_Prediction']

# Remove the specified columns from top_cols
columns_to_remove = ['SeedlingsPerPit', 'TransplantingIrrigationHours', 'TransIrriCost', 'StandingWater',
                     '1appDaysUrea', '2appDaysUrea', 'TransplantingIrrigationHours_per_Acre',
                     'TransIrriCost_per_Acre', 'TransplantingIrrigationHours_per_Acre_capped',
                     'TransIrriCost_per_Acre_capped', 'Days_bw_Nurs_SowTransp', 'Days_bw_Nurs_Harv',
                     'Days_bw_Nurs_Till', 'NursingDate_ModeDiff', 'Days_bw_Nurs_SowTransp_ModeDiff',
                     'Days_bw_Nurs_Harv_ModeDiff', 'Days_bw_Nurs_Till_ModeDiff', '2appDaysUrea_MeanDiff']

for column in columns_to_remove:
    if column in top_cols:
     top_cols.remove(column)

# %%
# from sklearn.linear_model import SGDRegressor
# from sklearn.svm import SVC
# import shap
# from sklearn.ensemble import VotingRegressor
# from lightgbm import LGBMRegressor
# from catboost import CatBoostRegressor
# import xgboost as xgb


# # Split data
# outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

# X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
# X = X[top_cols]


# # Initialize an array to store fold-wise predictions
# k = 5
# fold_wise_predictions = np.zeros((len(df_test), k))

# # Define number of splits for k-fold cross-validation
# kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# # Iterate over each fold and train XGBoost model
# for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
#     X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
#     y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

#     # Instantiate an XGBoost regressor model
#     best_params = {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100,
#                    'alpha': 0, 'lambda': 0}
#     xgb_reg = xgb.XGBRegressor(**best_params, colsample_bytree=0.3)
# #


#     # Tuned Tree estimators
#     lgbm = LGBMRegressor(boosting_type='goss', n_estimators=1000, learning_rate=0.08, num_leaves=100, max_depth=7)
#     catboost = CatBoostRegressor(depth=10, iterations=1000, learning_rate=0.5, l2_leaf_reg=5)


#     # Define the VotingRegressor
#     voting_regressor = VotingRegressor(
#         estimators=[
#             ('lgbm', lgbm),
#             ('catboost', catboost),
#             ('xgboost', xgb_reg)
#         ], weights=[2, 3, 1]
#     )


#     # Fit the model
#     voting_regressor.fit(X_tr, y_tr)

#     # Make predictions
#     test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
#     test_folds_pred = voting_regressor.predict(
#         test_predictors) * df_test["Acre"]


#     # Store fold-wise predictions
#     fold_wise_predictions[:, i] = test_folds_pred

    
# # Calculate the average of predictions from each fold for each row
# final_predictions = np.mean(fold_wise_predictions, axis=1)


# # Add predictions to sample submission file
# df_test_pred = pd.read_csv("data/SampleSubmission.csv")
# df_test_pred['Yield'] = final_predictions
# df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
#                                  df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# # Choose a floor value
# df_test_pred['Yield'] = np.where(
#     df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# # Export submission
# df_test_pred.to_csv('submission/SubmissionShawFinalRepeatTest.csv', index=False)

# print("---Predictions made---")

# %% [markdown]
# # EDIT THIS ONE !!!!

# %%
import xgboost as xgb
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import VotingRegressor
import shap
from sklearn.svm import SVC
from sklearn.linear_model import SGDRegressor
from joblib import load

# Load the model
model = load(
    '/home/shaw/Documents/GitHub/crop-yield-estimate/voting_regressor_model_9147.88969046982.pkl')


# Split data
outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
X = X[top_cols]


# Initialize an array to store fold-wise predictions
k = 5
fold_wise_predictions = np.zeros((len(df_test), k))

# Define number of splits for k-fold cross-validation
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# Iterate over each fold and train XGBoost model
for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    

    # Fit the model
    model.fit(X_tr, y_tr)

    # Make predictions
    test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
    test_folds_pred = model.predict(
        test_predictors) * df_test["Acre"]

    # Store fold-wise predictions
    fold_wise_predictions[:, i] = test_folds_pred


# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                 df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
    df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv(
    'submission/SubmissionShawFinalRepeatTest.csv', index=False)

print("---Predictions made---")
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2722
# [LightGBM] [Info] Number of data points in the train set: 3096, number of used features: 47
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 1882.305577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 695:	learn: 1.3672062	total: 25.7s	remaining: 11.2s
# 696:	learn: 1.3627602	total: 25.8s	remaining: 11.2s
# 697:	learn: 1.3531602	total: 25.8s	remaining: 11.2s
# 698:	learn: 1.3448558	total: 25.8s	remaining: 11.1s
# 699:	learn: 1.3373894	total: 25.9s	remaining: 11.1s
# 700:	learn: 1.3320081	total: 25.9s	remaining: 11.1s
# 701:	learn: 1.3318579	total: 25.9s	remaining: 11s
# 702:	learn: 1.3240293	total: 26s	remaining: 11s
# 703:	learn: 1.3161194	total: 26s	remaining: 10.9s
# 704:	learn: 1.3053932	total: 26s	remaining: 10.9s
# 705:	learn: 1.2975807	total: 26.1s	remaining: 10.9s
# 706:	learn: 1.2914756	total: 26.1s	remaining: 10.8s
# 707:	learn: 1.2830212	total: 26.2s	remaining: 10.8s
# 708:	learn: 1.2656587	total: 26.2s	remaining: 10.7s
# 709:	learn: 1.2571320	total: 26.2s	remaining: 10.7s
# 710:	learn: 1.2476900	total: 26.3s	remaining: 10.7s
# 711:	learn: 1.2475327	total: 26.4s	remaining: 10.7s
# 712:	learn: 1.2333261	total: 26.4s	remaining: 10.6s
# 713:	learn: 1.2187461	total: 26.4s	remaining: 10.6s
# 714:	learn: 1.2144639	total: 26.5s	remaining: 10.6s
# 715:	learn: 1.2009275	total: 26.5s	remaining: 10.5s
# 716:	learn: 1.1908958	total: 26.5s	remaining: 10.5s
# 717:	learn: 1.1834762	total: 26.6s	remaining: 10.4s
# 718:	learn: 1.1765710	total: 26.6s	remaining: 10.4s
# 719:	learn: 1.1685992	total: 26.7s	remaining: 10.4s
# 720:	learn: 1.1674029	total: 26.7s	remaining: 10.3s
# 721:	learn: 1.1635019	total: 26.7s	remaining: 10.3s
# 722:	learn: 1.1547926	total: 26.8s	remaining: 10.3s
# 723:	learn: 1.1513247	total: 26.8s	remaining: 10.2s
# 724:	learn: 1.1455758	total: 26.8s	remaining: 10.2s
# 725:	learn: 1.1404316	total: 26.9s	remaining: 10.1s
# 726:	learn: 1.1346286	total: 26.9s	remaining: 10.1s
# 727:	learn: 1.1274290	total: 26.9s	remaining: 10.1s
# 728:	learn: 1.1163079	total: 27s	remaining: 10s
# 729:	learn: 1.1064805	total: 27s	remaining: 9.99s
# 730:	learn: 1.0982125	total: 27s	remaining: 9.95s
# 731:	learn: 1.0912923	total: 27.1s	remaining: 9.91s
# 732:	learn: 1.0829498	total: 27.1s	remaining: 9.87s
# 733:	learn: 1.0809560	total: 27.1s	remaining: 9.83s
# 734:	learn: 1.0698808	total: 27.2s	remaining: 9.79s
# 735:	learn: 1.0626471	total: 27.2s	remaining: 9.76s
# 736:	learn: 1.0513916	total: 27.2s	remaining: 9.72s
# 737:	learn: 1.0449492	total: 27.3s	remaining: 9.68s
# 738:	learn: 1.0387434	total: 27.3s	remaining: 9.64s
# 739:	learn: 1.0327163	total: 27.3s	remaining: 9.6s
# 740:	learn: 1.0243981	total: 27.4s	remaining: 9.57s
# 741:	learn: 1.0121950	total: 27.4s	remaining: 9.53s
# 742:	learn: 1.0099367	total: 27.4s	remaining: 9.49s
# 743:	learn: 1.0052923	total: 27.5s	remaining: 9.45s
# 744:	learn: 1.0028226	total: 27.5s	remaining: 9.41s
# 745:	learn: 0.9950452	total: 27.5s	remaining: 9.38s
# 746:	learn: 0.9873518	total: 27.6s	remaining: 9.34s
# 747:	learn: 0.9850964	total: 27.6s	remaining: 9.3s
# 748:	learn: 0.9762497	total: 27.6s	remaining: 9.26s
# 749:	learn: 0.9687158	total: 27.7s	remaining: 9.22s
# 750:	learn: 0.9621982	total: 27.7s	remaining: 9.18s
# 751:	learn: 0.9537926	total: 27.7s	remaining: 9.15s
# 752:	learn: 0.9499238	total: 27.8s	remaining: 9.11s
# 753:	learn: 0.9459044	total: 27.8s	remaining: 9.07s
# 754:	learn: 0.9437274	total: 27.8s	remaining: 9.03s
# 755:	learn: 0.9433732	total: 27.9s	remaining: 8.99s
# 756:	learn: 0.9352757	total: 27.9s	remaining: 8.96s
# 757:	learn: 0.9317695	total: 27.9s	remaining: 8.92s
# 758:	learn: 0.9256475	total: 28s	remaining: 8.88s
# 759:	learn: 0.9216851	total: 28s	remaining: 8.84s
# 760:	learn: 0.9148569	total: 28s	remaining: 8.8s
# 761:	learn: 0.9078655	total: 28.1s	remaining: 8.77s
# 762:	learn: 0.9056526	total: 28.1s	remaining: 8.73s
# 763:	learn: 0.9016405	total: 28.1s	remaining: 8.69s
# 764:	learn: 0.8946923	total: 28.2s	remaining: 8.65s
# 765:	learn: 0.8874533	total: 28.2s	remaining: 8.61s
# 766:	learn: 0.8794696	total: 28.2s	remaining: 8.57s
# 767:	learn: 0.8780904	total: 28.3s	remaining: 8.54s
# 768:	learn: 0.8746265	total: 28.3s	remaining: 8.5s
# 769:	learn: 0.8665460	total: 28.4s	remaining: 8.47s
# 770:	learn: 0.8664491	total: 28.4s	remaining: 8.43s
# 771:	learn: 0.8602901	total: 28.4s	remaining: 8.4s
# 772:	learn: 0.8576733	total: 28.5s	remaining: 8.36s
# 773:	learn: 0.8537496	total: 28.5s	remaining: 8.32s
# 774:	learn: 0.8494594	total: 28.5s	remaining: 8.28s
# 775:	learn: 0.8471998	total: 28.6s	remaining: 8.24s
# 776:	learn: 0.8454813	total: 28.6s	remaining: 8.21s
# 777:	learn: 0.8351145	total: 28.6s	remaining: 8.17s
# 778:	learn: 0.8281700	total: 28.7s	remaining: 8.13s
# 779:	learn: 0.8246850	total: 28.7s	remaining: 8.09s
# 780:	learn: 0.8192728	total: 28.7s	remaining: 8.05s
# 781:	learn: 0.8146705	total: 28.8s	remaining: 8.02s
# 782:	learn: 0.8098271	total: 28.8s	remaining: 7.98s
# 783:	learn: 0.8065660	total: 28.8s	remaining: 7.94s
# 784:	learn: 0.7997738	total: 28.9s	remaining: 7.9s
# 785:	learn: 0.7924546	total: 28.9s	remaining: 7.87s
# 786:	learn: 0.7879966	total: 28.9s	remaining: 7.83s
# 787:	learn: 0.7804200	total: 29s	remaining: 7.79s
# 788:	learn: 0.7734114	total: 29s	remaining: 7.75s
# 789:	learn: 0.7685330	total: 29s	remaining: 7.71s
# 790:	learn: 0.7632374	total: 29.1s	remaining: 7.68s
# 791:	learn: 0.7584198	total: 29.1s	remaining: 7.64s
# 792:	learn: 0.7522040	total: 29.1s	remaining: 7.6s
# 793:	learn: 0.7502466	total: 29.1s	remaining: 7.56s
# 794:	learn: 0.7446681	total: 29.2s	remaining: 7.52s
# 795:	learn: 0.7400328	total: 29.2s	remaining: 7.49s
# 796:	learn: 0.7368098	total: 29.3s	remaining: 7.45s
# 797:	learn: 0.7321346	total: 29.3s	remaining: 7.41s
# 798:	learn: 0.7259346	total: 29.3s	remaining: 7.37s
# 799:	learn: 0.7227597	total: 29.3s	remaining: 7.34s
# 800:	learn: 0.7197368	total: 29.4s	remaining: 7.3s
# 801:	learn: 0.7196061	total: 29.4s	remaining: 7.26s
# 802:	learn: 0.7150352	total: 29.4s	remaining: 7.22s
# 803:	learn: 0.7092846	total: 29.5s	remaining: 7.19s
# 804:	learn: 0.7068229	total: 29.5s	remaining: 7.15s
# 805:	learn: 0.7036978	total: 29.6s	remaining: 7.12s
# 806:	learn: 0.6994749	total: 29.6s	remaining: 7.08s
# 807:	learn: 0.6972244	total: 29.6s	remaining: 7.04s
# 808:	learn: 0.6920639	total: 29.7s	remaining: 7.01s
# 809:	learn: 0.6822806	total: 29.7s	remaining: 6.97s
# 810:	learn: 0.6783507	total: 29.7s	remaining: 6.93s
# 811:	learn: 0.6744973	total: 29.8s	remaining: 6.89s
# 812:	learn: 0.6725705	total: 29.8s	remaining: 6.86s
# 813:	learn: 0.6675625	total: 29.8s	remaining: 6.82s
# 814:	learn: 0.6643831	total: 29.9s	remaining: 6.78s
# 815:	learn: 0.6599894	total: 29.9s	remaining: 6.74s
# 816:	learn: 0.6542762	total: 29.9s	remaining: 6.71s
# 817:	learn: 0.6515171	total: 30s	remaining: 6.67s
# 818:	learn: 0.6478232	total: 30s	remaining: 6.63s
# 819:	learn: 0.6467620	total: 30s	remaining: 6.59s
# 820:	learn: 0.6424788	total: 30.1s	remaining: 6.56s
# 821:	learn: 0.6358953	total: 30.1s	remaining: 6.52s
# 822:	learn: 0.6328743	total: 30.1s	remaining: 6.48s
# 823:	learn: 0.6308005	total: 30.2s	remaining: 6.44s
# 824:	learn: 0.6292129	total: 30.2s	remaining: 6.41s
# 825:	learn: 0.6267047	total: 30.2s	remaining: 6.37s
# 826:	learn: 0.6227915	total: 30.3s	remaining: 6.33s
# 827:	learn: 0.6219992	total: 30.3s	remaining: 6.29s
# 828:	learn: 0.6189097	total: 30.3s	remaining: 6.26s
# 829:	learn: 0.6143773	total: 30.4s	remaining: 6.22s
# 830:	learn: 0.6106266	total: 30.4s	remaining: 6.18s
# 831:	learn: 0.6061254	total: 30.4s	remaining: 6.15s
# 832:	learn: 0.5992888	total: 30.5s	remaining: 6.11s
# 833:	learn: 0.5973601	total: 30.5s	remaining: 6.08s
# 834:	learn: 0.5950912	total: 30.6s	remaining: 6.04s
# 835:	learn: 0.5901801	total: 30.6s	remaining: 6s
# 836:	learn: 0.5865591	total: 30.6s	remaining: 5.97s
# 837:	learn: 0.5824491	total: 30.7s	remaining: 5.93s
# 838:	learn: 0.5820826	total: 30.7s	remaining: 5.89s
# 839:	learn: 0.5790445	total: 30.7s	remaining: 5.85s
# 840:	learn: 0.5756657	total: 30.8s	remaining: 5.82s
# 841:	learn: 0.5700258	total: 30.8s	remaining: 5.78s
# 842:	learn: 0.5666293	total: 30.8s	remaining: 5.74s
# 843:	learn: 0.5603513	total: 30.9s	remaining: 5.71s
# 844:	learn: 0.5576107	total: 30.9s	remaining: 5.67s
# 845:	learn: 0.5516985	total: 30.9s	remaining: 5.63s
# 846:	learn: 0.5496093	total: 31s	remaining: 5.59s
# 847:	learn: 0.5487898	total: 31s	remaining: 5.56s
# 848:	learn: 0.5414750	total: 31s	remaining: 5.52s
# 849:	learn: 0.5361559	total: 31.1s	remaining: 5.49s
# 850:	learn: 0.5345503	total: 31.1s	remaining: 5.45s
# 851:	learn: 0.5342868	total: 31.2s	remaining: 5.41s
# 852:	learn: 0.5342687	total: 31.2s	remaining: 5.38s
# 853:	learn: 0.5284348	total: 31.2s	remaining: 5.34s
# 854:	learn: 0.5251147	total: 31.3s	remaining: 5.3s
# 855:	learn: 0.5238248	total: 31.3s	remaining: 5.26s
# 856:	learn: 0.5223355	total: 31.4s	remaining: 5.23s
# 857:	learn: 0.5198998	total: 31.4s	remaining: 5.2s
# 858:	learn: 0.5184532	total: 31.5s	remaining: 5.16s
# 859:	learn: 0.5161657	total: 31.5s	remaining: 5.13s
# 860:	learn: 0.5143083	total: 31.5s	remaining: 5.09s
# 861:	learn: 0.5100136	total: 31.6s	remaining: 5.05s
# 862:	learn: 0.5062135	total: 31.6s	remaining: 5.02s
# 863:	learn: 0.5044465	total: 31.6s	remaining: 4.98s
# 864:	learn: 0.5007662	total: 31.7s	remaining: 4.94s
# 865:	learn: 0.4984604	total: 31.7s	remaining: 4.91s
# 866:	learn: 0.4956271	total: 31.8s	remaining: 4.87s
# 867:	learn: 0.4915095	total: 31.8s	remaining: 4.84s
# 868:	learn: 0.4900398	total: 31.8s	remaining: 4.8s
# 869:	learn: 0.4846076	total: 31.9s	remaining: 4.76s
# 870:	learn: 0.4826023	total: 31.9s	remaining: 4.72s
# 871:	learn: 0.4809562	total: 31.9s	remaining: 4.69s
# 872:	learn: 0.4798521	total: 32s	remaining: 4.65s
# 873:	learn: 0.4768932	total: 32s	remaining: 4.61s
# 874:	learn: 0.4749635	total: 32s	remaining: 4.58s
# 875:	learn: 0.4730997	total: 32.1s	remaining: 4.54s
# 876:	learn: 0.4708091	total: 32.1s	remaining: 4.5s
# 877:	learn: 0.4676177	total: 32.1s	remaining: 4.46s
# 878:	learn: 0.4661916	total: 32.2s	remaining: 4.43s
# 879:	learn: 0.4636132	total: 32.2s	remaining: 4.39s
# 880:	learn: 0.4616255	total: 32.2s	remaining: 4.35s
# 881:	learn: 0.4585238	total: 32.3s	remaining: 4.32s
# 882:	learn: 0.4572711	total: 32.3s	remaining: 4.28s
# 883:	learn: 0.4508022	total: 32.3s	remaining: 4.24s
# 884:	learn: 0.4492533	total: 32.4s	remaining: 4.21s
# 885:	learn: 0.4464976	total: 32.4s	remaining: 4.17s
# 886:	learn: 0.4433344	total: 32.4s	remaining: 4.13s
# 887:	learn: 0.4403386	total: 32.5s	remaining: 4.09s
# 888:	learn: 0.4388818	total: 32.5s	remaining: 4.06s
# 889:	learn: 0.4358957	total: 32.5s	remaining: 4.02s
# 890:	learn: 0.4351144	total: 32.6s	remaining: 3.98s
# 891:	learn: 0.4323585	total: 32.6s	remaining: 3.95s
# 892:	learn: 0.4309302	total: 32.6s	remaining: 3.91s
# 893:	learn: 0.4254662	total: 32.7s	remaining: 3.87s
# 894:	learn: 0.4215652	total: 32.7s	remaining: 3.84s
# 895:	learn: 0.4202669	total: 32.7s	remaining: 3.8s
# 896:	learn: 0.4186897	total: 32.8s	remaining: 3.76s
# 897:	learn: 0.4157731	total: 32.8s	remaining: 3.73s
# 898:	learn: 0.4145538	total: 32.8s	remaining: 3.69s
# 899:	learn: 0.4135711	total: 32.9s	remaining: 3.65s
# 900:	learn: 0.4118535	total: 32.9s	remaining: 3.62s
# 901:	learn: 0.4117880	total: 33s	remaining: 3.58s
# 902:	learn: 0.4084889	total: 33s	remaining: 3.54s
# 903:	learn: 0.4052526	total: 33s	remaining: 3.51s
# 904:	learn: 0.4032939	total: 33.1s	remaining: 3.47s
# 905:	learn: 0.4004340	total: 33.1s	remaining: 3.43s
# 906:	learn: 0.3970065	total: 33.1s	remaining: 3.4s
# 907:	learn: 0.3918673	total: 33.2s	remaining: 3.36s
# 908:	learn: 0.3894521	total: 33.2s	remaining: 3.32s
# 909:	learn: 0.3893468	total: 33.2s	remaining: 3.29s
# 910:	learn: 0.3869996	total: 33.3s	remaining: 3.25s
# 911:	learn: 0.3854844	total: 33.3s	remaining: 3.21s
# 912:	learn: 0.3841994	total: 33.3s	remaining: 3.18s
# 913:	learn: 0.3819283	total: 33.4s	remaining: 3.14s
# 914:	learn: 0.3809453	total: 33.4s	remaining: 3.1s
# 915:	learn: 0.3790943	total: 33.4s	remaining: 3.07s
# 916:	learn: 0.3768598	total: 33.5s	remaining: 3.03s
# 917:	learn: 0.3749929	total: 33.5s	remaining: 2.99s
# 918:	learn: 0.3732922	total: 33.5s	remaining: 2.96s
# 919:	learn: 0.3710806	total: 33.6s	remaining: 2.92s
# 920:	learn: 0.3682402	total: 33.6s	remaining: 2.88s
# 921:	learn: 0.3661501	total: 33.6s	remaining: 2.85s
# 922:	learn: 0.3649723	total: 33.7s	remaining: 2.81s
# 923:	learn: 0.3648749	total: 33.7s	remaining: 2.77s
# 924:	learn: 0.3629656	total: 33.7s	remaining: 2.74s
# 925:	learn: 0.3597096	total: 33.8s	remaining: 2.7s
# 926:	learn: 0.3581585	total: 33.8s	remaining: 2.66s
# 927:	learn: 0.3547289	total: 33.9s	remaining: 2.63s
# 928:	learn: 0.3523824	total: 33.9s	remaining: 2.59s
# 929:	learn: 0.3513374	total: 33.9s	remaining: 2.55s
# 930:	learn: 0.3486348	total: 34s	remaining: 2.52s
# 931:	learn: 0.3464716	total: 34s	remaining: 2.48s
# 932:	learn: 0.3443442	total: 34s	remaining: 2.44s
# 933:	learn: 0.3421983	total: 34.1s	remaining: 2.41s
# 934:	learn: 0.3408603	total: 34.1s	remaining: 2.37s
# 935:	learn: 0.3384112	total: 34.1s	remaining: 2.33s
# 936:	learn: 0.3372167	total: 34.2s	remaining: 2.3s
# 937:	learn: 0.3354830	total: 34.2s	remaining: 2.26s
# 938:	learn: 0.3338757	total: 34.2s	remaining: 2.22s
# 939:	learn: 0.3315707	total: 34.2s	remaining: 2.19s
# 940:	learn: 0.3297823	total: 34.3s	remaining: 2.15s
# 941:	learn: 0.3291121	total: 34.3s	remaining: 2.11s
# 942:	learn: 0.3280067	total: 34.4s	remaining: 2.08s
# 943:	learn: 0.3247919	total: 34.4s	remaining: 2.04s
# 944:	learn: 0.3233687	total: 34.4s	remaining: 2s
# 945:	learn: 0.3219370	total: 34.5s	remaining: 1.97s
# 946:	learn: 0.3206639	total: 34.5s	remaining: 1.93s
# 947:	learn: 0.3157583	total: 34.5s	remaining: 1.89s
# 948:	learn: 0.3123282	total: 34.6s	remaining: 1.86s
# 949:	learn: 0.3118269	total: 34.6s	remaining: 1.82s
# 950:	learn: 0.3091984	total: 34.6s	remaining: 1.78s
# 951:	learn: 0.3082170	total: 34.7s	remaining: 1.75s
# 952:	learn: 0.3075399	total: 34.7s	remaining: 1.71s
# 953:	learn: 0.3068413	total: 34.7s	remaining: 1.68s
# 954:	learn: 0.3061460	total: 34.8s	remaining: 1.64s
# 955:	learn: 0.3061311	total: 34.8s	remaining: 1.6s
# 956:	learn: 0.3038267	total: 34.8s	remaining: 1.56s
# 957:	learn: 0.3030188	total: 34.9s	remaining: 1.53s
# 958:	learn: 0.3014836	total: 34.9s	remaining: 1.49s
# 959:	learn: 0.3014706	total: 34.9s	remaining: 1.46s
# 960:	learn: 0.2993466	total: 35s	remaining: 1.42s
# 961:	learn: 0.2976165	total: 35s	remaining: 1.38s
# 962:	learn: 0.2962777	total: 35s	remaining: 1.35s
# 963:	learn: 0.2958236	total: 35.1s	remaining: 1.31s
# 964:	learn: 0.2941814	total: 35.1s	remaining: 1.27s
# 965:	learn: 0.2938164	total: 35.1s	remaining: 1.24s
# 966:	learn: 0.2930554	total: 35.2s	remaining: 1.2s
# 967:	learn: 0.2925491	total: 35.2s	remaining: 1.16s
# 968:	learn: 0.2902203	total: 35.2s	remaining: 1.13s
# 969:	learn: 0.2885385	total: 35.3s	remaining: 1.09s
# 970:	learn: 0.2865546	total: 35.3s	remaining: 1.05s
# 971:	learn: 0.2847014	total: 35.3s	remaining: 1.02s
# 972:	learn: 0.2831970	total: 35.4s	remaining: 982ms
# 973:	learn: 0.2817013	total: 35.4s	remaining: 945ms
# 974:	learn: 0.2806629	total: 35.5s	remaining: 909ms
# 975:	learn: 0.2783322	total: 35.5s	remaining: 873ms
# 976:	learn: 0.2782854	total: 35.5s	remaining: 836ms
# 977:	learn: 0.2778152	total: 35.5s	remaining: 800ms
# 978:	learn: 0.2759553	total: 35.6s	remaining: 763ms
# 979:	learn: 0.2729370	total: 35.6s	remaining: 727ms
# 980:	learn: 0.2714176	total: 35.7s	remaining: 691ms
# 981:	learn: 0.2699217	total: 35.7s	remaining: 655ms
# 982:	learn: 0.2668375	total: 35.8s	remaining: 618ms
# 983:	learn: 0.2657467	total: 35.8s	remaining: 582ms
# 984:	learn: 0.2637694	total: 35.8s	remaining: 546ms
# 985:	learn: 0.2618266	total: 35.9s	remaining: 510ms
# 986:	learn: 0.2606403	total: 36s	remaining: 474ms
# 987:	learn: 0.2587322	total: 36s	remaining: 437ms
# 988:	learn: 0.2574571	total: 36s	remaining: 401ms
# 989:	learn: 0.2568593	total: 36.1s	remaining: 364ms
# 990:	learn: 0.2546023	total: 36.1s	remaining: 328ms
# 991:	learn: 0.2532665	total: 36.1s	remaining: 291ms
# 992:	learn: 0.2519920	total: 36.2s	remaining: 255ms
# 993:	learn: 0.2502519	total: 36.2s	remaining: 219ms
# 994:	learn: 0.2493657	total: 36.2s	remaining: 182ms
# 995:	learn: 0.2482900	total: 36.3s	remaining: 146ms
# 996:	learn: 0.2476936	total: 36.3s	remaining: 109ms
# 997:	learn: 0.2454261	total: 36.3s	remaining: 72.8ms
# 998:	learn: 0.2448864	total: 36.4s	remaining: 36.4ms
# 999:	learn: 0.2441199	total: 36.4s	remaining: 0us
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# ---Predictions made---

# %%
SubmissionShawFinalRepeatTest = pd.read_csv(
    'submission/SubmissionShawFinalRepeatTest.csv')
SubmissionShawFinal = pd.read_csv('submission/SubmissionShawFinal.csv')

difference = (SubmissionShawFinal['Yield']).subtract(
    SubmissionShawFinalRepeatTest['Yield'])
positive_difference = difference.abs()
sum_of_positive_difference = positive_difference.sum().sum()

# %%
print(sum_of_positive_difference)
# Out:
# 9684.271798302341
