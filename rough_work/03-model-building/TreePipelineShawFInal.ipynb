# %% [markdown]
# # DONT EDIT - MESSAGE TO MYSELF

# %%
# Import system libraries

import os
import sys

# Import data cleaning libraries
import pandas as pd
import numpy as np
import calendar
from datetime import datetime

# Import machine learning libraries
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, GridSearchCV

# Import data visualisation libraries
import matplotlib.pyplot as plt

# Import warning libraries
import warnings
warnings.filterwarnings("ignore")

# Set working directory
# Set this to your own path
os.chdir('/home/shaw/Documents/GitHub/crop-yield-estimate/')
# Set this to your own path
sys.path.insert(0, '/home/shaw/Documents/GitHub/crop-yield-estimate/pipeline')

# Import preprocessing libraries
from preprocessing import clustering
from preprocessing import dim_reduction
from preprocessing import feature_selection
from preprocessing import scaling
from preprocessing import feature_engineering
from preprocessing import cleaning

# Preprocess data
train_path = "data/Train.csv"
test_path = "data/Test.csv"
df = cleaning.clean_data(train_path, test_path)
df = feature_engineering.get_features(df)
df = scaling.scale_features(df)
df = feature_selection.select_features(df)
df = dim_reduction.reduce_dim(df)
df = clustering.get_clusters(df)


# Split data into training and test sets
df_train = df[df['Yield'].isna() == False]
df_test = df[df['Yield'].isna() == True]

# %%
top_cols = ['SeedlingsPerPit','Ganaura','CropOrgFYM','NoFertilizerAppln','BasalDAP',
            'BasalUrea','2appDaysUrea','Harv_hand_rent','Residue_length',
            'TransplantingIrrigationHours_per_Acre','TransIrriCost_per_Acre',
            'CropOrgFYM_per_Acre','BasalDAP_per_Acre','BasalUrea_per_Acre','1tdUrea_per_Acre',
            'Harv_hand_rent_per_Acre','TpIrrigationCost_Imputed_per_Acre',
            'Days_bw_SowTransp_Harv','Days_bw_Harv_Thresh','NursingDate_ModeDiff',
            'TillageDate_ModeDiff','HarvestDate_ModeDiff','ThreshingDate_ModeDiff',
            'Num_LandPrepMethod','Num_CropbasalFerts','Num_TopDressFert','Latitude',
            'Longitude','CropEstMethod_LineSowingAfterTillage','Threshing_method_machine',
            'Stubble_use_plowed_in_soil','LandPrepMethod_FourWheelTracRotavator_True',
            'LandPrepMethod_WetTillagePuddling_True','NursDetFactor_PreMonsoonShowers_True',
            'NursDetFactor_LabourAvailability_True','FirstTopDressFert_DAP_True',
            'HarvestMonth_November','ThreshingMonth_January','Block_Chehrakala',
            'PCropSolidOrgFertAppMethod_Broadcasting','PCropSolidOrgFertAppMethod_SoilApplied',
            'MineralFertAppMethod_1_Broadcasting','MineralFertAppMethod_1_SoilApplied','PC4',
            'PC10','PC21','top_shapley_k2_label_1', 'TpIrrigationHours_Imputed',
            'TpIrrigationCost_Imputed', 'SeedlingsPerPit_Imputed', 'NursingDate_ModeDiff_Imputed',
            '2appDaysUrea_Imputed']#,'Error_Prediction','Block_Prediction']#,'Linear_Yield_Prediction']

# Remove the specified columns from top_cols
columns_to_remove = ['SeedlingsPerPit', 'TransplantingIrrigationHours', 'TransIrriCost', 'StandingWater',
                     '1appDaysUrea', '2appDaysUrea', 'TransplantingIrrigationHours_per_Acre',
                     'TransIrriCost_per_Acre', 'TransplantingIrrigationHours_per_Acre_capped',
                     'TransIrriCost_per_Acre_capped', 'Days_bw_Nurs_SowTransp', 'Days_bw_Nurs_Harv',
                     'Days_bw_Nurs_Till', 'NursingDate_ModeDiff', 'Days_bw_Nurs_SowTransp_ModeDiff',
                     'Days_bw_Nurs_Harv_ModeDiff', 'Days_bw_Nurs_Till_ModeDiff', '2appDaysUrea_MeanDiff']

for column in columns_to_remove:
    if column in top_cols:
     top_cols.remove(column)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVC
import shap
from sklearn.ensemble import VotingRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
import xgboost as xgb


# Split data
outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
X = X[top_cols]


# Initialize an array to store fold-wise predictions
k = 5
fold_wise_predictions = np.zeros((len(df_test), k))

# Define number of splits for k-fold cross-validation
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# Iterate over each fold and train XGBoost model
for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Instantiate an XGBoost regressor model
    best_params = {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100,
                   'alpha': 0, 'lambda': 0}
    xgb_reg = xgb.XGBRegressor(**best_params, colsample_bytree=0.3)



    # Tuned Tree estimators
    lgbm = LGBMRegressor(boosting_type='goss', n_estimators=1000, learning_rate=0.08, num_leaves=100, max_depth=7)
    catboost = CatBoostRegressor(depth=10, iterations=1000, learning_rate=0.5, l2_leaf_reg=5)


    # Define the VotingRegressor
    voting_regressor = VotingRegressor(
        estimators=[
            ('lgbm', lgbm),
            ('catboost', catboost),
            ('xgboost', xgb_reg)
        ], weights=[2, 3, 1]
    )


    # Fit the model
    voting_regressor.fit(X_tr, y_tr)

    # Make predictions
    test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
    test_folds_pred = voting_regressor.predict(
        test_predictors) * df_test["Acre"]


    # Store fold-wise predictions
    fold_wise_predictions[:, i] = test_folds_pred

    
# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                 df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
    df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv('submission/SubmissionShawFinalRepeatTest.csv', index=False)

print("---Predictions made---")
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000900 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2722
# [LightGBM] [Info] Number of data points in the train set: 3096, number of used features: 47
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 1882.305577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 696:	learn: 1.3750105	total: 16.7s	remaining: 7.26s
# 697:	learn: 1.3683787	total: 16.8s	remaining: 7.25s
# 698:	learn: 1.3586212	total: 16.8s	remaining: 7.23s
# 699:	learn: 1.3507073	total: 16.8s	remaining: 7.21s
# 700:	learn: 1.3420001	total: 16.8s	remaining: 7.18s
# 701:	learn: 1.3327905	total: 16.9s	remaining: 7.16s
# 702:	learn: 1.3286801	total: 16.9s	remaining: 7.13s
# 703:	learn: 1.3222167	total: 16.9s	remaining: 7.11s
# 704:	learn: 1.3138249	total: 16.9s	remaining: 7.09s
# 705:	learn: 1.3066856	total: 17s	remaining: 7.06s
# 706:	learn: 1.2993299	total: 17s	remaining: 7.04s
# 707:	learn: 1.2940063	total: 17s	remaining: 7.01s
# 708:	learn: 1.2861813	total: 17s	remaining: 6.99s
# 709:	learn: 1.2757923	total: 17.1s	remaining: 6.97s
# 710:	learn: 1.2621245	total: 17.1s	remaining: 6.94s
# 711:	learn: 1.2502781	total: 17.1s	remaining: 6.92s
# 712:	learn: 1.2491362	total: 17.1s	remaining: 6.9s
# 713:	learn: 1.2402969	total: 17.2s	remaining: 6.87s
# 714:	learn: 1.2352067	total: 17.2s	remaining: 6.85s
# 715:	learn: 1.2298399	total: 17.2s	remaining: 6.82s
# 716:	learn: 1.2277622	total: 17.2s	remaining: 6.8s
# 717:	learn: 1.2220214	total: 17.2s	remaining: 6.77s
# 718:	learn: 1.2128402	total: 17.3s	remaining: 6.75s
# 719:	learn: 1.2104309	total: 17.3s	remaining: 6.72s
# 720:	learn: 1.2057311	total: 17.3s	remaining: 6.7s
# 721:	learn: 1.1975748	total: 17.3s	remaining: 6.68s
# 722:	learn: 1.1897850	total: 17.4s	remaining: 6.65s
# 723:	learn: 1.1861089	total: 17.4s	remaining: 6.63s
# 724:	learn: 1.1800959	total: 17.4s	remaining: 6.6s
# 725:	learn: 1.1748965	total: 17.4s	remaining: 6.58s
# 726:	learn: 1.1616280	total: 17.5s	remaining: 6.56s
# 727:	learn: 1.1598638	total: 17.5s	remaining: 6.53s
# 728:	learn: 1.1520642	total: 17.5s	remaining: 6.51s
# 729:	learn: 1.1483779	total: 17.5s	remaining: 6.48s
# 730:	learn: 1.1420543	total: 17.6s	remaining: 6.46s
# 731:	learn: 1.1267830	total: 17.6s	remaining: 6.43s
# 732:	learn: 1.1185159	total: 17.6s	remaining: 6.41s
# 733:	learn: 1.1040680	total: 17.6s	remaining: 6.39s
# 734:	learn: 1.0958246	total: 17.6s	remaining: 6.36s
# 735:	learn: 1.0865022	total: 17.7s	remaining: 6.34s
# 736:	learn: 1.0795354	total: 17.7s	remaining: 6.32s
# 737:	learn: 1.0772532	total: 17.7s	remaining: 6.29s
# 738:	learn: 1.0726354	total: 17.7s	remaining: 6.27s
# 739:	learn: 1.0710876	total: 17.8s	remaining: 6.24s
# 740:	learn: 1.0662969	total: 17.8s	remaining: 6.22s
# 741:	learn: 1.0594565	total: 17.8s	remaining: 6.19s
# 742:	learn: 1.0534933	total: 17.8s	remaining: 6.17s
# 743:	learn: 1.0510508	total: 17.9s	remaining: 6.14s
# 744:	learn: 1.0442950	total: 17.9s	remaining: 6.12s
# 745:	learn: 1.0409698	total: 17.9s	remaining: 6.1s
# 746:	learn: 1.0392147	total: 17.9s	remaining: 6.07s
# 747:	learn: 1.0362099	total: 18s	remaining: 6.05s
# 748:	learn: 1.0307305	total: 18s	remaining: 6.03s
# 749:	learn: 1.0263834	total: 18s	remaining: 6s
# 750:	learn: 1.0207598	total: 18s	remaining: 5.98s
# 751:	learn: 1.0138761	total: 18.1s	remaining: 5.95s
# 752:	learn: 1.0026005	total: 18.1s	remaining: 5.93s
# 753:	learn: 0.9950388	total: 18.1s	remaining: 5.91s
# 754:	learn: 0.9877233	total: 18.1s	remaining: 5.88s
# 755:	learn: 0.9823623	total: 18.1s	remaining: 5.86s
# 756:	learn: 0.9742751	total: 18.2s	remaining: 5.83s
# 757:	learn: 0.9668889	total: 18.2s	remaining: 5.81s
# 758:	learn: 0.9640789	total: 18.2s	remaining: 5.79s
# 759:	learn: 0.9557012	total: 18.2s	remaining: 5.76s
# 760:	learn: 0.9438356	total: 18.3s	remaining: 5.74s
# 761:	learn: 0.9401709	total: 18.3s	remaining: 5.71s
# 762:	learn: 0.9389450	total: 18.3s	remaining: 5.69s
# 763:	learn: 0.9340698	total: 18.3s	remaining: 5.66s
# 764:	learn: 0.9316596	total: 18.4s	remaining: 5.64s
# 765:	learn: 0.9255609	total: 18.4s	remaining: 5.62s
# 766:	learn: 0.9242279	total: 18.4s	remaining: 5.59s
# 767:	learn: 0.9214236	total: 18.4s	remaining: 5.57s
# 768:	learn: 0.9190508	total: 18.5s	remaining: 5.54s
# 769:	learn: 0.9139283	total: 18.5s	remaining: 5.52s
# 770:	learn: 0.9079744	total: 18.5s	remaining: 5.5s
# 771:	learn: 0.9065222	total: 18.5s	remaining: 5.47s
# 772:	learn: 0.8947639	total: 18.6s	remaining: 5.45s
# 773:	learn: 0.8863971	total: 18.6s	remaining: 5.42s
# 774:	learn: 0.8806113	total: 18.6s	remaining: 5.4s
# 775:	learn: 0.8747158	total: 18.6s	remaining: 5.38s
# 776:	learn: 0.8718524	total: 18.6s	remaining: 5.35s
# 777:	learn: 0.8688823	total: 18.7s	remaining: 5.33s
# 778:	learn: 0.8613616	total: 18.7s	remaining: 5.3s
# 779:	learn: 0.8589012	total: 18.7s	remaining: 5.28s
# 780:	learn: 0.8555487	total: 18.7s	remaining: 5.25s
# 781:	learn: 0.8485023	total: 18.8s	remaining: 5.23s
# 782:	learn: 0.8449650	total: 18.8s	remaining: 5.21s
# 783:	learn: 0.8385644	total: 18.8s	remaining: 5.18s
# 784:	learn: 0.8319524	total: 18.8s	remaining: 5.16s
# 785:	learn: 0.8238540	total: 18.9s	remaining: 5.14s
# 786:	learn: 0.8218994	total: 18.9s	remaining: 5.11s
# 787:	learn: 0.8205452	total: 18.9s	remaining: 5.09s
# 788:	learn: 0.8148153	total: 18.9s	remaining: 5.06s
# 789:	learn: 0.8132193	total: 19s	remaining: 5.04s
# 790:	learn: 0.8119556	total: 19s	remaining: 5.02s
# 791:	learn: 0.8091991	total: 19s	remaining: 4.99s
# 792:	learn: 0.8054820	total: 19s	remaining: 4.97s
# 793:	learn: 0.8022739	total: 19.1s	remaining: 4.94s
# 794:	learn: 0.7980584	total: 19.1s	remaining: 4.92s
# 795:	learn: 0.7936127	total: 19.1s	remaining: 4.9s
# 796:	learn: 0.7902448	total: 19.1s	remaining: 4.87s
# 797:	learn: 0.7873121	total: 19.2s	remaining: 4.85s
# 798:	learn: 0.7821562	total: 19.2s	remaining: 4.82s
# 799:	learn: 0.7800379	total: 19.2s	remaining: 4.8s
# 800:	learn: 0.7762987	total: 19.2s	remaining: 4.78s
# 801:	learn: 0.7721723	total: 19.3s	remaining: 4.75s
# 802:	learn: 0.7650110	total: 19.3s	remaining: 4.73s
# 803:	learn: 0.7569171	total: 19.3s	remaining: 4.7s
# 804:	learn: 0.7516182	total: 19.3s	remaining: 4.68s
# 805:	learn: 0.7436253	total: 19.3s	remaining: 4.66s
# 806:	learn: 0.7397595	total: 19.4s	remaining: 4.63s
# 807:	learn: 0.7323788	total: 19.4s	remaining: 4.61s
# 808:	learn: 0.7292391	total: 19.4s	remaining: 4.58s
# 809:	learn: 0.7204513	total: 19.4s	remaining: 4.56s
# 810:	learn: 0.7174682	total: 19.5s	remaining: 4.54s
# 811:	learn: 0.7174034	total: 19.5s	remaining: 4.51s
# 812:	learn: 0.7126480	total: 19.5s	remaining: 4.49s
# 813:	learn: 0.7074715	total: 19.5s	remaining: 4.46s
# 814:	learn: 0.7010737	total: 19.6s	remaining: 4.44s
# 815:	learn: 0.6961574	total: 19.6s	remaining: 4.42s
# 816:	learn: 0.6908158	total: 19.6s	remaining: 4.39s
# 817:	learn: 0.6883860	total: 19.6s	remaining: 4.37s
# 818:	learn: 0.6809975	total: 19.7s	remaining: 4.34s
# 819:	learn: 0.6778915	total: 19.7s	remaining: 4.32s
# 820:	learn: 0.6731206	total: 19.7s	remaining: 4.3s
# 821:	learn: 0.6689857	total: 19.7s	remaining: 4.27s
# 822:	learn: 0.6652348	total: 19.8s	remaining: 4.25s
# 823:	learn: 0.6591698	total: 19.8s	remaining: 4.22s
# 824:	learn: 0.6560582	total: 19.8s	remaining: 4.2s
# 825:	learn: 0.6512019	total: 19.8s	remaining: 4.18s
# 826:	learn: 0.6476072	total: 19.8s	remaining: 4.15s
# 827:	learn: 0.6461097	total: 19.9s	remaining: 4.13s
# 828:	learn: 0.6414519	total: 19.9s	remaining: 4.1s
# 829:	learn: 0.6406763	total: 19.9s	remaining: 4.08s
# 830:	learn: 0.6359048	total: 20s	remaining: 4.06s
# 831:	learn: 0.6309140	total: 20s	remaining: 4.04s
# 832:	learn: 0.6282262	total: 20s	remaining: 4.01s
# 833:	learn: 0.6277249	total: 20.1s	remaining: 3.99s
# 834:	learn: 0.6230596	total: 20.1s	remaining: 3.97s
# 835:	learn: 0.6191344	total: 20.1s	remaining: 3.94s
# 836:	learn: 0.6178138	total: 20.1s	remaining: 3.92s
# 837:	learn: 0.6153467	total: 20.1s	remaining: 3.89s
# 838:	learn: 0.6116186	total: 20.2s	remaining: 3.87s
# 839:	learn: 0.6063033	total: 20.2s	remaining: 3.85s
# 840:	learn: 0.6045059	total: 20.2s	remaining: 3.82s
# 841:	learn: 0.6032472	total: 20.2s	remaining: 3.8s
# 842:	learn: 0.6030284	total: 20.3s	remaining: 3.77s
# 843:	learn: 0.5985453	total: 20.3s	remaining: 3.75s
# 844:	learn: 0.5965542	total: 20.3s	remaining: 3.73s
# 845:	learn: 0.5922395	total: 20.3s	remaining: 3.7s
# 846:	learn: 0.5900587	total: 20.4s	remaining: 3.68s
# 847:	learn: 0.5875414	total: 20.4s	remaining: 3.65s
# 848:	learn: 0.5837365	total: 20.4s	remaining: 3.63s
# 849:	learn: 0.5837110	total: 20.4s	remaining: 3.6s
# 850:	learn: 0.5792115	total: 20.4s	remaining: 3.58s
# 851:	learn: 0.5782281	total: 20.5s	remaining: 3.56s
# 852:	learn: 0.5715545	total: 20.5s	remaining: 3.53s
# 853:	learn: 0.5664025	total: 20.5s	remaining: 3.51s
# 854:	learn: 0.5619228	total: 20.5s	remaining: 3.48s
# 855:	learn: 0.5557833	total: 20.6s	remaining: 3.46s
# 856:	learn: 0.5540342	total: 20.6s	remaining: 3.44s
# 857:	learn: 0.5492404	total: 20.6s	remaining: 3.41s
# 858:	learn: 0.5476991	total: 20.6s	remaining: 3.39s
# 859:	learn: 0.5442248	total: 20.7s	remaining: 3.36s
# 860:	learn: 0.5436392	total: 20.7s	remaining: 3.34s
# 861:	learn: 0.5413770	total: 20.7s	remaining: 3.31s
# 862:	learn: 0.5383267	total: 20.7s	remaining: 3.29s
# 863:	learn: 0.5349760	total: 20.8s	remaining: 3.27s
# 864:	learn: 0.5325574	total: 20.8s	remaining: 3.24s
# 865:	learn: 0.5291603	total: 20.8s	remaining: 3.22s
# 866:	learn: 0.5248468	total: 20.8s	remaining: 3.19s
# 867:	learn: 0.5208238	total: 20.8s	remaining: 3.17s
# 868:	learn: 0.5182092	total: 20.9s	remaining: 3.15s
# 869:	learn: 0.5154242	total: 20.9s	remaining: 3.12s
# 870:	learn: 0.5126505	total: 20.9s	remaining: 3.1s
# 871:	learn: 0.5108740	total: 20.9s	remaining: 3.07s
# 872:	learn: 0.5089764	total: 21s	remaining: 3.05s
# 873:	learn: 0.5082255	total: 21s	remaining: 3.03s
# 874:	learn: 0.5038902	total: 21s	remaining: 3s
# 875:	learn: 0.5019483	total: 21s	remaining: 2.98s
# 876:	learn: 0.4994873	total: 21.1s	remaining: 2.95s
# 877:	learn: 0.4964298	total: 21.1s	remaining: 2.93s
# 878:	learn: 0.4937427	total: 21.1s	remaining: 2.9s
# 879:	learn: 0.4925025	total: 21.1s	remaining: 2.88s
# 880:	learn: 0.4890518	total: 21.2s	remaining: 2.86s
# 881:	learn: 0.4874126	total: 21.2s	remaining: 2.83s
# 882:	learn: 0.4842919	total: 21.2s	remaining: 2.81s
# 883:	learn: 0.4813025	total: 21.2s	remaining: 2.79s
# 884:	learn: 0.4774985	total: 21.2s	remaining: 2.76s
# 885:	learn: 0.4764768	total: 21.3s	remaining: 2.74s
# 886:	learn: 0.4735142	total: 21.3s	remaining: 2.71s
# 887:	learn: 0.4714600	total: 21.3s	remaining: 2.69s
# 888:	learn: 0.4672084	total: 21.3s	remaining: 2.66s
# 889:	learn: 0.4640346	total: 21.4s	remaining: 2.64s
# 890:	learn: 0.4607933	total: 21.4s	remaining: 2.62s
# 891:	learn: 0.4569769	total: 21.4s	remaining: 2.59s
# 892:	learn: 0.4539222	total: 21.4s	remaining: 2.57s
# 893:	learn: 0.4498288	total: 21.5s	remaining: 2.54s
# 894:	learn: 0.4453559	total: 21.5s	remaining: 2.52s
# 895:	learn: 0.4419055	total: 21.5s	remaining: 2.5s
# 896:	learn: 0.4368224	total: 21.5s	remaining: 2.47s
# 897:	learn: 0.4338058	total: 21.6s	remaining: 2.45s
# 898:	learn: 0.4316979	total: 21.6s	remaining: 2.42s
# 899:	learn: 0.4305235	total: 21.6s	remaining: 2.4s
# 900:	learn: 0.4299393	total: 21.6s	remaining: 2.38s
# 901:	learn: 0.4279880	total: 21.6s	remaining: 2.35s
# 902:	learn: 0.4270655	total: 21.7s	remaining: 2.33s
# 903:	learn: 0.4235462	total: 21.7s	remaining: 2.3s
# 904:	learn: 0.4208504	total: 21.7s	remaining: 2.28s
# 905:	learn: 0.4174424	total: 21.7s	remaining: 2.25s
# 906:	learn: 0.4152436	total: 21.8s	remaining: 2.23s
# 907:	learn: 0.4118036	total: 21.8s	remaining: 2.21s
# 908:	learn: 0.4096281	total: 21.8s	remaining: 2.18s
# 909:	learn: 0.4086397	total: 21.8s	remaining: 2.16s
# 910:	learn: 0.4050337	total: 21.9s	remaining: 2.13s
# 911:	learn: 0.4018183	total: 21.9s	remaining: 2.11s
# 912:	learn: 0.4009862	total: 21.9s	remaining: 2.09s
# 913:	learn: 0.4009556	total: 21.9s	remaining: 2.06s
# 914:	learn: 0.3985235	total: 21.9s	remaining: 2.04s
# 915:	learn: 0.3969111	total: 22s	remaining: 2.02s
# 916:	learn: 0.3954454	total: 22s	remaining: 1.99s
# 917:	learn: 0.3925277	total: 22s	remaining: 1.97s
# 918:	learn: 0.3908993	total: 22s	remaining: 1.94s
# 919:	learn: 0.3906143	total: 22.1s	remaining: 1.92s
# 920:	learn: 0.3884043	total: 22.1s	remaining: 1.89s
# 921:	learn: 0.3867124	total: 22.1s	remaining: 1.87s
# 922:	learn: 0.3853167	total: 22.1s	remaining: 1.85s
# 923:	learn: 0.3842141	total: 22.2s	remaining: 1.82s
# 924:	learn: 0.3806902	total: 22.2s	remaining: 1.8s
# 925:	learn: 0.3785187	total: 22.2s	remaining: 1.77s
# 926:	learn: 0.3754805	total: 22.2s	remaining: 1.75s
# 927:	learn: 0.3753026	total: 22.3s	remaining: 1.73s
# 928:	learn: 0.3733301	total: 22.3s	remaining: 1.7s
# 929:	learn: 0.3701507	total: 22.3s	remaining: 1.68s
# 930:	learn: 0.3685893	total: 22.3s	remaining: 1.65s
# 931:	learn: 0.3671042	total: 22.3s	remaining: 1.63s
# 932:	learn: 0.3653915	total: 22.4s	remaining: 1.61s
# 933:	learn: 0.3631417	total: 22.4s	remaining: 1.58s
# 934:	learn: 0.3609208	total: 22.4s	remaining: 1.56s
# 935:	learn: 0.3593352	total: 22.4s	remaining: 1.53s
# 936:	learn: 0.3576852	total: 22.5s	remaining: 1.51s
# 937:	learn: 0.3557842	total: 22.5s	remaining: 1.49s
# 938:	learn: 0.3530840	total: 22.5s	remaining: 1.46s
# 939:	learn: 0.3525129	total: 22.5s	remaining: 1.44s
# 940:	learn: 0.3491867	total: 22.6s	remaining: 1.41s
# 941:	learn: 0.3468027	total: 22.6s	remaining: 1.39s
# 942:	learn: 0.3433448	total: 22.6s	remaining: 1.37s
# 943:	learn: 0.3407797	total: 22.6s	remaining: 1.34s
# 944:	learn: 0.3385899	total: 22.7s	remaining: 1.32s
# 945:	learn: 0.3368715	total: 22.7s	remaining: 1.29s
# 946:	learn: 0.3352935	total: 22.7s	remaining: 1.27s
# 947:	learn: 0.3332677	total: 22.7s	remaining: 1.25s
# 948:	learn: 0.3311463	total: 22.7s	remaining: 1.22s
# 949:	learn: 0.3289421	total: 22.8s	remaining: 1.2s
# 950:	learn: 0.3278909	total: 22.8s	remaining: 1.17s
# 951:	learn: 0.3261153	total: 22.8s	remaining: 1.15s
# 952:	learn: 0.3258659	total: 22.8s	remaining: 1.13s
# 953:	learn: 0.3239406	total: 22.9s	remaining: 1.1s
# 954:	learn: 0.3221585	total: 22.9s	remaining: 1.08s
# 955:	learn: 0.3206294	total: 22.9s	remaining: 1.05s
# 956:	learn: 0.3202181	total: 22.9s	remaining: 1.03s
# 957:	learn: 0.3181927	total: 23s	remaining: 1.01s
# 958:	learn: 0.3171276	total: 23s	remaining: 982ms
# 959:	learn: 0.3149031	total: 23s	remaining: 958ms
# 960:	learn: 0.3133518	total: 23s	remaining: 935ms
# 961:	learn: 0.3125413	total: 23.1s	remaining: 911ms
# 962:	learn: 0.3112372	total: 23.1s	remaining: 887ms
# 963:	learn: 0.3102194	total: 23.1s	remaining: 863ms
# 964:	learn: 0.3084346	total: 23.1s	remaining: 839ms
# 965:	learn: 0.3049881	total: 23.1s	remaining: 815ms
# 966:	learn: 0.3023733	total: 23.2s	remaining: 791ms
# 967:	learn: 0.2982767	total: 23.2s	remaining: 768ms
# 968:	learn: 0.2963357	total: 23.3s	remaining: 744ms
# 969:	learn: 0.2953693	total: 23.3s	remaining: 720ms
# 970:	learn: 0.2940108	total: 23.3s	remaining: 696ms
# 971:	learn: 0.2926283	total: 23.3s	remaining: 672ms
# 972:	learn: 0.2916252	total: 23.3s	remaining: 648ms
# 973:	learn: 0.2899011	total: 23.4s	remaining: 624ms
# 974:	learn: 0.2888895	total: 23.4s	remaining: 600ms
# 975:	learn: 0.2882873	total: 23.4s	remaining: 576ms
# 976:	learn: 0.2870183	total: 23.4s	remaining: 552ms
# 977:	learn: 0.2846460	total: 23.5s	remaining: 528ms
# 978:	learn: 0.2839050	total: 23.5s	remaining: 504ms
# 979:	learn: 0.2825478	total: 23.5s	remaining: 480ms
# 980:	learn: 0.2809029	total: 23.5s	remaining: 456ms
# 981:	learn: 0.2793872	total: 23.6s	remaining: 432ms
# 982:	learn: 0.2775689	total: 23.6s	remaining: 408ms
# 983:	learn: 0.2758636	total: 23.6s	remaining: 384ms
# 984:	learn: 0.2749034	total: 23.6s	remaining: 360ms
# 985:	learn: 0.2726988	total: 23.7s	remaining: 336ms
# 986:	learn: 0.2717374	total: 23.7s	remaining: 312ms
# 987:	learn: 0.2694852	total: 23.7s	remaining: 288ms
# 988:	learn: 0.2686368	total: 23.7s	remaining: 264ms
# 989:	learn: 0.2672177	total: 23.7s	remaining: 240ms
# 990:	learn: 0.2643637	total: 23.8s	remaining: 216ms
# 991:	learn: 0.2622303	total: 23.8s	remaining: 192ms
# 992:	learn: 0.2609723	total: 23.8s	remaining: 168ms
# 993:	learn: 0.2588402	total: 23.8s	remaining: 144ms
# 994:	learn: 0.2565730	total: 23.9s	remaining: 120ms
# 995:	learn: 0.2550293	total: 23.9s	remaining: 95.9ms
# 996:	learn: 0.2532353	total: 23.9s	remaining: 72ms
# 997:	learn: 0.2511386	total: 23.9s	remaining: 48ms
# 998:	learn: 0.2492539	total: 24s	remaining: 24ms
# 999:	learn: 0.2478729	total: 24s	remaining: 0us
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# ---Predictions made---

# %% [markdown]
# # EDIT THIS ONE !!!!

# %%
import xgboost as xgb
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import VotingRegressor
import shap
from sklearn.svm import SVC
from sklearn.linear_model import SGDRegressor
from joblib import load

# Load the model
model = load(
    '/home/shaw/Documents/GitHub/crop-yield-estimate/voting_regressor_model_9147.88969046982.pkl')


# Split data
outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
X = X[top_cols]


# Initialize an array to store fold-wise predictions
k = 5
fold_wise_predictions = np.zeros((len(df_test), k))

# Define number of splits for k-fold cross-validation
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# Iterate over each fold and train XGBoost model
for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Instantiate an XGBoost regressor model
    best_params = {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100,
                   'alpha': 0, 'lambda': 0}

    # Fit the model
    model.fit(X_tr, y_tr)

    # Make predictions
    test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
    test_folds_pred = model.predict(
        test_predictors) * df_test["Acre"]

    # Store fold-wise predictions
    fold_wise_predictions[:, i] = test_folds_pred


# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                 df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
    df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv(
    'submission/SubmissionShawFinalRepeatTest.csv', index=False)

print("---Predictions made---")
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000744 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2722
# [LightGBM] [Info] Number of data points in the train set: 3096, number of used features: 47
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 1882.305577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 696:	learn: 1.2788599	total: 23.4s	remaining: 10.2s
# 697:	learn: 1.2677865	total: 23.4s	remaining: 10.1s
# 698:	learn: 1.2562275	total: 23.5s	remaining: 10.1s
# 699:	learn: 1.2498415	total: 23.5s	remaining: 10.1s
# 700:	learn: 1.2391023	total: 23.5s	remaining: 10s
# 701:	learn: 1.2267238	total: 23.6s	remaining: 10s
# 702:	learn: 1.2207491	total: 23.6s	remaining: 9.98s
# 703:	learn: 1.2107990	total: 23.7s	remaining: 9.95s
# 704:	learn: 1.2068735	total: 23.7s	remaining: 9.91s
# 705:	learn: 1.1973841	total: 23.7s	remaining: 9.88s
# 706:	learn: 1.1866720	total: 23.8s	remaining: 9.85s
# 707:	learn: 1.1847008	total: 23.8s	remaining: 9.81s
# 708:	learn: 1.1759217	total: 23.9s	remaining: 9.79s
# 709:	learn: 1.1690469	total: 23.9s	remaining: 9.76s
# 710:	learn: 1.1566487	total: 23.9s	remaining: 9.73s
# 711:	learn: 1.1516303	total: 24s	remaining: 9.7s
# 712:	learn: 1.1458149	total: 24s	remaining: 9.66s
# 713:	learn: 1.1303328	total: 24s	remaining: 9.63s
# 714:	learn: 1.1240792	total: 24.1s	remaining: 9.6s
# 715:	learn: 1.1171001	total: 24.1s	remaining: 9.56s
# 716:	learn: 1.1087514	total: 24.1s	remaining: 9.53s
# 717:	learn: 1.0995743	total: 24.2s	remaining: 9.49s
# 718:	learn: 1.0930572	total: 24.2s	remaining: 9.46s
# 719:	learn: 1.0902614	total: 24.2s	remaining: 9.43s
# 720:	learn: 1.0795707	total: 24.3s	remaining: 9.39s
# 721:	learn: 1.0738599	total: 24.3s	remaining: 9.36s
# 722:	learn: 1.0737853	total: 24.3s	remaining: 9.32s
# 723:	learn: 1.0661752	total: 24.4s	remaining: 9.29s
# 724:	learn: 1.0586007	total: 24.4s	remaining: 9.26s
# 725:	learn: 1.0528310	total: 24.4s	remaining: 9.22s
# 726:	learn: 1.0434628	total: 24.5s	remaining: 9.19s
# 727:	learn: 1.0341732	total: 24.5s	remaining: 9.16s
# 728:	learn: 1.0208195	total: 24.5s	remaining: 9.12s
# 729:	learn: 1.0166921	total: 24.6s	remaining: 9.09s
# 730:	learn: 1.0112654	total: 24.6s	remaining: 9.05s
# 731:	learn: 1.0060363	total: 24.6s	remaining: 9.02s
# 732:	learn: 0.9990501	total: 24.7s	remaining: 8.99s
# 733:	learn: 0.9903497	total: 24.7s	remaining: 8.96s
# 734:	learn: 0.9824917	total: 24.7s	remaining: 8.92s
# 735:	learn: 0.9766176	total: 24.8s	remaining: 8.89s
# 736:	learn: 0.9734539	total: 24.8s	remaining: 8.86s
# 737:	learn: 0.9661292	total: 24.9s	remaining: 8.82s
# 738:	learn: 0.9596373	total: 24.9s	remaining: 8.79s
# 739:	learn: 0.9547281	total: 24.9s	remaining: 8.75s
# 740:	learn: 0.9512650	total: 24.9s	remaining: 8.72s
# 741:	learn: 0.9474021	total: 25s	remaining: 8.69s
# 742:	learn: 0.9444190	total: 25s	remaining: 8.65s
# 743:	learn: 0.9408185	total: 25s	remaining: 8.62s
# 744:	learn: 0.9287456	total: 25.1s	remaining: 8.58s
# 745:	learn: 0.9230021	total: 25.1s	remaining: 8.55s
# 746:	learn: 0.9157803	total: 25.1s	remaining: 8.52s
# 747:	learn: 0.9142767	total: 25.2s	remaining: 8.48s
# 748:	learn: 0.9081935	total: 25.2s	remaining: 8.45s
# 749:	learn: 0.9062639	total: 25.2s	remaining: 8.42s
# 750:	learn: 0.9011490	total: 25.3s	remaining: 8.38s
# 751:	learn: 0.8953334	total: 25.3s	remaining: 8.35s
# 752:	learn: 0.8866718	total: 25.3s	remaining: 8.31s
# 753:	learn: 0.8820593	total: 25.4s	remaining: 8.28s
# 754:	learn: 0.8717185	total: 25.4s	remaining: 8.24s
# 755:	learn: 0.8637738	total: 25.4s	remaining: 8.21s
# 756:	learn: 0.8601004	total: 25.5s	remaining: 8.18s
# 757:	learn: 0.8565194	total: 25.5s	remaining: 8.14s
# 758:	learn: 0.8503157	total: 25.5s	remaining: 8.11s
# 759:	learn: 0.8469933	total: 25.6s	remaining: 8.07s
# 760:	learn: 0.8419336	total: 25.6s	remaining: 8.04s
# 761:	learn: 0.8401666	total: 25.6s	remaining: 8.01s
# 762:	learn: 0.8383576	total: 25.7s	remaining: 7.97s
# 763:	learn: 0.8354312	total: 25.7s	remaining: 7.94s
# 764:	learn: 0.8341978	total: 25.7s	remaining: 7.91s
# 765:	learn: 0.8304238	total: 25.8s	remaining: 7.87s
# 766:	learn: 0.8244444	total: 25.8s	remaining: 7.84s
# 767:	learn: 0.8160425	total: 25.8s	remaining: 7.8s
# 768:	learn: 0.8114830	total: 25.9s	remaining: 7.77s
# 769:	learn: 0.8081500	total: 25.9s	remaining: 7.74s
# 770:	learn: 0.8042281	total: 25.9s	remaining: 7.71s
# 771:	learn: 0.7990720	total: 26s	remaining: 7.67s
# 772:	learn: 0.7930573	total: 26s	remaining: 7.64s
# 773:	learn: 0.7872454	total: 26.1s	remaining: 7.61s
# 774:	learn: 0.7793336	total: 26.1s	remaining: 7.57s
# 775:	learn: 0.7767150	total: 26.1s	remaining: 7.54s
# 776:	learn: 0.7736996	total: 26.1s	remaining: 7.5s
# 777:	learn: 0.7736648	total: 26.2s	remaining: 7.47s
# 778:	learn: 0.7697102	total: 26.2s	remaining: 7.44s
# 779:	learn: 0.7613696	total: 26.2s	remaining: 7.4s
# 780:	learn: 0.7571710	total: 26.3s	remaining: 7.37s
# 781:	learn: 0.7512783	total: 26.3s	remaining: 7.33s
# 782:	learn: 0.7434788	total: 26.4s	remaining: 7.3s
# 783:	learn: 0.7370657	total: 26.4s	remaining: 7.27s
# 784:	learn: 0.7314978	total: 26.4s	remaining: 7.24s
# 785:	learn: 0.7242594	total: 26.4s	remaining: 7.2s
# 786:	learn: 0.7213476	total: 26.5s	remaining: 7.17s
# 787:	learn: 0.7138908	total: 26.5s	remaining: 7.13s
# 788:	learn: 0.7125411	total: 26.5s	remaining: 7.1s
# 789:	learn: 0.7088115	total: 26.6s	remaining: 7.06s
# 790:	learn: 0.7023565	total: 26.6s	remaining: 7.03s
# 791:	learn: 0.6968440	total: 26.6s	remaining: 7s
# 792:	learn: 0.6924303	total: 26.7s	remaining: 6.96s
# 793:	learn: 0.6897575	total: 26.7s	remaining: 6.93s
# 794:	learn: 0.6870500	total: 26.7s	remaining: 6.9s
# 795:	learn: 0.6828673	total: 26.8s	remaining: 6.86s
# 796:	learn: 0.6796145	total: 26.8s	remaining: 6.83s
# 797:	learn: 0.6773276	total: 26.8s	remaining: 6.79s
# 798:	learn: 0.6744761	total: 26.9s	remaining: 6.76s
# 799:	learn: 0.6734932	total: 26.9s	remaining: 6.73s
# 800:	learn: 0.6673641	total: 26.9s	remaining: 6.69s
# 801:	learn: 0.6604651	total: 27s	remaining: 6.66s
# 802:	learn: 0.6559567	total: 27s	remaining: 6.63s
# 803:	learn: 0.6533406	total: 27s	remaining: 6.59s
# 804:	learn: 0.6459151	total: 27.1s	remaining: 6.56s
# 805:	learn: 0.6433942	total: 27.1s	remaining: 6.53s
# 806:	learn: 0.6415301	total: 27.1s	remaining: 6.49s
# 807:	learn: 0.6354494	total: 27.2s	remaining: 6.46s
# 808:	learn: 0.6322122	total: 27.2s	remaining: 6.42s
# 809:	learn: 0.6295713	total: 27.2s	remaining: 6.39s
# 810:	learn: 0.6242126	total: 27.3s	remaining: 6.36s
# 811:	learn: 0.6230930	total: 27.3s	remaining: 6.32s
# 812:	learn: 0.6168367	total: 27.3s	remaining: 6.29s
# 813:	learn: 0.6131440	total: 27.4s	remaining: 6.25s
# 814:	learn: 0.6105496	total: 27.4s	remaining: 6.22s
# 815:	learn: 0.6067219	total: 27.4s	remaining: 6.19s
# 816:	learn: 0.6032117	total: 27.5s	remaining: 6.15s
# 817:	learn: 0.6013250	total: 27.5s	remaining: 6.12s
# 818:	learn: 0.5999050	total: 27.5s	remaining: 6.09s
# 819:	learn: 0.5974637	total: 27.6s	remaining: 6.05s
# 820:	learn: 0.5943749	total: 27.6s	remaining: 6.02s
# 821:	learn: 0.5927203	total: 27.6s	remaining: 5.99s
# 822:	learn: 0.5915807	total: 27.7s	remaining: 5.95s
# 823:	learn: 0.5887386	total: 27.7s	remaining: 5.92s
# 824:	learn: 0.5866084	total: 27.7s	remaining: 5.88s
# 825:	learn: 0.5796972	total: 27.8s	remaining: 5.85s
# 826:	learn: 0.5741507	total: 27.8s	remaining: 5.82s
# 827:	learn: 0.5712457	total: 27.8s	remaining: 5.78s
# 828:	learn: 0.5691562	total: 27.9s	remaining: 5.75s
# 829:	learn: 0.5664335	total: 27.9s	remaining: 5.71s
# 830:	learn: 0.5664071	total: 27.9s	remaining: 5.68s
# 831:	learn: 0.5627974	total: 28s	remaining: 5.65s
# 832:	learn: 0.5611167	total: 28s	remaining: 5.61s
# 833:	learn: 0.5596011	total: 28s	remaining: 5.58s
# 834:	learn: 0.5558441	total: 28.1s	remaining: 5.54s
# 835:	learn: 0.5528632	total: 28.1s	remaining: 5.51s
# 836:	learn: 0.5496999	total: 28.1s	remaining: 5.48s
# 837:	learn: 0.5467647	total: 28.2s	remaining: 5.44s
# 838:	learn: 0.5426582	total: 28.2s	remaining: 5.41s
# 839:	learn: 0.5397864	total: 28.2s	remaining: 5.38s
# 840:	learn: 0.5373312	total: 28.3s	remaining: 5.34s
# 841:	learn: 0.5340298	total: 28.3s	remaining: 5.31s
# 842:	learn: 0.5318614	total: 28.3s	remaining: 5.28s
# 843:	learn: 0.5297164	total: 28.4s	remaining: 5.24s
# 844:	learn: 0.5279438	total: 28.4s	remaining: 5.21s
# 845:	learn: 0.5226972	total: 28.4s	remaining: 5.18s
# 846:	learn: 0.5161338	total: 28.5s	remaining: 5.14s
# 847:	learn: 0.5131864	total: 28.5s	remaining: 5.11s
# 848:	learn: 0.5097248	total: 28.5s	remaining: 5.08s
# 849:	learn: 0.5071718	total: 28.6s	remaining: 5.04s
# 850:	learn: 0.5037078	total: 28.6s	remaining: 5.01s
# 851:	learn: 0.5006045	total: 28.6s	remaining: 4.97s
# 852:	learn: 0.4983361	total: 28.7s	remaining: 4.94s
# 853:	learn: 0.4959514	total: 28.7s	remaining: 4.91s
# 854:	learn: 0.4899216	total: 28.7s	remaining: 4.87s
# 855:	learn: 0.4877673	total: 28.8s	remaining: 4.84s
# 856:	learn: 0.4847934	total: 28.8s	remaining: 4.81s
# 857:	learn: 0.4811756	total: 28.8s	remaining: 4.77s
# 858:	learn: 0.4799129	total: 28.9s	remaining: 4.74s
# 859:	learn: 0.4760631	total: 28.9s	remaining: 4.71s
# 860:	learn: 0.4734254	total: 28.9s	remaining: 4.67s
# 861:	learn: 0.4705103	total: 29s	remaining: 4.64s
# 862:	learn: 0.4677850	total: 29s	remaining: 4.6s
# 863:	learn: 0.4639738	total: 29s	remaining: 4.57s
# 864:	learn: 0.4637815	total: 29.1s	remaining: 4.54s
# 865:	learn: 0.4599474	total: 29.1s	remaining: 4.5s
# 866:	learn: 0.4558446	total: 29.1s	remaining: 4.47s
# 867:	learn: 0.4531694	total: 29.2s	remaining: 4.43s
# 868:	learn: 0.4518231	total: 29.2s	remaining: 4.4s
# 869:	learn: 0.4503647	total: 29.2s	remaining: 4.37s
# 870:	learn: 0.4480132	total: 29.3s	remaining: 4.33s
# 871:	learn: 0.4464449	total: 29.3s	remaining: 4.3s
# 872:	learn: 0.4448002	total: 29.3s	remaining: 4.27s
# 873:	learn: 0.4414459	total: 29.4s	remaining: 4.23s
# 874:	learn: 0.4386654	total: 29.4s	remaining: 4.2s
# 875:	learn: 0.4359092	total: 29.4s	remaining: 4.17s
# 876:	learn: 0.4332167	total: 29.5s	remaining: 4.13s
# 877:	learn: 0.4318195	total: 29.5s	remaining: 4.1s
# 878:	learn: 0.4286317	total: 29.5s	remaining: 4.06s
# 879:	learn: 0.4260888	total: 29.6s	remaining: 4.03s
# 880:	learn: 0.4237971	total: 29.6s	remaining: 4s
# 881:	learn: 0.4209791	total: 29.6s	remaining: 3.96s
# 882:	learn: 0.4184079	total: 29.7s	remaining: 3.93s
# 883:	learn: 0.4145091	total: 29.7s	remaining: 3.9s
# 884:	learn: 0.4119057	total: 29.7s	remaining: 3.86s
# 885:	learn: 0.4108286	total: 29.8s	remaining: 3.83s
# 886:	learn: 0.4088141	total: 29.8s	remaining: 3.8s
# 887:	learn: 0.4042697	total: 29.8s	remaining: 3.76s
# 888:	learn: 0.4025098	total: 29.9s	remaining: 3.73s
# 889:	learn: 0.4003651	total: 29.9s	remaining: 3.7s
# 890:	learn: 0.3981167	total: 29.9s	remaining: 3.66s
# 891:	learn: 0.3961165	total: 30s	remaining: 3.63s
# 892:	learn: 0.3917818	total: 30s	remaining: 3.6s
# 893:	learn: 0.3856832	total: 30s	remaining: 3.56s
# 894:	learn: 0.3819657	total: 30.1s	remaining: 3.53s
# 895:	learn: 0.3802163	total: 30.1s	remaining: 3.5s
# 896:	learn: 0.3775701	total: 30.1s	remaining: 3.46s
# 897:	learn: 0.3741004	total: 30.2s	remaining: 3.43s
# 898:	learn: 0.3709034	total: 30.2s	remaining: 3.4s
# 899:	learn: 0.3682407	total: 30.3s	remaining: 3.36s
# 900:	learn: 0.3648514	total: 30.3s	remaining: 3.33s
# 901:	learn: 0.3636883	total: 30.4s	remaining: 3.3s
# 902:	learn: 0.3624003	total: 30.4s	remaining: 3.26s
# 903:	learn: 0.3593944	total: 30.4s	remaining: 3.23s
# 904:	learn: 0.3566375	total: 30.5s	remaining: 3.2s
# 905:	learn: 0.3541862	total: 30.5s	remaining: 3.16s
# 906:	learn: 0.3522682	total: 30.5s	remaining: 3.13s
# 907:	learn: 0.3491836	total: 30.6s	remaining: 3.1s
# 908:	learn: 0.3456372	total: 30.6s	remaining: 3.06s
# 909:	learn: 0.3421453	total: 30.6s	remaining: 3.03s
# 910:	learn: 0.3406246	total: 30.7s	remaining: 2.99s
# 911:	learn: 0.3379552	total: 30.7s	remaining: 2.96s
# 912:	learn: 0.3357527	total: 30.7s	remaining: 2.93s
# 913:	learn: 0.3334549	total: 30.8s	remaining: 2.89s
# 914:	learn: 0.3329308	total: 30.8s	remaining: 2.86s
# 915:	learn: 0.3295606	total: 30.8s	remaining: 2.83s
# 916:	learn: 0.3277335	total: 30.9s	remaining: 2.79s
# 917:	learn: 0.3255772	total: 30.9s	remaining: 2.76s
# 918:	learn: 0.3250957	total: 30.9s	remaining: 2.72s
# 919:	learn: 0.3233136	total: 30.9s	remaining: 2.69s
# 920:	learn: 0.3207574	total: 31s	remaining: 2.66s
# 921:	learn: 0.3199877	total: 31s	remaining: 2.62s
# 922:	learn: 0.3170931	total: 31.1s	remaining: 2.59s
# 923:	learn: 0.3162768	total: 31.1s	remaining: 2.56s
# 924:	learn: 0.3142577	total: 31.1s	remaining: 2.52s
# 925:	learn: 0.3135734	total: 31.2s	remaining: 2.49s
# 926:	learn: 0.3092721	total: 31.2s	remaining: 2.46s
# 927:	learn: 0.3076994	total: 31.2s	remaining: 2.42s
# 928:	learn: 0.3067214	total: 31.3s	remaining: 2.39s
# 929:	learn: 0.3047678	total: 31.3s	remaining: 2.35s
# 930:	learn: 0.3028707	total: 31.3s	remaining: 2.32s
# 931:	learn: 0.2995924	total: 31.4s	remaining: 2.29s
# 932:	learn: 0.2979168	total: 31.4s	remaining: 2.25s
# 933:	learn: 0.2956133	total: 31.4s	remaining: 2.22s
# 934:	learn: 0.2917368	total: 31.5s	remaining: 2.19s
# 935:	learn: 0.2897780	total: 31.5s	remaining: 2.15s
# 936:	learn: 0.2885339	total: 31.5s	remaining: 2.12s
# 937:	learn: 0.2865397	total: 31.6s	remaining: 2.09s
# 938:	learn: 0.2847178	total: 31.6s	remaining: 2.05s
# 939:	learn: 0.2843855	total: 31.6s	remaining: 2.02s
# 940:	learn: 0.2830271	total: 31.7s	remaining: 1.98s
# 941:	learn: 0.2811938	total: 31.7s	remaining: 1.95s
# 942:	learn: 0.2802658	total: 31.7s	remaining: 1.92s
# 943:	learn: 0.2796442	total: 31.8s	remaining: 1.88s
# 944:	learn: 0.2774852	total: 31.8s	remaining: 1.85s
# 945:	learn: 0.2765841	total: 31.8s	remaining: 1.82s
# 946:	learn: 0.2756761	total: 31.9s	remaining: 1.78s
# 947:	learn: 0.2717415	total: 31.9s	remaining: 1.75s
# 948:	learn: 0.2698250	total: 31.9s	remaining: 1.72s
# 949:	learn: 0.2673296	total: 32s	remaining: 1.68s
# 950:	learn: 0.2664772	total: 32s	remaining: 1.65s
# 951:	learn: 0.2655572	total: 32s	remaining: 1.61s
# 952:	learn: 0.2632930	total: 32s	remaining: 1.58s
# 953:	learn: 0.2624348	total: 32.1s	remaining: 1.55s
# 954:	learn: 0.2623067	total: 32.1s	remaining: 1.51s
# 955:	learn: 0.2609612	total: 32.2s	remaining: 1.48s
# 956:	learn: 0.2597533	total: 32.2s	remaining: 1.45s
# 957:	learn: 0.2596630	total: 32.2s	remaining: 1.41s
# 958:	learn: 0.2583137	total: 32.3s	remaining: 1.38s
# 959:	learn: 0.2569317	total: 32.3s	remaining: 1.34s
# 960:	learn: 0.2561865	total: 32.3s	remaining: 1.31s
# 961:	learn: 0.2554040	total: 32.4s	remaining: 1.28s
# 962:	learn: 0.2521667	total: 32.4s	remaining: 1.24s
# 963:	learn: 0.2517187	total: 32.4s	remaining: 1.21s
# 964:	learn: 0.2505127	total: 32.5s	remaining: 1.18s
# 965:	learn: 0.2497427	total: 32.5s	remaining: 1.14s
# 966:	learn: 0.2482071	total: 32.5s	remaining: 1.11s
# 967:	learn: 0.2464778	total: 32.6s	remaining: 1.08s
# 968:	learn: 0.2451988	total: 32.6s	remaining: 1.04s
# 969:	learn: 0.2440385	total: 32.6s	remaining: 1.01s
# 970:	learn: 0.2427077	total: 32.6s	remaining: 975ms
# 971:	learn: 0.2414581	total: 32.7s	remaining: 941ms
# 972:	learn: 0.2403868	total: 32.7s	remaining: 908ms
# 973:	learn: 0.2379440	total: 32.7s	remaining: 874ms
# 974:	learn: 0.2367189	total: 32.8s	remaining: 840ms
# 975:	learn: 0.2355343	total: 32.8s	remaining: 807ms
# 976:	learn: 0.2349122	total: 32.8s	remaining: 773ms
# 977:	learn: 0.2346554	total: 32.9s	remaining: 740ms
# 978:	learn: 0.2338428	total: 32.9s	remaining: 706ms
# 979:	learn: 0.2314291	total: 32.9s	remaining: 672ms
# 980:	learn: 0.2303757	total: 33s	remaining: 639ms
# 981:	learn: 0.2295318	total: 33s	remaining: 605ms
# 982:	learn: 0.2274245	total: 33s	remaining: 571ms
# 983:	learn: 0.2270290	total: 33.1s	remaining: 538ms
# 984:	learn: 0.2263919	total: 33.1s	remaining: 504ms
# 985:	learn: 0.2255400	total: 33.1s	remaining: 471ms
# 986:	learn: 0.2240791	total: 33.2s	remaining: 437ms
# 987:	learn: 0.2222722	total: 33.2s	remaining: 403ms
# 988:	learn: 0.2208406	total: 33.2s	remaining: 370ms
# 989:	learn: 0.2190817	total: 33.3s	remaining: 336ms
# 990:	learn: 0.2184789	total: 33.3s	remaining: 302ms
# 991:	learn: 0.2184656	total: 33.3s	remaining: 269ms
# 992:	learn: 0.2175754	total: 33.4s	remaining: 235ms
# 993:	learn: 0.2152771	total: 33.4s	remaining: 202ms
# 994:	learn: 0.2143464	total: 33.4s	remaining: 168ms
# 995:	learn: 0.2129741	total: 33.5s	remaining: 134ms
# 996:	learn: 0.2129666	total: 33.5s	remaining: 101ms
# 997:	learn: 0.2123315	total: 33.5s	remaining: 67.2ms
# 998:	learn: 0.2109029	total: 33.6s	remaining: 33.6ms
# 999:	learn: 0.2097121	total: 33.6s	remaining: 0us
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# ---Predictions made---

# %%
test_folds_pred = model.predict(
    test_predictors) * df_test["Acre"]

# Store fold-wise predictions
fold_wise_predictions[:, i] = test_folds_pred


# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv(
'submission/SubmissionShawFinalRepeatTest.csv', index=False)

print("---Predictions made---")


SubmissionShawFinalRepeatTest = pd.read_csv(
    'submission/SubmissionShawFinalRepeatTest.csv')
SubmissionShawFinal = pd.read_csv('submission/SubmissionShawFinal.csv')

difference = (SubmissionShawFinal['Yield']).subtract(
    SubmissionShawFinalRepeatTest['Yield'])
positive_difference = difference.abs()
sum_of_positive_difference = positive_difference.sum().sum()

# %%
print(sum_of_positive_difference)
# Out:
# 8989.400778719299
