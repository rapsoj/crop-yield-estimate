# %%
# import os
# import sys


# # Import data cleaning libraries
# import pandas as pd
# import numpy as np
# from sklearn.metrics import mean_squared_error


# # Import machine learning libraries
# from sklearn.model_selection import train_test_split
# from sklearn import svm
# from sklearn.pipeline import Pipeline
# from sklearn.model_selection import GridSearchCV
# import xgboost as xgb
# from sklearn.feature_selection import SelectFromModel
# from sklearn.linear_model import Lasso
# from sklearn.svm import SVC
# from sklearn.ensemble import VotingClassifier

# # Import data visualisation libraries
# import matplotlib.pyplot as plt

# # Import warning libraries
# import warnings
# warnings.filterwarnings("ignore")

# # Set working directory
# # Set this to your own path
# os.chdir('/home/shaw/Documents/GitHub/crop-yield-estimate/')
# # Set this to your own path
# sys.path.insert(0, '/home/shaw/Documents/GitHub/crop-yield-estimate/pipeline')


# from preprocessing import dim_reduction
# from preprocessing import feature_selection
# from preprocessing import scaling
# from preprocessing import feature_engineering
# from preprocessing import cleaning


# # Import preprocessing libraries
# # Import system libraries
# # Preprocess data
# train_path = "data/Train.csv"
# test_path = "data/Test.csv"
# df = cleaning.clean_data(train_path, test_path)
# df = feature_engineering.get_features(df)
# df = scaling.scale_features(df)
# df = feature_selection.select_features(df)
# df = dim_reduction.reduce_dim(df)


# df.drop(['SeedlingsPerPit',
#          'Ganaura',
#          'CropOrgFYM',
#          'NoFertilizerAppln',
#          'BasalDAP',
#          'BasalUrea',
#          '2appDaysUrea',
#          'Harv_hand_rent',
#          'Residue_length',
#          'TransplantingIrrigationHours_per_Acre',
#          'TransIrriCost_per_Acre',
#          'CropOrgFYM_per_Acre',
#          'BasalDAP_per_Acre',
#          'BasalUrea_per_Acre',
#          '1tdUrea_per_Acre',
#          'Harv_hand_rent_per_Acre',
#          'TpIrrigationCost_Imputed_per_Acre',
#          'Days_bw_SowTransp_Harv',
#          'Days_bw_Harv_Thresh',
#          'NursingDate_ModeDiff',
#          'TillageDate_ModeDiff',
#          'HarvestDate_ModeDiff',
#          'ThreshingDate_ModeDiff',
#          'Num_LandPrepMethod',
#          'Num_CropbasalFerts',
#          'Num_TopDressFert',
#          'Latitude',
#          'Longitude',
#          'CropEstMethod_LineSowingAfterTillage',
#          'Threshing_method_machine',
#          'Stubble_use_plowed_in_soil',
#          'LandPrepMethod_FourWheelTracRotavator_True',
#          'LandPrepMethod_WetTillagePuddling_True',
#          'NursDetFactor_PreMonsoonShowers_True',
#          'NursDetFactor_LabourAvailability_True',
#          'FirstTopDressFert_DAP_True',
#          'HarvestMonth_November',
#          'ThreshingMonth_January',
#          'Block_Chehrakala',
#          'PCropSolidOrgFertAppMethod_Broadcasting',
#          'PCropSolidOrgFertAppMethod_SoilApplied',
#          'MineralFertAppMethod_1_Broadcasting',
#          'MineralFertAppMethod_1_SoilApplied',
#          'PC4',
#          'PC10',
#          'PC21',], axis=1, inplace=True)

# # Split data into training and test sets
# df_train = df[df['Yield'].isna() == False]
# df_test = df[df['Yield'].isna() == True]


# df_train.dropna(axis=1, inplace=True)
# df_test.dropna(axis=1, inplace=True)


# # df_train.drop(['PCropSolidOrgFertAppMethod_NaN_True',
# #               'PCropSolidOrgFertAppMethod_RootApplication'], axis=1, inplace=True)
# # df_train_PC = df_train.loc[:, df_train.columns.str.startswith('PC')]
# # df_train_PC = df_train_PC.join(df_train['New_Yield'])
# # df_train_PC = df_train_PC.join(df_train['New_Yield_per_Acre'])


# outcome_cols = ["New_Yield", "New_Yield_per_Acre", 'Yield', 'Yield_per_Acre']

# # Drop columns excluding the top features
# X, y = df_train.drop(outcome_cols, axis=1), df_train["Yield_per_Acre"]

# %%
# Import system libraries

import os
import sys

# Import data cleaning libraries
import pandas as pd
import numpy as np
import calendar
from datetime import datetime

# Import machine learning libraries
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold, GridSearchCV

# Import data visualisation libraries
import matplotlib.pyplot as plt

# Import warning libraries
import warnings
warnings.filterwarnings("ignore")

# Set working directory
# Set this to your own path
os.chdir('/home/shaw/Documents/GitHub/crop-yield-estimate/')
# Set this to your own path
sys.path.insert(0, '/home/shaw/Documents/GitHub/crop-yield-estimate/pipeline')

# Import preprocessing libraries
from preprocessing import clustering
from preprocessing import dim_reduction
from preprocessing import feature_selection
from preprocessing import scaling
from preprocessing import feature_engineering
from preprocessing import cleaning

# Preprocess data
train_path = "data/Train.csv"
test_path = "data/Test.csv"
df = cleaning.clean_data(train_path, test_path)
df = feature_engineering.get_features(df)
df = scaling.scale_features(df)
df = feature_selection.select_features(df)
df = dim_reduction.reduce_dim(df)
df = clustering.get_clusters(df)

# # Add error predictions
# errors = pd.read_csv("pipeline/support_models/Error_Prediction.csv")
# df["Error_Prediction"] = errors["Error_Prediction"]

# # Add block predictions
# block = pd.read_csv("pipeline/support_models/Block_Prediction.csv")
# df["Block_Prediction"] = block["Block_Prediction"]

# # Add linear error predictions
# linear_yield = pd.read_csv(
#     "pipeline/support_models/Linear_Yield_Prediction.csv")
# df["Linear_Yield_Prediction"] = linear_yield["Linear_Yield_Prediction"]

# Split data into training and test sets
df_train = df[df['Yield'].isna() == False]
df_test = df[df['Yield'].isna() == True]

# %%
top_cols = ['SeedlingsPerPit','Ganaura','CropOrgFYM','NoFertilizerAppln','BasalDAP',
            'BasalUrea','2appDaysUrea','Harv_hand_rent','Residue_length',
            'TransplantingIrrigationHours_per_Acre','TransIrriCost_per_Acre',
            'CropOrgFYM_per_Acre','BasalDAP_per_Acre','BasalUrea_per_Acre','1tdUrea_per_Acre',
            'Harv_hand_rent_per_Acre','TpIrrigationCost_Imputed_per_Acre',
            'Days_bw_SowTransp_Harv','Days_bw_Harv_Thresh','NursingDate_ModeDiff',
            'TillageDate_ModeDiff','HarvestDate_ModeDiff','ThreshingDate_ModeDiff',
            'Num_LandPrepMethod','Num_CropbasalFerts','Num_TopDressFert','Latitude',
            'Longitude','CropEstMethod_LineSowingAfterTillage','Threshing_method_machine',
            'Stubble_use_plowed_in_soil','LandPrepMethod_FourWheelTracRotavator_True',
            'LandPrepMethod_WetTillagePuddling_True','NursDetFactor_PreMonsoonShowers_True',
            'NursDetFactor_LabourAvailability_True','FirstTopDressFert_DAP_True',
            'HarvestMonth_November','ThreshingMonth_January','Block_Chehrakala',
            'PCropSolidOrgFertAppMethod_Broadcasting','PCropSolidOrgFertAppMethod_SoilApplied',
            'MineralFertAppMethod_1_Broadcasting','MineralFertAppMethod_1_SoilApplied','PC4',
            'PC10','PC21','top_shapley_k2_label_1', 'TpIrrigationHours_Imputed',
            'TpIrrigationCost_Imputed', 'SeedlingsPerPit_Imputed', 'NursingDate_ModeDiff_Imputed',
            '2appDaysUrea_Imputed']#,'Error_Prediction','Block_Prediction']#,'Linear_Yield_Prediction']

# Remove the specified columns from top_cols
columns_to_remove = ['SeedlingsPerPit', 'TransplantingIrrigationHours', 'TransIrriCost', 'StandingWater',
                     '1appDaysUrea', '2appDaysUrea', 'TransplantingIrrigationHours_per_Acre',
                     'TransIrriCost_per_Acre', 'TransplantingIrrigationHours_per_Acre_capped',
                     'TransIrriCost_per_Acre_capped', 'Days_bw_Nurs_SowTransp', 'Days_bw_Nurs_Harv',
                     'Days_bw_Nurs_Till', 'NursingDate_ModeDiff', 'Days_bw_Nurs_SowTransp_ModeDiff',
                     'Days_bw_Nurs_Harv_ModeDiff', 'Days_bw_Nurs_Till_ModeDiff', '2appDaysUrea_MeanDiff']

for column in columns_to_remove:
    if column in top_cols:
     top_cols.remove(column)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVC
import shap
from sklearn.ensemble import VotingRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
import xgboost as xgb


# Split data
outcome_cols = ["Yield", "Yield_per_Acre", "New_Yield", "New_Yield_per_Acre"]

X, y = df_train.drop(outcome_cols, axis=1), df_train["New_Yield_per_Acre"]
X = X[top_cols]


# Initialize an array to store fold-wise predictions
k = 5
fold_wise_predictions = np.zeros((len(df_test), k))

# Define number of splits for k-fold cross-validation
kfold = KFold(n_splits=k, shuffle=True, random_state=42)

# Iterate over each fold and train XGBoost model
for i, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[train_idx], y.iloc[val_idx]

    # Instantiate an XGBoost regressor model
    best_params = {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100,
                   'alpha': 0, 'lambda': 0}
    xgb_reg = xgb.XGBRegressor(**best_params, colsample_bytree=0.3)



    # Tuned Tree estimators
    lgbm = LGBMRegressor(boosting_type='goss', n_estimators=1000, learning_rate=0.08, num_leaves=100, max_depth=7)
    catboost = CatBoostRegressor(depth=10, iterations=1000, learning_rate=0.5, l2_leaf_reg=5)


    # Define the VotingRegressor
    voting_regressor = VotingRegressor(
        estimators=[
            ('lgbm', lgbm),
            ('catboost', catboost),
            ('xgboost', xgb_reg)
        ], weights=[2, 3, 1]
    )


    # Fit the model
    voting_regressor.fit(X_tr, y_tr)

    # Make predictions
    test_predictors = df_test.drop(outcome_cols, axis=1)[top_cols]
    test_folds_pred = voting_regressor.predict(
        test_predictors) * df_test["Acre"]


    # Store fold-wise predictions
    fold_wise_predictions[:, i] = test_folds_pred

    
# Calculate the average of predictions from each fold for each row
final_predictions = np.mean(fold_wise_predictions, axis=1)


# Add predictions to sample submission file
df_test_pred = pd.read_csv("data/SampleSubmission.csv")
df_test_pred['Yield'] = final_predictions
df_test_pred['Yield'] = np.where(df_test_pred['ID'] == 'ID_PMSOXFT4FYDW',
                                 df_test_pred['Yield'] * 10, df_test_pred['Yield'])

# Choose a floor value
df_test_pred['Yield'] = np.where(
    df_test_pred['Yield'] <= 4, 4, df_test_pred['Yield'])

# Export submission
df_test_pred.to_csv('submission/SubmissionShawFinal.csv', index=False)

print("---Predictions made---")
# Out:
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002098 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2722
# [LightGBM] [Info] Number of data points in the train set: 3096, number of used features: 47
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] Start training from score 1882.305577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# 696:	learn: 1.3740495	total: 24.9s	remaining: 10.8s
# 697:	learn: 1.3699639	total: 25s	remaining: 10.8s
# 698:	learn: 1.3667037	total: 25s	remaining: 10.8s
# 699:	learn: 1.3663978	total: 25s	remaining: 10.7s
# 700:	learn: 1.3594723	total: 25.1s	remaining: 10.7s
# 701:	learn: 1.3506227	total: 25.1s	remaining: 10.7s
# 702:	learn: 1.3492662	total: 25.1s	remaining: 10.6s
# 703:	learn: 1.3406266	total: 25.2s	remaining: 10.6s
# 704:	learn: 1.3337210	total: 25.2s	remaining: 10.6s
# 705:	learn: 1.3210895	total: 25.3s	remaining: 10.5s
# 706:	learn: 1.3036288	total: 25.3s	remaining: 10.5s
# 707:	learn: 1.2969151	total: 25.3s	remaining: 10.4s
# 708:	learn: 1.2887108	total: 25.4s	remaining: 10.4s
# 709:	learn: 1.2827757	total: 25.4s	remaining: 10.4s
# 710:	learn: 1.2778790	total: 25.4s	remaining: 10.3s
# 711:	learn: 1.2654427	total: 25.5s	remaining: 10.3s
# 712:	learn: 1.2590184	total: 25.5s	remaining: 10.3s
# 713:	learn: 1.2571983	total: 25.5s	remaining: 10.2s
# 714:	learn: 1.2554255	total: 25.6s	remaining: 10.2s
# 715:	learn: 1.2448332	total: 25.6s	remaining: 10.2s
# 716:	learn: 1.2396402	total: 25.6s	remaining: 10.1s
# 717:	learn: 1.2395568	total: 25.7s	remaining: 10.1s
# 718:	learn: 1.2394746	total: 25.7s	remaining: 10.1s
# 719:	learn: 1.2365250	total: 25.8s	remaining: 10s
# 720:	learn: 1.2260186	total: 25.8s	remaining: 9.98s
# 721:	learn: 1.2166969	total: 25.8s	remaining: 9.95s
# 722:	learn: 1.2122816	total: 25.9s	remaining: 9.91s
# 723:	learn: 1.2024565	total: 25.9s	remaining: 9.88s
# 724:	learn: 1.1877983	total: 25.9s	remaining: 9.84s
# 725:	learn: 1.1806629	total: 26s	remaining: 9.8s
# 726:	learn: 1.1753675	total: 26s	remaining: 9.77s
# 727:	learn: 1.1654104	total: 26s	remaining: 9.73s
# 728:	learn: 1.1572051	total: 26.1s	remaining: 9.69s
# 729:	learn: 1.1508771	total: 26.1s	remaining: 9.66s
# 730:	learn: 1.1460156	total: 26.1s	remaining: 9.62s
# 731:	learn: 1.1374425	total: 26.2s	remaining: 9.58s
# 732:	learn: 1.1283013	total: 26.2s	remaining: 9.54s
# 733:	learn: 1.1265009	total: 26.2s	remaining: 9.51s
# 734:	learn: 1.1217791	total: 26.3s	remaining: 9.47s
# 735:	learn: 1.1142570	total: 26.3s	remaining: 9.44s
# 736:	learn: 1.1100586	total: 26.4s	remaining: 9.41s
# 737:	learn: 1.1064577	total: 26.4s	remaining: 9.37s
# 738:	learn: 1.0968314	total: 26.4s	remaining: 9.34s
# 739:	learn: 1.0829570	total: 26.5s	remaining: 9.3s
# 740:	learn: 1.0775976	total: 26.5s	remaining: 9.26s
# 741:	learn: 1.0692887	total: 26.5s	remaining: 9.23s
# 742:	learn: 1.0662384	total: 26.6s	remaining: 9.19s
# 743:	learn: 1.0570058	total: 26.6s	remaining: 9.15s
# 744:	learn: 1.0557712	total: 26.6s	remaining: 9.12s
# 745:	learn: 1.0468999	total: 26.7s	remaining: 9.08s
# 746:	learn: 1.0425387	total: 26.7s	remaining: 9.04s
# 747:	learn: 1.0422189	total: 26.7s	remaining: 9.01s
# 748:	learn: 1.0340075	total: 26.8s	remaining: 8.97s
# 749:	learn: 1.0314442	total: 26.8s	remaining: 8.93s
# 750:	learn: 1.0238096	total: 26.8s	remaining: 8.9s
# 751:	learn: 1.0226483	total: 26.9s	remaining: 8.86s
# 752:	learn: 1.0170471	total: 26.9s	remaining: 8.82s
# 753:	learn: 1.0108682	total: 26.9s	remaining: 8.79s
# 754:	learn: 1.0064953	total: 27s	remaining: 8.75s
# 755:	learn: 1.0063699	total: 27s	remaining: 8.71s
# 756:	learn: 1.0062740	total: 27s	remaining: 8.68s
# 757:	learn: 1.0053880	total: 27.1s	remaining: 8.64s
# 758:	learn: 0.9988133	total: 27.1s	remaining: 8.6s
# 759:	learn: 0.9926506	total: 27.1s	remaining: 8.57s
# 760:	learn: 0.9853994	total: 27.2s	remaining: 8.53s
# 761:	learn: 0.9799713	total: 27.2s	remaining: 8.49s
# 762:	learn: 0.9744668	total: 27.2s	remaining: 8.46s
# 763:	learn: 0.9638998	total: 27.3s	remaining: 8.42s
# 764:	learn: 0.9554167	total: 27.3s	remaining: 8.39s
# 765:	learn: 0.9498632	total: 27.3s	remaining: 8.35s
# 766:	learn: 0.9466662	total: 27.4s	remaining: 8.31s
# 767:	learn: 0.9445478	total: 27.4s	remaining: 8.28s
# 768:	learn: 0.9419945	total: 27.4s	remaining: 8.24s
# 769:	learn: 0.9352842	total: 27.5s	remaining: 8.21s
# 770:	learn: 0.9242182	total: 27.5s	remaining: 8.17s
# 771:	learn: 0.9137363	total: 27.5s	remaining: 8.13s
# 772:	learn: 0.9118348	total: 27.6s	remaining: 8.1s
# 773:	learn: 0.9086742	total: 27.6s	remaining: 8.06s
# 774:	learn: 0.9020077	total: 27.7s	remaining: 8.03s
# 775:	learn: 0.9011751	total: 27.7s	remaining: 8s
# 776:	learn: 0.9010877	total: 27.7s	remaining: 7.96s
# 777:	learn: 0.8960915	total: 27.8s	remaining: 7.92s
# 778:	learn: 0.8953037	total: 27.8s	remaining: 7.89s
# 779:	learn: 0.8851576	total: 27.8s	remaining: 7.85s
# 780:	learn: 0.8807655	total: 27.9s	remaining: 7.82s
# 781:	learn: 0.8719421	total: 27.9s	remaining: 7.78s
# 782:	learn: 0.8676669	total: 27.9s	remaining: 7.74s
# 783:	learn: 0.8624820	total: 28s	remaining: 7.71s
# 784:	learn: 0.8592825	total: 28s	remaining: 7.67s
# 785:	learn: 0.8558919	total: 28s	remaining: 7.63s
# 786:	learn: 0.8523522	total: 28.1s	remaining: 7.6s
# 787:	learn: 0.8486230	total: 28.1s	remaining: 7.56s
# 788:	learn: 0.8461569	total: 28.1s	remaining: 7.53s
# 789:	learn: 0.8418819	total: 28.2s	remaining: 7.49s
# 790:	learn: 0.8351581	total: 28.2s	remaining: 7.45s
# 791:	learn: 0.8298038	total: 28.2s	remaining: 7.42s
# 792:	learn: 0.8273981	total: 28.3s	remaining: 7.38s
# 793:	learn: 0.8210127	total: 28.3s	remaining: 7.34s
# 794:	learn: 0.8126155	total: 28.3s	remaining: 7.31s
# 795:	learn: 0.8085676	total: 28.4s	remaining: 7.27s
# 796:	learn: 0.7993078	total: 28.4s	remaining: 7.24s
# 797:	learn: 0.7960517	total: 28.4s	remaining: 7.2s
# 798:	learn: 0.7905533	total: 28.5s	remaining: 7.16s
# 799:	learn: 0.7895474	total: 28.5s	remaining: 7.13s
# 800:	learn: 0.7854011	total: 28.5s	remaining: 7.09s
# 801:	learn: 0.7804577	total: 28.6s	remaining: 7.05s
# 802:	learn: 0.7753635	total: 28.6s	remaining: 7.02s
# 803:	learn: 0.7753251	total: 28.6s	remaining: 6.98s
# 804:	learn: 0.7700555	total: 28.7s	remaining: 6.95s
# 805:	learn: 0.7698705	total: 28.7s	remaining: 6.92s
# 806:	learn: 0.7673403	total: 28.8s	remaining: 6.88s
# 807:	learn: 0.7625254	total: 28.8s	remaining: 6.85s
# 808:	learn: 0.7559155	total: 28.8s	remaining: 6.81s
# 809:	learn: 0.7527830	total: 28.9s	remaining: 6.77s
# 810:	learn: 0.7501278	total: 28.9s	remaining: 6.74s
# 811:	learn: 0.7448476	total: 28.9s	remaining: 6.7s
# 812:	learn: 0.7392688	total: 29s	remaining: 6.67s
# 813:	learn: 0.7363708	total: 29s	remaining: 6.63s
# 814:	learn: 0.7308328	total: 29s	remaining: 6.59s
# 815:	learn: 0.7250128	total: 29.1s	remaining: 6.55s
# 816:	learn: 0.7235354	total: 29.1s	remaining: 6.52s
# 817:	learn: 0.7177802	total: 29.1s	remaining: 6.48s
# 818:	learn: 0.7160129	total: 29.2s	remaining: 6.45s
# 819:	learn: 0.7091374	total: 29.2s	remaining: 6.41s
# 820:	learn: 0.7020303	total: 29.2s	remaining: 6.37s
# 821:	learn: 0.7010854	total: 29.3s	remaining: 6.34s
# 822:	learn: 0.6964242	total: 29.3s	remaining: 6.3s
# 823:	learn: 0.6943407	total: 29.3s	remaining: 6.27s
# 824:	learn: 0.6899360	total: 29.4s	remaining: 6.24s
# 825:	learn: 0.6844688	total: 29.4s	remaining: 6.2s
# 826:	learn: 0.6829039	total: 29.5s	remaining: 6.17s
# 827:	learn: 0.6803505	total: 29.5s	remaining: 6.13s
# 828:	learn: 0.6754385	total: 29.5s	remaining: 6.09s
# 829:	learn: 0.6719129	total: 29.6s	remaining: 6.06s
# 830:	learn: 0.6678241	total: 29.6s	remaining: 6.02s
# 831:	learn: 0.6673332	total: 29.6s	remaining: 5.99s
# 832:	learn: 0.6633022	total: 29.7s	remaining: 5.95s
# 833:	learn: 0.6564618	total: 29.7s	remaining: 5.91s
# 834:	learn: 0.6559286	total: 29.7s	remaining: 5.88s
# 835:	learn: 0.6508783	total: 29.8s	remaining: 5.84s
# 836:	learn: 0.6482066	total: 29.8s	remaining: 5.8s
# 837:	learn: 0.6478314	total: 29.8s	remaining: 5.77s
# 838:	learn: 0.6442964	total: 29.9s	remaining: 5.73s
# 839:	learn: 0.6422476	total: 29.9s	remaining: 5.69s
# 840:	learn: 0.6387355	total: 29.9s	remaining: 5.66s
# 841:	learn: 0.6361388	total: 30s	remaining: 5.62s
# 842:	learn: 0.6345936	total: 30s	remaining: 5.59s
# 843:	learn: 0.6291677	total: 30.1s	remaining: 5.56s
# 844:	learn: 0.6246916	total: 30.1s	remaining: 5.52s
# 845:	learn: 0.6223209	total: 30.1s	remaining: 5.48s
# 846:	learn: 0.6176550	total: 30.2s	remaining: 5.45s
# 847:	learn: 0.6136701	total: 30.2s	remaining: 5.41s
# 848:	learn: 0.6133021	total: 30.2s	remaining: 5.38s
# 849:	learn: 0.6093464	total: 30.3s	remaining: 5.34s
# 850:	learn: 0.6078541	total: 30.3s	remaining: 5.3s
# 851:	learn: 0.6042174	total: 30.3s	remaining: 5.27s
# 852:	learn: 0.6040568	total: 30.4s	remaining: 5.23s
# 853:	learn: 0.6025930	total: 30.4s	remaining: 5.2s
# 854:	learn: 0.6002988	total: 30.4s	remaining: 5.16s
# 855:	learn: 0.5988432	total: 30.5s	remaining: 5.13s
# 856:	learn: 0.5976273	total: 30.5s	remaining: 5.09s
# 857:	learn: 0.5937947	total: 30.5s	remaining: 5.05s
# 858:	learn: 0.5920366	total: 30.6s	remaining: 5.02s
# 859:	learn: 0.5885382	total: 30.6s	remaining: 4.98s
# 860:	learn: 0.5849736	total: 30.6s	remaining: 4.95s
# 861:	learn: 0.5829573	total: 30.7s	remaining: 4.91s
# 862:	learn: 0.5792843	total: 30.7s	remaining: 4.87s
# 863:	learn: 0.5784396	total: 30.7s	remaining: 4.84s
# 864:	learn: 0.5772010	total: 30.8s	remaining: 4.8s
# 865:	learn: 0.5722562	total: 30.8s	remaining: 4.77s
# 866:	learn: 0.5674043	total: 30.8s	remaining: 4.73s
# 867:	learn: 0.5666383	total: 30.9s	remaining: 4.69s
# 868:	learn: 0.5617284	total: 30.9s	remaining: 4.66s
# 869:	learn: 0.5603257	total: 30.9s	remaining: 4.62s
# 870:	learn: 0.5591300	total: 31s	remaining: 4.59s
# 871:	learn: 0.5566347	total: 31s	remaining: 4.55s
# 872:	learn: 0.5508162	total: 31s	remaining: 4.51s
# 873:	learn: 0.5460631	total: 31.1s	remaining: 4.48s
# 874:	learn: 0.5441797	total: 31.1s	remaining: 4.44s
# 875:	learn: 0.5400314	total: 31.1s	remaining: 4.41s
# 876:	learn: 0.5357860	total: 31.2s	remaining: 4.37s
# 877:	learn: 0.5344932	total: 31.2s	remaining: 4.33s
# 878:	learn: 0.5283990	total: 31.2s	remaining: 4.3s
# 879:	learn: 0.5239875	total: 31.3s	remaining: 4.26s
# 880:	learn: 0.5188266	total: 31.3s	remaining: 4.23s
# 881:	learn: 0.5159800	total: 31.3s	remaining: 4.19s
# 882:	learn: 0.5118829	total: 31.4s	remaining: 4.16s
# 883:	learn: 0.5096723	total: 31.4s	remaining: 4.12s
# 884:	learn: 0.5074772	total: 31.4s	remaining: 4.08s
# 885:	learn: 0.5050536	total: 31.5s	remaining: 4.05s
# 886:	learn: 0.5030216	total: 31.5s	remaining: 4.01s
# 887:	learn: 0.4990798	total: 31.6s	remaining: 3.98s
# 888:	learn: 0.4953486	total: 31.6s	remaining: 3.94s
# 889:	learn: 0.4953276	total: 31.6s	remaining: 3.91s
# 890:	learn: 0.4937974	total: 31.7s	remaining: 3.87s
# 891:	learn: 0.4912617	total: 31.7s	remaining: 3.84s
# 892:	learn: 0.4886507	total: 31.7s	remaining: 3.8s
# 893:	learn: 0.4857178	total: 31.8s	remaining: 3.77s
# 894:	learn: 0.4825274	total: 31.8s	remaining: 3.73s
# 895:	learn: 0.4776030	total: 31.8s	remaining: 3.69s
# 896:	learn: 0.4773095	total: 31.9s	remaining: 3.66s
# 897:	learn: 0.4752515	total: 31.9s	remaining: 3.62s
# 898:	learn: 0.4728964	total: 31.9s	remaining: 3.59s
# 899:	learn: 0.4723470	total: 32s	remaining: 3.55s
# 900:	learn: 0.4699136	total: 32s	remaining: 3.52s
# 901:	learn: 0.4678407	total: 32s	remaining: 3.48s
# 902:	learn: 0.4677848	total: 32.1s	remaining: 3.44s
# 903:	learn: 0.4671031	total: 32.1s	remaining: 3.41s
# 904:	learn: 0.4641042	total: 32.1s	remaining: 3.37s
# 905:	learn: 0.4608480	total: 32.2s	remaining: 3.34s
# 906:	learn: 0.4581028	total: 32.2s	remaining: 3.3s
# 907:	learn: 0.4558553	total: 32.2s	remaining: 3.27s
# 908:	learn: 0.4503764	total: 32.3s	remaining: 3.23s
# 909:	learn: 0.4442379	total: 32.3s	remaining: 3.19s
# 910:	learn: 0.4435040	total: 32.3s	remaining: 3.16s
# 911:	learn: 0.4406594	total: 32.4s	remaining: 3.12s
# 912:	learn: 0.4378927	total: 32.4s	remaining: 3.09s
# 913:	learn: 0.4353932	total: 32.4s	remaining: 3.05s
# 914:	learn: 0.4353427	total: 32.5s	remaining: 3.02s
# 915:	learn: 0.4353220	total: 32.5s	remaining: 2.98s
# 916:	learn: 0.4335668	total: 32.6s	remaining: 2.95s
# 917:	learn: 0.4321101	total: 32.6s	remaining: 2.91s
# 918:	learn: 0.4315315	total: 32.6s	remaining: 2.88s
# 919:	learn: 0.4302041	total: 32.7s	remaining: 2.84s
# 920:	learn: 0.4282189	total: 32.7s	remaining: 2.81s
# 921:	learn: 0.4271056	total: 32.7s	remaining: 2.77s
# 922:	learn: 0.4240361	total: 32.8s	remaining: 2.73s
# 923:	learn: 0.4206231	total: 32.8s	remaining: 2.7s
# 924:	learn: 0.4180033	total: 32.8s	remaining: 2.66s
# 925:	learn: 0.4179829	total: 32.9s	remaining: 2.63s
# 926:	learn: 0.4148174	total: 32.9s	remaining: 2.59s
# 927:	learn: 0.4140805	total: 32.9s	remaining: 2.56s
# 928:	learn: 0.4112548	total: 33s	remaining: 2.52s
# 929:	learn: 0.4109881	total: 33s	remaining: 2.48s
# 930:	learn: 0.4059058	total: 33s	remaining: 2.45s
# 931:	learn: 0.4053289	total: 33.1s	remaining: 2.41s
# 932:	learn: 0.4032040	total: 33.1s	remaining: 2.38s
# 933:	learn: 0.4008344	total: 33.1s	remaining: 2.34s
# 934:	learn: 0.3979590	total: 33.2s	remaining: 2.31s
# 935:	learn: 0.3962122	total: 33.2s	remaining: 2.27s
# 936:	learn: 0.3955150	total: 33.3s	remaining: 2.24s
# 937:	learn: 0.3940314	total: 33.3s	remaining: 2.2s
# 938:	learn: 0.3910303	total: 33.3s	remaining: 2.17s
# 939:	learn: 0.3876924	total: 33.4s	remaining: 2.13s
# 940:	learn: 0.3871091	total: 33.4s	remaining: 2.09s
# 941:	learn: 0.3853373	total: 33.4s	remaining: 2.06s
# 942:	learn: 0.3820640	total: 33.5s	remaining: 2.02s
# 943:	learn: 0.3814653	total: 33.5s	remaining: 1.99s
# 944:	learn: 0.3814043	total: 33.5s	remaining: 1.95s
# 945:	learn: 0.3790759	total: 33.6s	remaining: 1.92s
# 946:	learn: 0.3767639	total: 33.6s	remaining: 1.88s
# 947:	learn: 0.3721348	total: 33.6s	remaining: 1.84s
# 948:	learn: 0.3690648	total: 33.7s	remaining: 1.81s
# 949:	learn: 0.3662658	total: 33.7s	remaining: 1.77s
# 950:	learn: 0.3628892	total: 33.7s	remaining: 1.74s
# 951:	learn: 0.3605469	total: 33.8s	remaining: 1.7s
# 952:	learn: 0.3586267	total: 33.8s	remaining: 1.67s
# 953:	learn: 0.3565360	total: 33.8s	remaining: 1.63s
# 954:	learn: 0.3546011	total: 33.9s	remaining: 1.59s
# 955:	learn: 0.3518692	total: 33.9s	remaining: 1.56s
# 956:	learn: 0.3488186	total: 33.9s	remaining: 1.52s
# 957:	learn: 0.3460260	total: 34s	remaining: 1.49s
# 958:	learn: 0.3433331	total: 34s	remaining: 1.45s
# 959:	learn: 0.3418756	total: 34s	remaining: 1.42s
# 960:	learn: 0.3404038	total: 34.1s	remaining: 1.38s
# 961:	learn: 0.3382820	total: 34.1s	remaining: 1.35s
# 962:	learn: 0.3361297	total: 34.1s	remaining: 1.31s
# 963:	learn: 0.3334524	total: 34.2s	remaining: 1.27s
# 964:	learn: 0.3301070	total: 34.2s	remaining: 1.24s
# 965:	learn: 0.3286559	total: 34.2s	remaining: 1.2s
# 966:	learn: 0.3274732	total: 34.3s	remaining: 1.17s
# 967:	learn: 0.3248591	total: 34.3s	remaining: 1.13s
# 968:	learn: 0.3231131	total: 34.4s	remaining: 1.1s
# 969:	learn: 0.3210901	total: 34.4s	remaining: 1.06s
# 970:	learn: 0.3190128	total: 34.4s	remaining: 1.03s
# 971:	learn: 0.3164713	total: 34.5s	remaining: 993ms
# 972:	learn: 0.3148908	total: 34.5s	remaining: 957ms
# 973:	learn: 0.3138494	total: 34.5s	remaining: 922ms
# 974:	learn: 0.3136378	total: 34.6s	remaining: 886ms
# 975:	learn: 0.3129166	total: 34.6s	remaining: 851ms
# 976:	learn: 0.3111378	total: 34.6s	remaining: 815ms
# 977:	learn: 0.3091375	total: 34.7s	remaining: 780ms
# 978:	learn: 0.3067201	total: 34.7s	remaining: 744ms
# 979:	learn: 0.3046513	total: 34.7s	remaining: 709ms
# 980:	learn: 0.3026928	total: 34.8s	remaining: 673ms
# 981:	learn: 0.3025785	total: 34.8s	remaining: 638ms
# 982:	learn: 0.3011219	total: 34.8s	remaining: 602ms
# 983:	learn: 0.3010975	total: 34.9s	remaining: 567ms
# 984:	learn: 0.2988931	total: 34.9s	remaining: 532ms
# 985:	learn: 0.2986742	total: 35s	remaining: 496ms
# 986:	learn: 0.2961836	total: 35s	remaining: 461ms
# 987:	learn: 0.2927256	total: 35s	remaining: 425ms
# 988:	learn: 0.2924282	total: 35s	remaining: 390ms
# 989:	learn: 0.2904195	total: 35.1s	remaining: 354ms
# 990:	learn: 0.2888892	total: 35.1s	remaining: 319ms
# 991:	learn: 0.2863379	total: 35.2s	remaining: 284ms
# 992:	learn: 0.2851711	total: 35.2s	remaining: 248ms
# 993:	learn: 0.2819680	total: 35.2s	remaining: 213ms
# 994:	learn: 0.2810001	total: 35.3s	remaining: 177ms
# 995:	learn: 0.2793925	total: 35.3s	remaining: 142ms
# 996:	learn: 0.2776717	total: 35.3s	remaining: 106ms
# 997:	learn: 0.2747361	total: 35.4s	remaining: 70.8ms
# 998:	learn: 0.2742525	total: 35.4s	remaining: 35.4ms
# 999:	learn: 0.2718884	total: 35.4s	remaining: 0us
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# ---Predictions made---
